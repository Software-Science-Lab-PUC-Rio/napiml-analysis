# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values
from ipynb.fs.full.plots import single_barplot

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head(10)
# Out:
#     ID          Status Duration      D1_Undergraduation  \
# 2   31  Completed (31)     1317               Economics
# 3   34  Completed (31)      854                     -99
# 4   36  Completed (31)     1593             Mathmathics
# 5   57  Completed (31)     4238        Computer Science
# 6   46  Completed (31)     2821   Graduation in Actuary
# 7   53  Completed (31)     2097      Information System
# 8   58  Completed (31)     1696        Computer Science
# 9   64  Completed (31)     1250  Electrical engineering
# 10  65  Completed (31)      106                     -99
# 11  69  Completed (31)       79                     -99
#
#                   D1_Specialization                             D1_Master  \
# 2                               -99                    M.Sc. in Economics
# 3                       Management                                     No
# 4                       Informatics                  MSC Computer Science
# 5       Data science specialization                                   -99
# 6   Post Graduation in Data Science       M Sc in Data Science -ML models
# 7                               -99          M.Sc. in Applied Informatics
# 8                               -99                      Computer Science
# 9                               -99  M.Sc. in AI and Software Engineering
# 10                              -99                                   -99
# 11                              -99                                   -99
#
#                   D1_Phd                                         D1_Courses  \
# 2                    -99                         Data Scientist in Datacamp
# 3                     No                                                 No
# 4   PhD computer Science                          Vários cursos in Coursera
# 5                    -99                                                -99
# 6                no Ph D                            no other certifications
# 7                    -99                                                -99
# 8                    -99  Microsoft Professional Program Data Science & ...
# 9       Computer science  Azure Associate AI Engineer, Azure Data Scienc...
# 10                   -99                                                -99
# 11                   -99                                                -99
#
#    D1_Others D2_Country  ...  \
# 2        -99     Brazil  ...
# 3         No     Brazil  ...
# 4        -99     Brazil  ...
# 5        -99    Germany  ...
# 6        -99     Brazil  ...
# 7        -99     Brazil  ...
# 8        -99    Germany  ...
# 9        -99     Sweden  ...
# 10       -99          0  ...
# 11       -99          0  ...
#
#    Q12_RE_Most_Difficult_Activity_Customer_AligningRE_Data  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                              quoted
# 8                                              quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Conflicts   \
# 2                                              quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                              quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_New_Quality_Attributes  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                              quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                              quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Documentation   \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                              quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                          not quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Selecting_Metrics  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                              quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Verification   \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Changing_RE   \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                              quoted
# 8                                          not quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Others  \
# 2                                      not quoted
# 3                                      not quoted
# 4                                      not quoted
# 5                                      not quoted
# 6                                      not quoted
# 7                                      not quoted
# 8                                      not quoted
# 9                                      not quoted
# 10                                     not quoted
# 11                                     not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Others_Free  \
# 2                                                 -99
# 3                                                 -99
# 4                                                 -99
# 5                                                 -99
# 6                                                 -99
# 7                                                 -99
# 8                                                 -99
# 9                                                 -99
# 10                                                -99
# 11                                                -99
#
#                              Origin
# 2   https://ww2.unipark.de/uc/seml/
# 3                               -99
# 4                               -99
# 5                               -99
# 6                               -99
# 7                               -99
# 8                     https://t.co/
# 9         https://www.linkedin.com/
# 10                              -99
# 11  https://ww2.unipark.de/uc/seml/
#
# [10 rows x 185 columns]

# %%
df_q8 = df.filter(regex='Q8')
df_q8.head()
# Out:
#   Q8_Who_is_AdressingRE_ProjectLead  Q8_Who_is_AdressingRE_BusinessAnalyst   \
# 2                         not quoted                             not quoted
# 3                         not quoted                                 quoted
# 4                             quoted                             not quoted
# 5                             quoted                             not quoted
# 6                         not quoted                             not quoted
#
#   Q8_Who_is_AdressingRE_RequirementEngineer   \
# 2                                 not quoted
# 3                                 not quoted
# 4                                 not quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q8_Who_is_AdressingRE_SolutionArchitect   \
# 2                               not quoted
# 3                               not quoted
# 4                               not quoted
# 5                                   quoted
# 6                               not quoted
#
#   Q8_Who_is_AdressingRE_DataScientist  Q8_Who_is_AdressingRE_Developer'   \
# 2                           not quoted                            quoted
# 3                           not quoted                        not quoted
# 4                           not quoted                        not quoted
# 5                               quoted                            quoted
# 6                               quoted                        not quoted
#
#   Q8_Who_is_AdressingRE_Tester  Q8_Who_is_AdressingRE_Others  \
# 2                        quoted                   not quoted
# 3                    not quoted                   not quoted
# 4                    not quoted                   not quoted
# 5                    not quoted                   not quoted
# 6                    not quoted                   not quoted
#
#   Q8_Who_is_AdressingRE_Others_Free
# 2                                                -99
# 3                                                -99
# 4                                                -99
# 5                                                -99
# 6                                                -99

# %%
#Responses as others

df_q8_others = df_q8.filter(regex='Others')
df_q8_others

for c in df_q8_others.columns:
    print(c)
    print(df_q8_others[c].value_counts())
# Out:
# Q8_Who_is_AdressingRE_Others
# not quoted    175
# -77            82
# quoted         19
# Name: Q8_Who_is_AdressingRE_Others, dtype: int64
# Q8_Who_is_AdressingRE_Others_Free
# -99                                                              175
# -66                                                               82
# Machine Learning Engineer                                          1
# Subject Matter Expert                                              1
# Analistas de segurança                                             1
# Operational Research Analyst                                       1
# My master's program mentor                                         1
# software engineer                                                  1
# Me, student and developer                                          1
# SRE Team, mainly the Data Lead                                     1
# Product Owner                                                      1
# Business                                                           1
# Product owner                                                      1
# Director                                                           1
# Product owners. Customers                                          1
# No one                                                             1
# CEO                                                                1
# System Engineer                                                    1
# Architects, Tech Leads and managers                                1
# Stream Lead Application Development, Requirements Engineering      1
# Group of tech leads                                                1
# Name: Q8_Who_is_AdressingRE_Others_Free                  , dtype: int64

# %%
# Pandas DataFrame [quoted per columns]

dict_q8 = {}
for c in df_q8.columns:
    if "Free" and "Others" not in c:
        role = c.split('_')
        dict_q8[role[4:][0]] = df_q8[c].value_counts()['quoted']

df_q8_quoted = pd.DataFrame(data={'Position': list(dict_q8.keys()), 'Answers': list(dict_q8.values())})
df_q8_quoted = df_q8_quoted.sort_values('Answers', ascending=False)
df_q8_quoted
# Out:
#                Position  Answers
# 0          ProjectLead        99
# 4        DataScientist        95
# 1      BusinessAnalyst        50
# 5           Developer'        37
# 3    SolutionArchitect        24
# 2  RequirementEngineer        20
# 6               Tester         2

# %%
single_barplot(df_q8_quoted, "Answers", "Position",
               title="Q8. Who is actively addressing the requirements of ML-enabled system projects in your organization?",
               x_label="Count", y_label="Position", x_label_rotation=0)
