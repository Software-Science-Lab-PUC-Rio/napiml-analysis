# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values, replace_values_by_condition
from ipynb.fs.full.plots import single_barplot
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = get_df()
df = df[['D1_Undergraduation', 'D1_Specialization', 'D1_Master', 'D1_Phd', 'D1_Courses']]
df.head(10)
# Out:
#                         D1_Undergraduation                D1_Specialization  \
# 2                                Economics                              -99
# 3                                      -99                      Management
# 4                              Mathematics                      Informatics
# 5                         Computer Science      Data science specialization
# 6                        Actuarial Science  Post Graduation in Data Science
# 7                       Information System                              -99
# 8                         Computer Science                              -99
# 9   Electrical and Electronics Engineering                              -99
# 10                                     -99                              -99
# 11                                     -99                              -99
#
#                                D1_Master                D1_Phd  \
# 2                     M.Sc. in Economics                   -99
# ...

# %%
sorted(df['D1_Undergraduation'].unique())
sns.set(rc={'figure.figsize':(12.7,10.27)})
sns.barplot(x=df['D1_Undergraduation'].value_counts(), y=df['D1_Undergraduation'].value_counts().index, data=df, orient ="h", color="b")
# Out:
# <AxesSubplot:xlabel='D1_Undergraduation'>

# %%
df['D1_Undergraduation'].value_counts().index
# Out:
# Index(['Computer Science', '-99', 'Computer Engineering',
#        'Electrical and Electronics Engineering', 'Mathematics', 'Statistics',
#        'Information Systems', 'Software Engineering', 'Economics', 'Physics',
#        'Industrial Engineering', 'Civil Engineering', 'Engineering',
#        'Mechanical Engineering', 'Informatics', 'Chemical Engineering',
#        'Telecommunications Engineering', 'Systems Analysis',
#        'Mechatronics Engineering', 'Production Engineering',
#        'Mathematics, Physics', 'Actuarial Science', 'Aerospace Engineering',
#        'Nuclear Engineering', 'Data Processing', 'Metallurgical Engineering',
#        'Instrumentation and Control Engineering', 'Automation Engineering',
#        'System Administration', 'Logistics', 'Biology',
#        'Information Engineering', 'Manufacturing Engineering', 'Chip designer',
#        'Data Base', 'Robotics Engineering ',
#        'Management and Industrial Engineering',
# ...

# %%
replace_values_by_condition(df, 'D1_Undergraduation', '-99', 'Not selected', 'eq')
# Out:
#     D1_Undergraduation                D1_Specialization  \
# 2            Economics                              -99
# 3          No selected                      Management
# 4          Mathematics                      Informatics
# 5     Computer Science      Data science specialization
# 6    Actuarial Science  Post Graduation in Data Science
# ..                 ...                              ...
# 273   Computer Science             Software Engineering
# 274   Computer Science                              -99
# 275   Computer Science      Data Science Specialization
# 276   Computer Science                              -99
# 277        No selected                              -99
#
#                            D1_Master                D1_Phd  \
# 2                 M.Sc. in Economics                   -99
# 3                                 No                    No
# 4               MSC Computer Science  PhD computer Science
# ...

# %%
df['D1_Undergraduation'].value_counts().index
# Out:
# Index(['Computer Science', 'No selected',
#        'Electrical and Electronics Engineering', 'Computer Engineering',
#        'Mathematics', 'Statistics', 'Information Systems',
#        'Software Engineering', 'Economics', 'Industrial Engineering',
#        'Physics', 'Civil Engineering', 'Mechanical Engineering', 'Engineering',
#        'Chemical Engineering', 'Systems Analysis',
#        'Telecommunications Engineering', 'Mechatronics Engineering',
#        'Production Engineering', 'Mathematics, Physics', 'Actuarial Science',
#        'Nuclear Engineering', 'Instrumentation and Control Engineering',
#        'Metallurgical Engineering', 'Data Processing', 'Aerospace Engineering',
#        'Automation Engineering', 'System Administration', 'Logistics',
#        'Biology', 'Information Engineering', 'Chip designer',
#        'Computer System Management', 'Data Base', 'Robotics Engineering ',
#        'Management and Industrial Engineering',
# ...

# %%
sns.set(rc={'figure.figsize':(12.7,9.27)})
sns.barplot(x=df['D1_Undergraduation'].value_counts(), y=df['D1_Undergraduation'].value_counts().index, data=df, orient ="h", color="b")
# Out:
# <AxesSubplot:xlabel='D1_Undergraduation'>

# %%
df['D1_Undergraduation'].unique()
# Out:
# array(['Economics', '-99', 'Mathematics', 'Computer Science',
#        'Actuarial Science', 'Information System',
#        'Electrical and Electronics Engineering', 'Statistics',
#        'Mechanical Engineering', 'Physics', 'Engineering',
#        'Mathematics, Physics', 'Production Engineering',
#        'Industrial Pharmacy', 'Business Informatics',
#        'Computer Engineering', 'Mechatronics Engineering',
#        'Industrial Engineering', 'Computer System Management',
#        'Civil Engineering', 'Software Engineering',
#        'Telecommunications Engineering', 'Manufacturing Engineering',
#        'Information Systems', 'Computer Science, Mathematics',
#        'Systems Analysis', 'Computer System Administration',
#        'Management and Industrial Engineering', 'Robotics Engineering ',
#        'Data Base', 'Chip designer', 'Nuclear Engineering',
#        'Information Engineering', 'Biology', 'Logistics',
#        'System Administration', 'Automation Engineering',
# ...

# %%
df = replace_values_by_condition(df, 'D1_Undergraduation', 'Informatics', 'Computer Science', 'eq')
