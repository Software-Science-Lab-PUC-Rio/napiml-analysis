# %%
import pandas as pd
from ipynb.fs.full.utils import custom_groupby, get_df, rename_values
from ipynb.fs.full.plots import heatmap

# %%
df = get_df()

# %%
df.head(10)
# Out:
#     ID          Status Duration                      D1_Undergraduation  \
# 2   31  Completed (31)     1317                               Economics
# 3   34  Completed (31)      854                                     -99
# 4   36  Completed (31)     1593                             Mathematics
# 5   57  Completed (31)     4238                        Computer Science
# 6   46  Completed (31)     2821                       Actuarial Science
# 7   53  Completed (31)     2097                      Information System
# 8   58  Completed (31)     1696                        Computer Science
# 9   64  Completed (31)     1250  Electrical and Electronics Engineering
# 10  65  Completed (31)      106                                     -99
# 11  69  Completed (31)       79                                     -99
#
#                   D1_Specialization                             D1_Master  \
# 2                               -99                    M.Sc. in Economics
# 3                       Management                                     No
# 4                       Informatics                  MSC Computer Science
# 5       Data science specialization                                   -99
# 6   Post Graduation in Data Science       M Sc in Data Science -ML models
# 7                               -99          M.Sc. in Applied Informatics
# 8                               -99                      Computer Science
# 9                               -99  M.Sc. in AI and Software Engineering
# 10                              -99                                   -99
# 11                              -99                                   -99
#
#                   D1_Phd                                         D1_Courses  \
# 2                    -99                         Data Scientist in Datacamp
# 3                     No                                                 No
# 4   PhD computer Science                          Vários cursos in Coursera
# 5                    -99                                                -99
# 6                no Ph D                            no other certifications
# 7                    -99                                                -99
# 8                    -99  Microsoft Professional Program Data Science & ...
# 9       Computer science  Azure Associate AI Engineer, Azure Data Scienc...
# 10                   -99                                                -99
# 11                   -99                                                -99
#
#    D1_Others D2_Country  ... Q15_Model_Deploy_Production_Monitoring  \
# 2        -99     Brazil  ...                                    -77
# 3         No     Brazil  ...                                     70
# 4        -99     Brazil  ...                                     60
# 5        -99    Germany  ...                                    100
# 6        -99     Brazil  ...                                     80
# 7        -99     Brazil  ...                                     30
# 8        -99    Germany  ...                                     10
# 9        -99     Sweden  ...                                      0
# 10       -99          0  ...                                    -77
# 11       -99          0  ...                                    -77
#
#    Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                  not quoted
# 3                                  not quoted
# 4                                      quoted
# 5                                  not quoted
# 6                                  not quoted
# 7                                      quoted
# 8                                      quoted
# 9                                  not quoted
# 10                                 not quoted
# 11                                 not quoted
#
#    Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                         not quoted
# 3                                         not quoted
# 4                                         not quoted
# 5                                             quoted
# 6                                             quoted
# 7                                             quoted
# 8                                         not quoted
# 9                                         not quoted
# 10                                        not quoted
# 11                                        not quoted
#
#    Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                      not quoted
# 3                                          quoted
# 4                                          quoted
# 5                                          quoted
# 6                                          quoted
# 7                                      not quoted
# 8                                      not quoted
# 9                                      not quoted
# 10                                     not quoted
# 11                                     not quoted
#
#    Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                          not quoted                       not quoted
# 3                          not quoted                       not quoted
# 4                          not quoted                       not quoted
# 5                          not quoted                       not quoted
# 6                          not quoted                       not quoted
# 7                          not quoted                       not quoted
# 8                          not quoted                       not quoted
# 9                          not quoted                       not quoted
# 10                         not quoted                       not quoted
# 11                         not quoted                       not quoted
#
#    Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                    -99
# 3                                    -99
# 4                                    -99
# 5                                    -99
# 6                                    -99
# 7                                    -99
# 8                                    -99
# 9                                    -99
# 10                                   -99
# 11                                   -99
#
#    Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                            0
# 3                                           No
# 4                         Yes, Please, specify
# 5                                           No
# 6                                           No
# 7                                           No
# 8                                           No
# 9                                           No
# 10                                           0
# 11                                           0
#
#    Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                            -99
# 3                                            -99
# 4                                   Own approach
# 5                                            -99
# 6                                            -99
# 7                                            -99
# 8                                            -99
# 9                                            -99
# 10                                           -99
# 11                                           -99
#
#                              Origin
# 2   https://ww2.unipark.de/uc/seml/
# 3                               -99
# 4                               -99
# 5                               -99
# 6                               -99
# 7                               -99
# 8                     https://t.co/
# 9         https://www.linkedin.com/
# 10                              -99
# 11  https://ww2.unipark.de/uc/seml/
#
# [10 rows x 202 columns]

# %%
df[['D10_ML_Management_Framework_None', 'D10_ML_Management_Framework_CRISP-DM', 'D10_ML_Management_Framework_Kanban',
    'D10_ML_Management_Framework_Lean', 'D10_ML_Management_Framework_RUP', 'D10_ML_Management_Framework_SAFe',
    'D10_ML_Management_Framework_Scrum', 'D11_Agile_Development']].head()
# Out:
#   D10_ML_Management_Framework_None D10_ML_Management_Framework_CRISP-DM  \
# 2                       not quoted                           not quoted
# 3                       not quoted                           not quoted
# 4                           quoted                           not quoted
# 5                       not quoted                           not quoted
# 6                       not quoted                           not quoted
#
#   D10_ML_Management_Framework_Kanban D10_ML_Management_Framework_Lean  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                             quoted                       not quoted
#
#   D10_ML_Management_Framework_RUP D10_ML_Management_Framework_SAFe  \
# 2                      not quoted                       not quoted
# 3                      not quoted                       not quoted
# 4                      not quoted                       not quoted
# 5                      not quoted                       not quoted
# 6                      not quoted                       not quoted
#
#   D10_ML_Management_Framework_Scrum                   D11_Agile_Development
# 2                        not quoted                     Totally traditional
# 3                            quoted  Balanced between agile and traditional
# 4                        not quoted  Balanced between agile and traditional
# 5                            quoted                           Totally agile
# 6                        not quoted  Balanced between agile and traditional

# %%
frameworks_mapping = {
    'D10_ML_Management_Framework_None': 'None',
    'D10_ML_Management_Framework_CRISP-DM': 'CRISP-DM',
    'D10_ML_Management_Framework_Kanban': 'Kanban',
    'D10_ML_Management_Framework_Lean': 'Lean',
    'D10_ML_Management_Framework_RUP': 'RUP',
    'D10_ML_Management_Framework_SAFe': 'SAFe',
    'D10_ML_Management_Framework_Scrum': 'Scrum'
}

# %%
frameworks = []
agility = []
framework_agility = []
for index, row in df.iterrows():
    for f in frameworks_mapping:
        # formatted name for framework
        frameworks.append(frameworks_mapping[f])
        # what did the guy who answered an specific framework about agility
        agility.append(row['D11_Agile_Development'])
        # match
        if row[f] == 'not quoted':
            framework_agility.append(0)
        elif row[f] == 'quoted':
            framework_agility.append(1)

# %%
# create a custom dataframe to handle only the columns that we want
d10_11_df = pd.DataFrame()
d10_11_df['Framework'] = frameworks
d10_11_df['Agility'] = agility
d10_11_df['Answers'] = framework_agility

# %%
d10_11_df.head(1900)
# Out:
#      Framework              Agility  Answers
# 0         None  Totally traditional        0
# 1     CRISP-DM  Totally traditional        0
# 2       Kanban  Totally traditional        0
# 3         Lean  Totally traditional        0
# 4          RUP  Totally traditional        0
# ...        ...                  ...      ...
# 1895      SAFe  Totally traditional        0
# 1896     Scrum  Totally traditional        0
# 1897      None  Totally traditional        1
# 1898  CRISP-DM  Totally traditional        0
# 1899    Kanban  Totally traditional        0
#
# [1900 rows x 3 columns]

# %%
d10_11_df['Agility'].value_counts()
# Out:
# Mostly agile                              623
# Balanced between agile and traditional    539
# Totally traditional                       287
# Mostly traditional                        203
# Totally agile                             161
# I don't know                              112
# 0                                           7
# Name: Agility, dtype: int64

# %%
d10_11_df['Answers'].value_counts()
# Out:
# 0    1575
# 1     357
# Name: Answers, dtype: int64

# %%
d10_11_df.index.to_list()[1000:]
# Out:
# [1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  1010,
#  1011,
#  1012,
#  1013,
#  1014,
#  1015,
#  1016,
#  1017,
#  1018,
#  1019,
#  1020,
#  1021,
#  1022,
#  1023,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  1030,
#  1031,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1037,
#  1038,
#  1039,
#  1040,
#  1041,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1077,
#  1078,
#  1079,
#  1080,
#  1081,
#  1082,
#  1083,
#  1084,
#  1085,
#  1086,
#  1087,
#  1088,
#  1089,
#  1090,
#  1091,
#  1092,
#  1093,
#  1094,
#  1095,
#  1096,
#  1097,
#  1098,
#  1099,
#  1100,
#  1101,
#  1102,
#  1103,
#  1104,
#  1105,
#  1106,
#  1107,
#  1108,
#  1109,
#  1110,
#  1111,
#  1112,
#  1113,
#  1114,
#  1115,
#  1116,
#  1117,
#  1118,
#  1119,
#  1120,
#  1121,
#  1122,
#  1123,
#  1124,
#  1125,
#  1126,
#  1127,
#  1128,
#  1129,
#  1130,
#  1131,
#  1132,
#  1133,
#  1134,
#  1135,
#  1136,
#  1137,
#  1138,
#  1139,
#  1140,
#  1141,
#  1142,
#  1143,
#  1144,
#  1145,
#  1146,
#  1147,
#  1148,
#  1149,
#  1150,
#  1151,
#  1152,
#  1153,
#  1154,
#  1155,
#  1156,
#  1157,
#  1158,
#  1159,
#  1160,
#  1161,
#  1162,
#  1163,
#  1164,
#  1165,
#  1166,
#  1167,
#  1168,
#  1169,
#  1170,
#  1171,
#  1172,
#  1173,
#  1174,
#  1175,
#  1176,
#  1177,
#  1178,
#  1179,
#  1180,
#  1181,
#  1182,
#  1183,
#  1184,
#  1185,
#  1186,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1192,
#  1193,
#  1194,
#  1195,
#  1196,
#  1197,
#  1198,
#  1199,
#  1200,
#  1201,
#  1202,
#  1203,
#  1204,
#  1205,
#  1206,
#  1207,
#  1208,
#  1209,
#  1210,
#  1211,
#  1212,
#  1213,
#  1214,
#  1215,
#  1216,
#  1217,
#  1218,
#  1219,
#  1220,
#  1221,
#  1222,
#  1223,
#  1224,
#  1225,
#  1226,
#  1227,
#  1228,
#  1229,
#  1230,
#  1231,
#  1232,
#  1233,
#  1234,
#  1235,
#  1236,
#  1237,
#  1238,
#  1239,
#  1240,
#  1241,
#  1242,
#  1243,
#  1244,
#  1245,
#  1246,
#  1247,
#  1248,
#  1249,
#  1250,
#  1251,
#  1252,
#  1253,
#  1254,
#  1255,
#  1256,
#  1257,
#  1258,
#  1259,
#  1260,
#  1261,
#  1262,
#  1263,
#  1264,
#  1265,
#  1266,
#  1267,
#  1268,
#  1269,
#  1270,
#  1271,
#  1272,
#  1273,
#  1274,
#  1275,
#  1276,
#  1277,
#  1278,
#  1279,
#  1280,
#  1281,
#  1282,
#  1283,
#  1284,
#  1285,
#  1286,
#  1287,
#  1288,
#  1289,
#  1290,
#  1291,
#  1292,
#  1293,
#  1294,
#  1295,
#  1296,
#  1297,
#  1298,
#  1299,
#  1300,
#  1301,
#  1302,
#  1303,
#  1304,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  1315,
#  1316,
#  1317,
#  1318,
#  1319,
#  1320,
#  1321,
#  1322,
#  1323,
#  1324,
#  1325,
#  1326,
#  1327,
#  1328,
#  1329,
#  1330,
#  1331,
#  1332,
#  1333,
#  1334,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  1340,
#  1341,
#  1342,
#  1343,
#  1344,
#  1345,
#  1346,
#  1347,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1353,
#  1354,
#  1355,
#  1356,
#  1357,
#  1358,
#  1359,
#  1360,
#  1361,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1370,
#  1371,
#  1372,
#  1373,
#  1374,
#  1375,
#  1376,
#  1377,
#  1378,
#  1379,
#  1380,
#  1381,
#  1382,
#  1383,
#  1384,
#  1385,
#  1386,
#  1387,
#  1388,
#  1389,
#  1390,
#  1391,
#  1392,
#  1393,
#  1394,
#  1395,
#  1396,
#  1397,
#  1398,
#  1399,
#  1400,
#  1401,
#  1402,
#  1403,
#  1404,
#  1405,
#  1406,
#  1407,
#  1408,
#  1409,
#  1410,
#  1411,
#  1412,
#  1413,
#  1414,
#  1415,
#  1416,
#  1417,
#  1418,
#  1419,
#  1420,
#  1421,
#  1422,
#  1423,
#  1424,
#  1425,
#  1426,
#  1427,
#  1428,
#  1429,
#  1430,
#  1431,
#  1432,
#  1433,
#  1434,
#  1435,
#  1436,
#  1437,
#  1438,
#  1439,
#  1440,
#  1441,
#  1442,
#  1443,
#  1444,
#  1445,
#  1446,
#  1447,
#  1448,
#  1449,
#  1450,
#  1451,
#  1452,
#  1453,
#  1454,
#  1455,
#  1456,
#  1457,
#  1458,
#  1459,
#  1460,
#  1461,
#  1462,
#  1463,
#  1464,
#  1465,
#  1466,
#  1467,
#  1468,
#  1469,
#  1470,
#  1471,
#  1472,
#  1473,
#  1474,
#  1475,
#  1476,
#  1477,
#  1478,
#  1479,
#  1480,
#  1481,
#  1482,
#  1483,
#  1484,
#  1485,
#  1486,
#  1487,
#  1488,
#  1489,
#  1490,
#  1491,
#  1492,
#  1493,
#  1494,
#  1495,
#  1496,
#  1497,
#  1498,
#  1499,
#  1500,
#  1501,
#  1502,
#  1503,
#  1504,
#  1505,
#  1506,
#  1507,
#  1508,
#  1509,
#  1510,
#  1511,
#  1512,
#  1513,
#  1514,
#  1515,
#  1516,
#  1517,
#  1518,
#  1519,
#  1520,
#  1521,
#  1522,
#  1523,
#  1524,
#  1525,
#  1526,
#  1527,
#  1528,
#  1529,
#  1530,
#  1531,
#  1532,
#  1533,
#  1534,
#  1535,
#  1536,
#  1537,
#  1538,
#  1539,
#  1540,
#  1541,
#  1542,
#  1543,
#  1544,
#  1545,
#  1546,
#  1547,
#  1548,
#  1549,
#  1550,
#  1551,
#  1552,
#  1553,
#  1554,
#  1555,
#  1556,
#  1557,
#  1558,
#  1559,
#  1560,
#  1561,
#  1562,
#  1563,
#  1564,
#  1565,
#  1566,
#  1567,
#  1568,
#  1569,
#  1570,
#  1571,
#  1572,
#  1573,
#  1574,
#  1575,
#  1576,
#  1577,
#  1578,
#  1579,
#  1580,
#  1581,
#  1582,
#  1583,
#  1584,
#  1585,
#  1586,
#  1587,
#  1588,
#  1589,
#  1590,
#  1591,
#  1592,
#  1593,
#  1594,
#  1595,
#  1596,
#  1597,
#  1598,
#  1599,
#  1600,
#  1601,
#  1602,
#  1603,
#  1604,
#  1605,
#  1606,
#  1607,
#  1608,
#  1609,
#  1610,
#  1611,
#  1612,
#  1613,
#  1614,
#  1615,
#  1616,
#  1617,
#  1618,
#  1619,
#  1620,
#  1621,
#  1622,
#  1623,
#  1624,
#  1625,
#  1626,
#  1627,
#  1628,
#  1629,
#  1630,
#  1631,
#  1632,
#  1633,
#  1634,
#  1635,
#  1636,
#  1637,
#  1638,
#  1639,
#  1640,
#  1641,
#  1642,
#  1643,
#  1644,
#  1645,
#  1646,
#  1647,
#  1648,
#  1649,
#  1650,
#  1651,
#  1652,
#  1653,
#  1654,
#  1655,
#  1656,
#  1657,
#  1658,
#  1659,
#  1660,
#  1661,
#  1662,
#  1663,
#  1664,
#  1665,
#  1666,
#  1667,
#  1668,
#  1669,
#  1670,
#  1671,
#  1672,
#  1673,
#  1674,
#  1675,
#  1676,
#  1677,
#  1678,
#  1679,
#  1680,
#  1681,
#  1682,
#  1683,
#  1684,
#  1685,
#  1686,
#  1687,
#  1688,
#  1689,
#  1690,
#  1691,
#  1692,
#  1693,
#  1694,
#  1695,
#  1696,
#  1697,
#  1698,
#  1699,
#  1700,
#  1701,
#  1702,
#  1703,
#  1704,
#  1705,
#  1706,
#  1707,
#  1708,
#  1709,
#  1710,
#  1711,
#  1712,
#  1713,
#  1714,
#  1715,
#  1716,
#  1717,
#  1718,
#  1719,
#  1720,
#  1721,
#  1722,
#  1723,
#  1724,
#  1725,
#  1726,
#  1727,
#  1728,
#  1729,
#  1730,
#  1731,
#  1732,
#  1733,
#  1734,
#  1735,
#  1736,
#  1737,
#  1738,
#  1739,
#  1740,
#  1741,
#  1742,
#  1743,
#  1744,
#  1745,
#  1746,
#  1747,
#  1748,
#  1749,
#  1750,
#  1751,
#  1752,
#  1753,
#  1754,
#  1755,
#  1756,
#  1757,
#  1758,
#  1759,
#  1760,
#  1761,
#  1762,
#  1763,
#  1764,
#  1765,
#  1766,
#  1767,
#  1768,
#  1769,
#  1770,
#  1771,
#  1772,
#  1773,
#  1774,
#  1775,
#  1776,
#  1777,
#  1778,
#  1779,
#  1780,
#  1781,
#  1782,
#  1783,
#  1784,
#  1785,
#  1786,
#  1787,
#  1788,
#  1789,
#  1790,
#  1791,
#  1792,
#  1793,
#  1794,
#  1795,
#  1796,
#  1797,
#  1798,
#  1799,
#  1800,
#  1801,
#  1802,
#  1803,
#  1804,
#  1805,
#  1806,
#  1807,
#  1808,
#  1809,
#  1810,
#  1811,
#  1812,
#  1813,
#  1814,
#  1815,
#  1816,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1823,
#  1824,
#  1825,
#  1826,
#  1827,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1833,
#  1834,
#  1835,
#  1836,
#  1837,
#  1838,
#  1839,
#  1840,
#  1841,
#  1842,
#  1843,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1857,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1868,
#  1869,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931]

# %%
heatmap(d10_11_df.set_index(['Framework', 'Agility', 'Answers'], append=True), 'Framework', 'Agility', 'Answers', title='Frameworks and Agility')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Framework'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 heatmap(d10_11_df.set_index(['Framework', 'Agility', 'Answers'], append=True), 'Framework', 'Agility', 'Answers', title='Frameworks and Agility')
#
# File ~\Documents\Mestrado PUC\NaPiML\survey-analysis\napmil-analysis\Análises\plots.ipynb:54, in heatmap(df, x_axis, y_axis, xy_match, title, fmt)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "2bb137dc",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "# importing important libs\n",
#      11     "import seaborn as sns\n",
#      12     "import matplotlib.pyplot as plt\n",
#      13     "\n",
#      14     "# set a grid for all seaborn plots\n",
#      15     "sns.set_theme(style=\"whitegrid\")"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 2,
#      21    "id": "88e158cb",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "def single_barplot(df, x_axis, y_axis, title='', x_label='', y_label='', x_label_rotation=0):\n",
#      26     "    #draw a barplot with single bars\n",
#      27     "    barplot = sns.catplot(data=df, kind=\"bar\", x=x_axis, y=y_axis, ci=\"sd\", palette=\"dark\", alpha=.5, linewidth=5,\n",
#      28     "                          height=5, aspect=10/5).set(title=title)\n",
#      29     "    \n",
#      30     "    barplot.set_xticklabels(rotation=x_label_rotation)\n",
#      31     "    barplot.despine(left=True)\n",
#      32     "    barplot.set_axis_labels(x_label, y_label)"
#      33    ]
#      34   },
#      35   {
#      36    "cell_type": "code",
#      37    "execution_count": 3,
#      38    "id": "dc378b37",
#      39    "metadata": {},
#      40    "outputs": [],
#      41    "source": [
#      42     "def pie_chart(values, labels, title=\"\"):\n",
#      43     "    #'values' contains percentages of pie - sum must not exceed 100\n",
#      44     "    # 'values' and 'labels' must have same length\n",
#      45     "\n",
#      46     "    #define Seaborn color palette to use\n",
#      47     "    colors = sns.color_palette('pastel')[0:len(values)]\n",
#      48     "\n",
#      49     "    #create pie chart with matplotlib but use seaborn default color pallete\n",
#      50     "    plt.pie(values, labels=labels, colors=colors, autopct='%.0f%%')\n",
#      51     "    plt.title(title)\n",
#      52     "    plt.show()"
#      53    ]
# ---> 54   },
#      55   {
#      56    "cell_type": "code",
#      57    "execution_count": 4,
#      58    "id": "4d1b3d3f",
#      59    "metadata": {},
#      60    "outputs": [],
#      61    "source": [
#      62     "def single_boxplot(df, y_axis, title=''):\n",
#      63     "    #draw a single boxplot - only y axis\n",
#      64     "    sns.boxplot(y=y_axis, data=df).set(title=title)\n",
#      65     "    sns.despine(offset=10, trim=True)"
#      66    ]
#      67   },
#      68   {
#      69    "cell_type": "code",
#      70    "execution_count": 5,
#      71    "id": "aa855ed3",
#      72    "metadata": {},
#      73    "outputs": [],
#      74    "source": [
#      75     "def single_violinplot(df, y_axis, title=''):\n",
#      76     "    # draw a single violinplot - only y axis\n",
#      77     "    # also show a line indicating quartiles\n",
#      78     "    sns.violinplot(data=df, y=y_axis, inner=\"quartile\", linewidth=1).set(title=title)\n",
#      79     "    sns.despine(left=True)"
#      80    ]
#      81   },
#      82   {
#      83    "cell_type": "code",
#      84    "execution_count": 6,
#      85    "id": "70635977",
#      86    "metadata": {},
#      87    "outputs": [],
#      88    "source": [
#      89     "def single_histplot(df, x_axis, title=''):\n",
#      90     "    # draw a histplot about one variable - only x axis\n",
#      91     "    sns.histplot(data=df, x=x_axis, kde=True).set(title=title)"
#      92    ]
#      93   },
#      94   {
#      95    "cell_type": "code",
#      96    "execution_count": 1,
#      97    "id": "4bb786d8",
#      98    "metadata": {},
#      99    "outputs": [],
#     100    "source": [
#     101     "def heatmap(df, x_axis, y_axis, xy_match, title='', fmt=''):\n",
#     102     "    # x_axis is the column which will become row\n",
#     103     "    # y_axis is the column which will keep being column\n",
#     104     "    # xy_match is the column that associates x to y\n",
#     105     "    # print(df.head())\n",
#     106     "    pivot_df = df.pivot(x_axis, y_axis, xy_match)\n",
#     107     "    # print(pivot_df.head())\n",
#     108     "    sns.heatmap(pivot_df, annot=True, fmt=fmt, linewidths=.5).set(title=title)"
#     109    ]
#     110   },
#     111   {
#     112    "cell_type": "code",
#     113    "execution_count": null,
#     114    "id": "bc33b0dd",
#     115    "metadata": {},
#     116    "outputs": [],
#     117    "source": []
#     118   }
#     119  ],
#     120  "metadata": {
#     121   "kernelspec": {
#     122    "display_name": "Python 3 (ipykernel)",
#     123    "language": "python",
#     124    "name": "python3"
#     125   },
#     126   "language_info": {
#     127    "codemirror_mode": {
#     128     "name": "ipython",
#     129     "version": 3
#     130    },
#     131    "file_extension": ".py",
#     132    "mimetype": "text/x-python",
#     133    "name": "python",
#     134    "nbconvert_exporter": "python",
#     135    "pygments_lexer": "ipython3",
#     136    "version": "3.8.10"
#     137   }
#     138  },
#     139  "nbformat": 4,
#     140  "nbformat_minor": 5
#     141 }
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\core\frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7874     from pandas.core.reshape.pivot import pivot
# -> 7876     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\core\reshape\pivot.py:506, in pivot(data, index, columns, values)
#     504         index_list = [Series(data.index, name=data.index.name)]
#     505 else:
# --> 506     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     508 data_columns = [data[col] for col in columns_listlike]
#     509 index_list.extend(data_columns)
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\core\reshape\pivot.py:506, in <listcomp>(.0)
#     504         index_list = [Series(data.index, name=data.index.name)]
#     505 else:
# --> 506     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     508 data_columns = [data[col] for col in columns_listlike]
#     509 index_list.extend(data_columns)
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\.virtualenvs\napmil-analysis-S-Ct1lS5\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Framework'

# %%
d10_11_df.set_index(['Framework', 'Agility', 'Answers'], append=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(0, None, Totally traditional, 0), (1, CRISP-DM, Totally traditional, 0), (2, Kanban, Totally traditional, 0), (3, Lean, Totally traditional, 0), (4, RUP, Totally traditional, 0), (5, SAFe, Totally traditional, 0), (6, Scrum, Totally traditional, 0), (7, None, Balanced between agile and traditional, 0), (8, CRISP-DM, Balanced between agile and traditional, 0), (9, Kanban, Balanced between agile and traditional, 0), (10, Lean, Balanced between agile and traditional, 0), (11, RUP, Balanced between agile and traditional, 0), (12, SAFe, Balanced between agile and traditional, 0), (13, Scrum, Balanced between agile and traditional, 1), (14, None, Balanced between agile and traditional, 1), (15, CRISP-DM, Balanced between agile and traditional, 0), (16, Kanban, Balanced between agile and traditional, 0), (17, Lean, Balanced between agile and traditional, 0), (18, RUP, Balanced between agile and traditional, 0), (19, SAFe, Balanced between agile and traditional, 0), (20, Scrum, Balanced between agile and traditional, 0), (21, None, Totally agile, 0), (22, CRISP-DM, Totally agile, 0), (23, Kanban, Totally agile, 0), (24, Lean, Totally agile, 0), (25, RUP, Totally agile, 0), (26, SAFe, Totally agile, 0), (27, Scrum, Totally agile, 1), (28, None, Balanced between agile and traditional, 0), (29, CRISP-DM, Balanced between agile and traditional, 0), (30, Kanban, Balanced between agile and traditional, 1), (31, Lean, Balanced between agile and traditional, 0), (32, RUP, Balanced between agile and traditional, 0), (33, SAFe, Balanced between agile and traditional, 0), (34, Scrum, Balanced between agile and traditional, 0), (35, None, Balanced between agile and traditional, 0), (36, CRISP-DM, Balanced between agile and traditional, 0), (37, Kanban, Balanced between agile and traditional, 1), (38, Lean, Balanced between agile and traditional, 0), (39, RUP, Balanced between agile and traditional, 0), (40, SAFe, Balanced between agile and traditional, 0), (41, Scrum, Balanced between agile and traditional, 1), (42, None, Balanced between agile and traditional, 1), (43, CRISP-DM, Balanced between agile and traditional, 0), (44, Kanban, Balanced between agile and traditional, 0), (45, Lean, Balanced between agile and traditional, 0), (46, RUP, Balanced between agile and traditional, 0), (47, SAFe, Balanced between agile and traditional, 0), (48, Scrum, Balanced between agile and traditional, 1), (49, None, Mostly agile, 0), (50, CRISP-DM, Mostly agile, 0), (51, Kanban, Mostly agile, 1), (52, Lean, Mostly agile, 0), (53, RUP, Mostly agile, 0), (54, SAFe, Mostly agile, 0), (55, Scrum, Mostly agile, 0), (56, None, Totally traditional, 0), (57, CRISP-DM, Totally traditional, 0), (58, Kanban, Totally traditional, 0), (59, Lean, Totally traditional, 0), (60, RUP, Totally traditional, 0), (61, SAFe, Totally traditional, 0), (62, Scrum, Totally traditional, 0), (63, None, Totally traditional, 0), (64, CRISP-DM, Totally traditional, 0), (65, Kanban, Totally traditional, 0), (66, Lean, Totally traditional, 0), (67, RUP, Totally traditional, 0), (68, SAFe, Totally traditional, 0), (69, Scrum, Totally traditional, 0), (70, None, Balanced between agile and traditional, 0), (71, CRISP-DM, Balanced between agile and traditional, 0), (72, Kanban, Balanced between agile and traditional, 0), (73, Lean, Balanced between agile and traditional, 0), (74, RUP, Balanced between agile and traditional, 0), (75, SAFe, Balanced between agile and traditional, 0), (76, Scrum, Balanced between agile and traditional, 1), (77, None, Balanced between agile and traditional, 0), (78, CRISP-DM, Balanced between agile and traditional, 0), (79, Kanban, Balanced between agile and traditional, 1), (80, Lean, Balanced between agile and traditional, 0), (81, RUP, Balanced between agile and traditional, 0), (82, SAFe, Balanced between agile and traditional, 0), (83, Scrum, Balanced between agile and traditional, 1), (84, None, Totally traditional, 0), (85, CRISP-DM, Totally traditi ...
#
# [1932 rows x 0 columns]
