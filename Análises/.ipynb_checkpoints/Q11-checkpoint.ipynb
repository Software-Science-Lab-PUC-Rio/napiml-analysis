# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values
from ipynb.fs.full.plots import single_barplot

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head()
# Out:
#    ID          Status Duration     D1_Undergraduation  \
# 2  31  Completed (31)     1317              Economics
# 3  34  Completed (31)      854                    -99
# 4  36  Completed (31)     1593            Mathmathics
# 5  57  Completed (31)     4238       Computer Science
# 6  46  Completed (31)     2821  Graduation in Actuary
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q12_RE_Most_Difficult_Activity_AligningREData  \
# 2                                    not quoted
# 3                                    not quoted
# 4                                    not quoted
# 5                                    not quoted
# 6                                    not quoted
#
#   Q12_RE_Most_Difficult_Activity_Conflicts   \
# 2                                    quoted
# 3                                not quoted
# 4                                not quoted
# 5                                not quoted
# 6                                not quoted
#
#   Q12_RE_Most_Difficult_Activity_NewQualityAttributes  \
# 2                                         not quoted
# 3                                         not quoted
# 4                                         not quoted
# 5                                             quoted
# 6                                         not quoted
#
#   Q12_RE_Most_Difficult_Activity_Documentation   \
# 2                                    not quoted
# 3                                    not quoted
# 4                                    not quoted
# 5                                        quoted
# 6                                    not quoted
#
#   Q12_RE_Most_Difficult_Activity_SelectingMetrics  \
# 2                                      not quoted
# 3                                      not quoted
# 4                                          quoted
# 5                                      not quoted
# 6                                      not quoted
#
#   Q12_RE_Most_Difficult_Activity_Verification   \
# 2                                   not quoted
# 3                                   not quoted
# 4                                   not quoted
# 5                                   not quoted
# 6                                   not quoted
#
#   Q12_RE_Most_Difficult_Activity_ChangingRE   \
# 2                                 not quoted
# 3                                 not quoted
# 4                                 not quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q12_RE_Most_Difficult_Activity_Customer_Others  \
# 2                                     not quoted
# 3                                     not quoted
# 4                                     not quoted
# 5                                     not quoted
# 6                                     not quoted
#
#   Q12_RE_Most_Difficult_Activity_Customer_Others_Free  \
# 2                                                -99
# 3                                                -99
# 4                                                -99
# 5                                                -99
# 6                                                -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 185 columns]

# %%
df_q11 = df.filter(regex='Q11')
df_q11.head()
# Out:
#   Q11_NFRs_NotConsidered  Q11_NFRs_DataQuality  Q11_NFRs_ModelAccountability   \
# 2                  quoted            not quoted                    not quoted
# 3              not quoted                quoted                    not quoted
# 4              not quoted            not quoted                    not quoted
# 5              not quoted                quoted                    not quoted
# 6              not quoted                quoted                        quoted
#
#   Q11_NFRs_ModelEthicsFairness  Q11_NFRs_ModelExplainability   \
# 2                    not quoted                    not quoted
# 3                        quoted                    not quoted
# 4                    not quoted                        quoted
# 5                    not quoted                        quoted
# 6                        quoted                        quoted
#
#   Q11_NFRs_ModelInteractiveness  Q11_NFRs_ModelReliability  \
# 2                     not quoted                not quoted
# 3                     not quoted                not quoted
# 4                     not quoted                not quoted
# 5                     not quoted                not quoted
# 6                         quoted                    quoted
#
#   Q11_NFRs_ModelTransparency Q11_NFRs_SystemCompatibility  \
# 2                 not quoted                   not quoted
# 3                     quoted                   not quoted
# 4                 not quoted                   not quoted
# 5                 not quoted                   not quoted
# 6                     quoted                   not quoted
#
#   Q11_NFRs_SystemMaintanibility Q11_NFRs_SystemPerformance  \
# 2                    not quoted                 not quoted
# 3                    not quoted                 not quoted
# 4                    not quoted                     quoted
# 5                        quoted                 not quoted
# 6                    not quoted                 not quoted
#
#   Q11_NFRs_SystemPortability Q11_NFRs_SystemPrivacy   \
# 2                 not quoted              not quoted
# 3                 not quoted              not quoted
# 4                 not quoted              not quoted
# 5                 not quoted              not quoted
# 6                 not quoted              not quoted
#
#   Q11_NFRs_SystemReliability  Q11_NFRs_SystemSafety Q11_NFRs_SystemSecurity   \
# 2                  not quoted            not quoted               not quoted
# 3                  not quoted            not quoted               not quoted
# 4                  not quoted            not quoted                   quoted
# 5                      quoted            not quoted               not quoted
# 6                  not quoted            not quoted               not quoted
#
#   Q11_NFRs_SystemUsability Q11_NFRs_Others   \
# 2               not quoted       not quoted
# 3               not quoted       not quoted
# 4               not quoted       not quoted
# 5               not quoted       not quoted
# 6                   quoted       not quoted
#
#   Q11_NFRs_Others_Free
# 2                                    -99
# 3                                    -99
# 4                                    -99
# 5                                    -99
# 6                                    -99

# %%
#Responses as others

df_q11_others = df_q11.filter(regex='Others')
df_q11_others

for c in df_q11_others.columns:
    print(c)
    print(df_q11_others[c].value_counts())
# Out:
# Q11_NFRs_Others
# not quoted    191
# -77            82
# quoted          3
# Name: Q11_NFRs_Others , dtype: int64
# Q11_NFRs_Others_Free
# -99              192
# -66               82
# i am not sure      1
# Name: Q11_NFRs_Others_Free                  , dtype: int64

# %%
# Pandas DataFrame [quoted per columns]

dict_q11 = {}
for c in df_q11.columns:
    if "Free" and "Others" not in c:
        role = c.split('_')
        dict_q11[role[2:][0]] = df_q11[c].value_counts()['quoted']

df_q11_quoted = pd.DataFrame(data={'NFRs': list(dict_q11.keys()), 'Answers': list(dict_q11.values())})
df_q11_quoted = df_q11_quoted.sort_values('Answers', ascending=False)
df_q11_quoted
# Out:
#                      NFRs  Answers
# 1            DataQuality       119
# 6        ModelReliability       73
# 10      SystemPerformance       69
# 4    ModelExplainability        65
# 16        SystemUsability       50
# 9    SystemMaintanibility       36
# 13     SystemReliability        35
# 15        SystemSecurity        32
# 7       ModelTransparency       32
# 8     SystemCompatibility       28
# 2    ModelAccountability        26
# 12         SystemPrivacy        23
# 3    ModelEthicsFairness        22
# 14           SystemSafety       21
# 0          NotConsidered        19
# 5   ModelInteractiveness        15
# 11      SystemPortability       13

# %%
single_barplot(df_q11_quoted, "Answers", "NFRs", 
               title="Q11. Which Non-Functional Requirements (NFRs) do typically play a major role in terms of criticality in ML-enabled system?",
               x_label="Count", y_label="Technique", x_label_rotation=0)
