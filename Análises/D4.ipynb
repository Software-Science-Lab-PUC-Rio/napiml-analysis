# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, remove_value
from ipynb.fs.full.plots import single_barplot

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head(10)
# Out:
#     ID          Status Duration                      D1_Undergraduation  \
# 2   31  Completed (31)     1317                               Economics
# 3   34  Completed (31)      854                                     -99
# 4   36  Completed (31)     1593                             Mathematics
# 5   57  Completed (31)     4238                        Computer Science
# 6   46  Completed (31)     2821                       Actuarial Science
# 7   53  Completed (31)     2097                      Information System
# 8   58  Completed (31)     1696                        Computer Science
# 9   64  Completed (31)     1250  Electrical and Electronics Engineering
# 10  65  Completed (31)      106                                     -99
# 11  69  Completed (31)       79                                     -99
#
#                   D1_Specialization                             D1_Master  \
# 2                               -99                    M.Sc. in Economics
# 3                       Management                                     No
# 4                       Informatics                  MSC Computer Science
# 5       Data science specialization                                   -99
# 6   Post Graduation in Data Science       M Sc in Data Science -ML models
# 7                               -99          M.Sc. in Applied Informatics
# 8                               -99                      Computer Science
# 9                               -99  M.Sc. in AI and Software Engineering
# 10                              -99                                   -99
# 11                              -99                                   -99
#
#                   D1_Phd                                         D1_Courses  \
# 2                    -99                         Data Scientist in Datacamp
# 3                     No                                                 No
# 4   PhD computer Science                          Vários cursos in Coursera
# 5                    -99                                                -99
# 6                no Ph D                            no other certifications
# 7                    -99                                                -99
# 8                    -99  Microsoft Professional Program Data Science & ...
# 9       Computer science  Azure Associate AI Engineer, Azure Data Scienc...
# 10                   -99                                                -99
# 11                   -99                                                -99
#
#    D1_Others D2_Country  ... Q12_RE_Most_Difficult_Activity_AligningREData  \
# 2        -99     Brazil  ...                                    not quoted
# 3         No     Brazil  ...                                    not quoted
# 4        -99     Brazil  ...                                    not quoted
# 5        -99    Germany  ...                                    not quoted
# 6        -99     Brazil  ...                                    not quoted
# 7        -99     Brazil  ...                                        quoted
# 8        -99    Germany  ...                                        quoted
# 9        -99     Sweden  ...                                        quoted
# 10       -99          0  ...                                    not quoted
# 11       -99          0  ...                                    not quoted
#
#    Q12_RE_Most_Difficult_Activity_Conflicts   \
# 2                                     quoted
# 3                                 not quoted
# 4                                 not quoted
# 5                                 not quoted
# 6                                 not quoted
# 7                                 not quoted
# 8                                     quoted
# 9                                     quoted
# 10                                not quoted
# 11                                not quoted
#
#    Q12_RE_Most_Difficult_Activity_NewQualityAttributes  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                              quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                              quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Documentation   \
# 2                                     not quoted
# 3                                     not quoted
# 4                                     not quoted
# 5                                         quoted
# 6                                     not quoted
# 7                                     not quoted
# 8                                     not quoted
# 9                                     not quoted
# 10                                    not quoted
# 11                                    not quoted
#
#    Q12_RE_Most_Difficult_Activity_SelectingMetrics  \
# 2                                       not quoted
# 3                                       not quoted
# 4                                           quoted
# 5                                       not quoted
# 6                                       not quoted
# 7                                       not quoted
# 8                                       not quoted
# 9                                           quoted
# 10                                      not quoted
# 11                                      not quoted
#
#    Q12_RE_Most_Difficult_Activity_Verification   \
# 2                                    not quoted
# 3                                    not quoted
# 4                                    not quoted
# 5                                    not quoted
# 6                                    not quoted
# 7                                    not quoted
# 8                                    not quoted
# 9                                        quoted
# 10                                   not quoted
# 11                                   not quoted
#
#    Q12_RE_Most_Difficult_Activity_ChangingRE   \
# 2                                  not quoted
# 3                                  not quoted
# 4                                  not quoted
# 5                                  not quoted
# 6                                  not quoted
# 7                                      quoted
# 8                                  not quoted
# 9                                      quoted
# 10                                 not quoted
# 11                                 not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Others  \
# 2                                      not quoted
# 3                                      not quoted
# 4                                      not quoted
# 5                                      not quoted
# 6                                      not quoted
# 7                                      not quoted
# 8                                      not quoted
# 9                                      not quoted
# 10                                     not quoted
# 11                                     not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Others_Free  \
# 2                                                 -99
# 3                                                 -99
# 4                                                 -99
# 5                                                 -99
# 6                                                 -99
# 7                                                 -99
# 8                                                 -99
# 9                                                 -99
# 10                                                -99
# 11                                                -99
#
#                              Origin
# 2   https://ww2.unipark.de/uc/seml/
# 3                               -99
# 4                               -99
# 5                               -99
# 6                               -99
# 7                               -99
# 8                     https://t.co/
# 9         https://www.linkedin.com/
# 10                              -99
# 11  https://ww2.unipark.de/uc/seml/
#
# [10 rows x 185 columns]

# %%
# mapping of old labels to new one
d4_rename_mapping = {
    'Project Lead / Project Manager': 'Project Lead / Project Manager',
    'Business Analyst': 'Business Analyst',
    'Requirements Engineer': 'Requirements Engineer',
    'Solution Architect': 'Solution Architect',
    'Data Scientist': 'Data Scientist',
    'Developer': 'Developer',
    'Test Manager / Tester': 'Test Manager / Tester',
    'Other, which one?': 'Other'
}

# %%
remove_value(df,'0','D4_Role')
# index of our barplot
indexes = list(df['D4_Role'].value_counts().index)
# total answers of each index
values = list(df['D4_Role'].value_counts())
# dataframe specific for question D4
d4_df= pd.DataFrame(data={'Main Role': rename_values(d4_rename_mapping, indexes), 'Answers': values})

# %%
#drop all rows that have 'Other, which one?' selected - it will be displayed in other view
d4_df = d4_df[d4_df['Main Role'] != 'Other']

# %%
single_barplot(d4_df, "Answers", "Main Role", title="Which role best describes your current activities within the company?",
               x_label="Answers", y_label="Role")
