# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values
from ipynb.fs.full.plots import single_barplot

# %%
df = get_df()

# %%
print(df)
# Out:
#       ID          Status Duration D1_Undergraduation  \
# 2     31  Completed (31)     1317          Economics
# 3     34  Completed (31)      854                -99
# 4     36  Completed (31)     1593        Mathematics
# 5     57  Completed (31)     4238   Computer Science
# 6     46  Completed (31)     2821  Actuarial Science
# ..   ...             ...      ...                ...
# 273  458  Suspended (22)        0   Computer Science
# 274  499  Suspended (22)        0   Computer Science
# 275  500  Suspended (22)        0   Computer Science
# 276  518  Suspended (22)        0   Computer Science
# 277  522  Suspended (22)       35                -99
#
#                    D1_Specialization                        D1_Master  \
# 2                                -99               M.Sc. in Economics
# 3                        Management                                No
# 4                        Informatics             MSC Computer Science
# ...

# %%
df[['Q13','Q13_1']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df[['Q13','Q13_1']]
#
# File ~\.virtualenvs\napiml-analysis-3t_E8WS-\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.virtualenvs\napiml-analysis-3t_E8WS-\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
# ...
