# %% [markdown]
# # Question Q4: Practitioners Main Problems on Model Deployment Stage

# %% [markdown]
# *Question*: According to your personal experience, please outline the main problems or difficulties (up to three) faced during each of the seven ML life cycle stages.

# %% [markdown]
# *Answer Type*: Text Free

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Initialization
#
# Here we get a formatted Pandas DataFrame from a raw CSV containing the Survey responses. When formatting, we discard unused columns and renames existing ones to more clear names. We created two classes that help us manage this dataframe and create meaningful charts.

# %%
dataframe_obj = DataframeUtils(df_path='./data/main_data.csv', sep=';',
                               to_discard_columns_file='./data/unused_columns.txt',
                               to_format_columns_file='./data/formatted_columns.txt')
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# In this research, we conservatively considered those who fully completed the survey. So, we discarded suspended submissions.

# %%
dataframe_obj.df.drop(dataframe_obj.df[dataframe_obj.df['Status'] == 'Suspended (22)'].index, inplace = True)

# %%
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Grounded Theory
#
# Here we get a formatted Pandas DataFrame from an Excel file containing the codes and categorization of our qualitative responses.

# %%
qualitative_df = pd.read_excel('./data/Problems on ML Stages/MODEL DEPLOYMENT.xlsx')
qualitative_df.head()
# Out:
#    lfdn                 MODEL DEPLOYMENT  \
# 0    31  Show the model in a didatic way
# 1    36   Prepare production environment
# 2    46   what kind of deploy is better?
# 3    53        Not knowing how to deploy
# 4    58                             Cost
#
#                                      TOPIC        CATEGORY
# 0  MODEL INTERPRETATION AND EXPLAINABILITY   COMMUNICATION
# 1       PRODUCTION INFRASTRUCTURE (DEPLOY)  INFRASTRUCTURE
# 2       PRODUCTION INFRASTRUCTURE (DEPLOY)  INFRASTRUCTURE
# 3       PRODUCTION INFRASTRUCTURE (DEPLOY)  INFRASTRUCTURE
# 4                         FINANCIAL ISSUES    ORGANIZATION

# %% [markdown]
# ### Basic Analysis

# %%
# get our valid respondents ids
respondents_ids = list(dataframe_obj.df['ID'])
respondents_ids = [int(respondent_id) for respondent_id in respondents_ids]
respondents_ids[:5]
# Out:
# [31, 34, 36, 57, 46]

# %%
# get our valid respondents ids
respondents_ids = list(dataframe_obj.df['ID'])
respondents_ids = [int(respondent_id) for respondent_id in respondents_ids]
respondents_ids[:5]
# Out:
# [31, 34, 36, 57, 46]

# %%
# discard the ids that are suspended
qualitative_df = qualitative_df[qualitative_df['lfdn'].isin(respondents_ids)][['MODEL DEPLOYMENT', 'TOPIC', 'CATEGORY']]

# %%
# get a list with all the reported categories
category_column = list(qualitative_df['CATEGORY'])
category_column[:5]
# Out:
# ['COMMUNICATION',
#  'INFRASTRUCTURE',
#  'INFRASTRUCTURE',
#  'INFRASTRUCTURE',
#  'ORGANIZATION']

# %%
# compute the total of answers that belong to each category
total_per_category_df = qualitative_df[['CATEGORY', 'TOPIC']].groupby(['CATEGORY']).count()
total_per_category_df
# Out:
#                 TOPIC
# CATEGORY
# COMMUNICATION       3
# DATA                2
# INFRASTRUCTURE     84
# METHOD             25
# ORGANIZATION       15
# PEOPLE              6
# PLANNING            3

# %%
# get the total of qualitative answers
total_answers = total_per_category_df['TOPIC'].sum()
print(f'The total of qualitative answers to be considered is {total_answers}')
# Out:
# The total of qualitative answers to be considered is 138

# %%
# we create two lists that contain, for each category, the total of qualitative answers and their percentage
category_percentage = []
category_total = []
# note that we will have repeated values, once we are creating lists with the same length of the column 'CATEGORY' in the qualitative dataframe
for category in category_column:
    category_percentage.append(round(total_per_category_df.loc[category]['TOPIC'] / total_answers * 100, 2))
    category_total.append(total_per_category_df.loc[category]['TOPIC'])

# %%
# include two new columns to our qualitative dataframe
qualitative_df['CATEGORY_TOTAL'] = category_total
qualitative_df['CATEGORY_%'] = category_percentage
qualitative_df.head()
# Out:
#                   MODEL DEPLOYMENT                                    TOPIC  \
# 0  Show the model in a didatic way  MODEL INTERPRETATION AND EXPLAINABILITY
# 1   Prepare production environment       PRODUCTION INFRASTRUCTURE (DEPLOY)
# 2   what kind of deploy is better?       PRODUCTION INFRASTRUCTURE (DEPLOY)
# 3        Not knowing how to deploy       PRODUCTION INFRASTRUCTURE (DEPLOY)
# 4                             Cost                         FINANCIAL ISSUES
#
#          CATEGORY  CATEGORY_TOTAL  CATEGORY_%
# 0   COMMUNICATION               3        2.17
# 1  INFRASTRUCTURE              84       60.87
# 2  INFRASTRUCTURE              84       60.87
# 3  INFRASTRUCTURE              84       60.87
# 4    ORGANIZATION              15       10.87

# %%
# now we group our results considering the category and the topic
qualitative_df = qualitative_df.groupby(['CATEGORY', 'CATEGORY_TOTAL', 'CATEGORY_%', 'TOPIC']).count()

# %%
# rename the remaining column, which is now a simple count representing the quantity of each category and topic
qualitative_df.columns = ['QUANTITY']
# add the percentage version of each quantity to improve readability
qualitative_df['QUANTITY_%'] = round(qualitative_df['QUANTITY'] / qualitative_df['QUANTITY'].sum() * 100, 2)
qualitative_df
# Out:
#                                                                                   QUANTITY  \
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# COMMUNICATION  3              2.17       MODEL INTERPRETATION AND EXPLAINABILITY         3
# DATA           2              1.45       DATA UNAVAILABLE                                1
#                                          INSUFFICIENT DATA                               1
# INFRASTRUCTURE 84             60.87      COMPUTATIONAL CONSTRAINTS                       3
#                                          HARD TO INTEGRATE WITH OLD APPLICATIONS        10
#                                          INFRASTRUCTURE                                  6
#                                          MODEL MONITORING                                1
#                                          MODEL UPDATE                                    3
#                                          PRODUCTION INFRASTRUCTURE (DEPLOY)             59
#                                          UPDATING THE LIBRARIES USED                     1
#                                          VERSION CONTROL                                 1
# METHOD         25             18.12      API USE                                         3
#                                          CLIENT VALIDATION                               1
#                                          COMPLEX UI                                      2
#                                          CREATE ROBUST APIS                              1
#                                          FEATURE SELECTION                               1
#                                          MEET REGULATORY REQUIREMENTS                    1
#                                          METRICS                                         1
#                                          PERFORMANCE ISSUES                              4
#                                          PROGRAMMING LANGUAGE                            1
#                                          SCALABILITY                                     9
#                                          SOFTWARE ENGINEERING BEST PRACTICES             1
# ORGANIZATION   15             10.87      COMMUNICATION ISSUES AMONG THE TEAM             2
#                                          DATA ENGINEER UNAVAILABLE                       2
#                                          FINANCIAL ISSUES                                6
#                                          LACK OF DOCUMENTATION                           1
#                                          LACK OF PRIORIZATION                            2
#                                          RESOURCES                                       2
# PEOPLE         6              4.35       LACK OF DATA SCIENCE KNOWLEDGE                  2
#                                          LACK OF KNOWLEDGE                               3
#                                          USER ACCEPTANCE                                 1
# PLANNING       3              2.17       LACK OF TIME                                    3
#
#                                                                                   QUANTITY_%
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# COMMUNICATION  3              2.17       MODEL INTERPRETATION AND EXPLAINABILITY        2.17
# DATA           2              1.45       DATA UNAVAILABLE                               0.72
#                                          INSUFFICIENT DATA                              0.72
# INFRASTRUCTURE 84             60.87      COMPUTATIONAL CONSTRAINTS                      2.17
#                                          HARD TO INTEGRATE WITH OLD APPLICATIONS        7.25
#                                          INFRASTRUCTURE                                 4.35
#                                          MODEL MONITORING                               0.72
#                                          MODEL UPDATE                                   2.17
#                                          PRODUCTION INFRASTRUCTURE (DEPLOY)            42.75
#                                          UPDATING THE LIBRARIES USED                    0.72
#                                          VERSION CONTROL                                0.72
# METHOD         25             18.12      API USE                                        2.17
#                                          CLIENT VALIDATION                              0.72
#                                          COMPLEX UI                                     1.45
#                                          CREATE ROBUST APIS                             0.72
#                                          FEATURE SELECTION                              0.72
#                                          MEET REGULATORY REQUIREMENTS                   0.72
#                                          METRICS                                        0.72
#                                          PERFORMANCE ISSUES                             2.90
#                                          PROGRAMMING LANGUAGE                           0.72
#                                          SCALABILITY                                    6.52
#                                          SOFTWARE ENGINEERING BEST PRACTICES            0.72
# ORGANIZATION   15             10.87      COMMUNICATION ISSUES AMONG THE TEAM            1.45
#                                          DATA ENGINEER UNAVAILABLE                      1.45
#                                          FINANCIAL ISSUES                               4.35
#                                          LACK OF DOCUMENTATION                          0.72
#                                          LACK OF PRIORIZATION                           1.45
#                                          RESOURCES                                      1.45
# PEOPLE         6              4.35       LACK OF DATA SCIENCE KNOWLEDGE                 1.45
#                                          LACK OF KNOWLEDGE                              2.17
#                                          USER ACCEPTANCE                                0.72
# PLANNING       3              2.17       LACK OF TIME                                   2.17
