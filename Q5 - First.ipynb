# %% [markdown]
# # First Problems that most likely lead to Project Failure

# %% [markdown]
# *Question*: Regarding the problems listed in previous question,
# please rank the ones (up to three) that most likely lead o
# overall project failur.

# %% [markdown]
# *Answer Type*: Text Free

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Initialization
#
# Here we get a formatted Pandas DataFrame from a raw CSV containing the Survey responses. When formatting, we discard unused columns and renames existing ones to more clear names. We created two classes that help us manage this dataframe and create meaningful charts.

# %%
dataframe_obj = DataframeUtils(df_path='./data/main_data.csv', sep=';',
                               to_discard_columns_file='./data/unused_columns.txt',
                               to_format_columns_file='./data/formatted_columns.txt')
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %%
# For PROFES, we discarded suspended submissions (e.g., remove those who didn't complete the survey).
dataframe_obj.df.drop(dataframe_obj.df[dataframe_obj.df['Status'] == 'Suspended (22)'].index, inplace = True)

# %%
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Grounded Theory
#
# Here we get a formatted Pandas DataFrame from an Excel file containing the codes and categorization of our qualitative responses.

# %%
qualitative_df = pd.read_excel('./data/Problems on ML Stages/PROJECT FAILURE - FIRST.xlsx')
qualitative_df.head()
# Out:
#    lfdn                                         Q5 - FIRST  \
# 0    31         Problems with data collection and cleaning
# 1    36                                   Data preparation
# 2    46  understand the pain and identify if ML is real...
# 3    53                        insufficient amount of data
# 4    58                                   DATA UNAVAILABLE
#
#                    TOPIC CATEGORY
# 0       DATA PREPARATION     DATA
# 1       DATA PREPARATION     DATA
# 2  PROBLEM UNDERSTANDING    INPUT
# 3      INSUFFICIENT DATA     DATA
# 4      DATA AVAILABILITY     DATA

# %% [markdown]
# ### Basic Analysis

# %%
# get our respondents ids
respondents_ids = list(dataframe_obj.df['ID'])
respondents_ids = [int(respondent_id) for respondent_id in respondents_ids]
respondents_ids[:5]
# Out:
# [31, 34, 36, 57, 46]

# %%
# discard the ids
qualitative_df = qualitative_df[qualitative_df['lfdn'].isin(respondents_ids)][['Q5 - FIRST', 'TOPIC', 'CATEGORY']]

# %%
# get a list with all the reported categories
category_column = list(qualitative_df['CATEGORY'])
category_column[:5]
# Out:
# ['DATA', 'DATA', 'INPUT', 'DATA', 'DATA']

# %%
# compute the total of answers that belong to each category
total_per_category_df = qualitative_df[['CATEGORY', 'TOPIC']].groupby(['CATEGORY']).count()
total_per_category_df
# Out:
#                 TOPIC
# CATEGORY
# DATA               46
# INFRASTRUCTURE      2
# INPUT              52
# METHOD             29
# ORGANIZATION        8
# PEOPLE              2

# %%
# get the total of qualitative answers
total_answers = total_per_category_df['TOPIC'].sum()
print(f'The total of qualitative answers to be considered is {total_answers}')
# Out:
# The total of qualitative answers to be considered is 139

# %%
# we create two lists that contain, for each category, the total of qualitative answers and their percentage
category_percentage = []
category_total = []
# note that we will have repeated values, once we are creating lists with the same length of the column 'CATEGORY' in the qualitative dataframe
for category in category_column:
    category_percentage.append(round(total_per_category_df.loc[category]['TOPIC'] / total_answers * 100, 2))
    category_total.append(total_per_category_df.loc[category]['TOPIC'])

# %%
# include two new columns to our qualitative dataframe
qualitative_df['CATEGORY_TOTAL'] = category_total
qualitative_df['CATEGORY_%'] = category_percentage
qualitative_df.head()
# Out:
#                                           Q5 - FIRST                  TOPIC  \
# 0         Problems with data collection and cleaning       DATA PREPARATION
# 1                                   Data preparation       DATA PREPARATION
# 2  understand the pain and identify if ML is real...  PROBLEM UNDERSTANDING
# 3                        insufficient amount of data      INSUFFICIENT DATA
# 4                                   DATA UNAVAILABLE      DATA AVAILABILITY
#
#   CATEGORY  CATEGORY_TOTAL  CATEGORY_%
# 0     DATA              46       33.09
# 1     DATA              46       33.09
# 2    INPUT              52       37.41
# 3     DATA              46       33.09
# 4     DATA              46       33.09

# %%
# now we group our results considering the category and the topic
qualitative_df = qualitative_df.groupby(['CATEGORY', 'CATEGORY_TOTAL', 'CATEGORY_%', 'TOPIC']).count()

# %%
# rename the remaining column, which is now a simple count representing the quantity of each category and topic
qualitative_df.columns = ['QUANTITY']
# add the percentage version of each quantity to improve readability
qualitative_df['QUANTITY_%'] = round(qualitative_df['QUANTITY'] / qualitative_df['QUANTITY'].sum() * 100, 2)
qualitative_df
# Out:
#                                                                                            QUANTITY  \
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           46             33.09      DATA AVAILABILITY                                        6
#                                          DATA CLEANING                                            1
#                                          DATA COLLECTION                                          9
#                                          DATA COMPLEXITY                                          1
#                                          DATA PREPARATION                                         7
#                                          DATA QUALITY                                            12
#                                          DATA UNDERSTANDING                                       1
#                                          INSUFFICIENT DATA                                        9
# INFRASTRUCTURE 2              1.44       COMPUTATIONAL CONSTRAINTS                                2
# INPUT          52             37.41      BUSINESS/DOMAIN UNDERSTANDING                            1
#                                          GATHERING REQUIREMENTS                                   2
#                                          INCOMPLETE/INCORRECT REQUIREMENTS                        9
#                                          LACK OF DOMAIN KNOWLEDGE                                 8
#                                          PROBLEM UNDERSTANDING                                   31
#                                          SCOPE DEFINITION                                         1
# METHOD         29             20.86      ALGORITHMS SELECTION                                     2
#                                          CHOOSE AND EVALUATE THE METRICS                          5
#                                          COMMUNICATION                                            2
#                                          IMPROVING THE MODEL                                      1
#                                          INSUFFICIENT/UNACCEPTABLE RESULTS                        1
#                                          MANAGING EXPECTATIONS                                   10
#                                          MODEL CREATION                                           1
#                                          MODEL DEPLOYMENT                                         1
#                                          MODEL EVALUATION                                         1
#                                          MODEL MONITORING                                         1
#                                          QUALITY ASSURANCE                                        1
#                                          SOLUTIONS UNIQUENESS                                     1
#                                          TIME CONSUMING                                           2
# ORGANIZATION   8              5.76       CONTRACT NEGOTIATION                                     1
#                                          LACK OF RESOURCES FOR MONITORING                         1
#                                          LACK OF TIME                                             2
#                                          LOW CLIENT/DOMAIN EXPERT AVAILABILITY/ENGAGEMENT         3
#                                          MANAGEMENT ENGAGEMENT                                    1
# PEOPLE         2              1.44       LACK OF MODEL DEPLOYMENT KNOW HOW                        1
#                                          LACK OF TALENT/SKILL                                     1
#
#                                                                                            QUANTITY_%
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           46             33.09      DATA AVAILABILITY                                       4.32
#                                          DATA CLEANING                                           0.72
#                                          DATA COLLECTION                                         6.47
#                                          DATA COMPLEXITY                                         0.72
#                                          DATA PREPARATION                                        5.04
#                                          DATA QUALITY                                            8.63
#                                          DATA UNDERSTANDING                                      0.72
#                                          INSUFFICIENT DATA                                       6.47
# INFRASTRUCTURE 2              1.44       COMPUTATIONAL CONSTRAINTS                               1.44
# INPUT          52             37.41      BUSINESS/DOMAIN UNDERSTANDING                           0.72
#                                          GATHERING REQUIREMENTS                                  1.44
#                                          INCOMPLETE/INCORRECT REQUIREMENTS                       6.47
#                                          LACK OF DOMAIN KNOWLEDGE                                5.76
#                                          PROBLEM UNDERSTANDING                                  22.30
#                                          SCOPE DEFINITION                                        0.72
# METHOD         29             20.86      ALGORITHMS SELECTION                                    1.44
#                                          CHOOSE AND EVALUATE THE METRICS                         3.60
#                                          COMMUNICATION                                           1.44
#                                          IMPROVING THE MODEL                                     0.72
#                                          INSUFFICIENT/UNACCEPTABLE RESULTS                       0.72
#                                          MANAGING EXPECTATIONS                                   7.19
#                                          MODEL CREATION                                          0.72
#                                          MODEL DEPLOYMENT                                        0.72
#                                          MODEL EVALUATION                                        0.72
#                                          MODEL MONITORING                                        0.72
#                                          QUALITY ASSURANCE                                       0.72
#                                          SOLUTIONS UNIQUENESS                                    0.72
#                                          TIME CONSUMING                                          1.44
# ORGANIZATION   8              5.76       CONTRACT NEGOTIATION                                    0.72
#                                          LACK OF RESOURCES FOR MONITORING                        0.72
#                                          LACK OF TIME                                            1.44
#                                          LOW CLIENT/DOMAIN EXPERT AVAILABILITY/ENGAGEMENT        2.16
#                                          MANAGEMENT ENGAGEMENT                                   0.72
# PEOPLE         2              1.44       LACK OF MODEL DEPLOYMENT KNOW HOW                       0.72
#                                          LACK OF TALENT/SKILL                                    0.72

# %%
df = qualitative_df['QUANTITY_%'].copy()
df.index = qualitative_df.index.get_level_values('TOPIC')
for key, val in zip(list(df.keys()), list(df)):
    print(f"{key.lower()} ({val} %)")
# Out:
# data availability (4.32 %)
# data cleaning (0.72 %)
# data collection (6.47 %)
# data complexity (0.72 %)
# data preparation (5.04 %)
# data quality (8.63 %)
# data understanding (0.72 %)
# insufficient data (6.47 %)
# computational constraints (1.44 %)
# business/domain understanding (0.72 %)
# gathering requirements (1.44 %)
# incomplete/incorrect requirements (6.47 %)
# lack of domain knowledge (5.76 %)
# problem understanding (22.3 %)
# scope definition (0.72 %)
# algorithms selection (1.44 %)
# choose and evaluate the metrics (3.6 %)
# communication (1.44 %)
# improving the model (0.72 %)
# insufficient/unacceptable results  (0.72 %)
# managing expectations (7.19 %)
# model creation (0.72 %)
# model deployment (0.72 %)
# model evaluation (0.72 %)
# model monitoring (0.72 %)
# quality assurance (0.72 %)
# solutions uniqueness (0.72 %)
# time consuming (1.44 %)
# contract negotiation (0.72 %)
# lack of resources for monitoring (0.72 %)
# lack of time (1.44 %)
# low client/domain expert availability/engagement (2.16 %)
# management engagement (0.72 %)
# lack of model deployment know how (0.72 %)
# lack of talent/skill (0.72 %)
