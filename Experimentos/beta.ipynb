# %%
# importing important libs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# set a grid for all seaborn plots
sns.set_theme(style="whitegrid")

# %%
# print all columns - same name as in csv file
def list_columns(df):
    for column in list(df.columns):
        print(column)

# %%
# remove a list of columns
def remove_columns(df, columns):
    df = df.drop(columns=columns)
    return df

# %%
# remove rows by index
def remove_rows(df, indexes):
    df = df.drop(indexes)
    return df

# %%
def format_df(df):
    unnecessary_columns = ['Q13. In the context of the ML-enabled system projects you participated in, which approach is typically used to deploy ML models?',
                           'Q13. In the context of the ML-enabled system projects you participated in, which approach is typically used to deploy ML models?.1',
                           'Q13. In the context of the ML-enabled system projects you participated in, which approach is typically used to deploy ML models?.2',
                           'Q13. In the context of the ML-enabled system projects you participated in, which approach is typically used to deploy ML models?.3',
                           'Q13. In the context of the ML-enabled system projects you participated in, which approach is typically used to deploy ML models?.4',
                           'Q14. Do you/your organization follow the practice and principles of ML-Ops in ML-enabled system projects? For instance, do you have an automated pipeline to retrain and deploy your ML models?',
                           'Q14. Do you/your organization follow the practice and principles of ML-Ops in ML-enabled system projects? For instance, do you have an automated pipeline to retrain and deploy your ML models?.1',
                           'Q14. Do you/your organization follow the practice and principles of ML-Ops in ML-enabled system projects? For instance, do you have an automated pipeline to retrain and deploy your ML models?.2',
                           'Q15. Based on your experience, what percentage of the ML-enabled system projects that get deployed into production have their ML models actually being monitored?',
                           'Q16. Which of the following ML model aspects are monitored for the deployed ML-enabled system projects you have worked on?',
                           'Q16. Which of the following ML model aspects are monitored for the deployed ML-enabled system projects you have worked on?.1',
                           'Q16. Which of the following ML model aspects are monitored for the deployed ML-enabled system projects you have worked on?.2',
                           'Q16. Which of the following ML model aspects are monitored for the deployed ML-enabled system projects you have worked on?.3',
                           'Q16. Which of the following ML model aspects are monitored for the deployed ML-enabled system projects you have worked on?.4',
                           'Q16. Which of the following ML model aspects are monitored for the deployed ML-enabled system projects you have worked on?.5',
                           'Q17. Do you use Automated Machine Learning (AutoML) tools (e.g., AutoWEKA, Auto-sklearn, Auto-PyTorch), in your ML-enabled system projects?',
                           'Q17. Do you use Automated Machine Learning (AutoML) tools (e.g., AutoWEKA, Auto-sklearn, Auto-PyTorch), in your ML-enabled system projects?.1',
                           'In case you would like to be notified about the results, please fill in your email address.',
                           'Unnamed: 206', 'Unnamed: 208', 'Unnamed: 209', 'Unnamed: 210', 'Unnamed: 211', 'Unnamed: 212', 'Unnamed: 213', 'Unnamed: 214', 
                           'Unnamed: 215', 'Unnamed: 216', 'Unnamed: 217', 'Unnamed: 218', 'Unnamed: 219', 'Unnamed: 220', 'Unnamed: 221', 'Unnamed: 222',
                           'Unnamed: 223', 'Unnamed: 224', 'Unnamed: 225', 'Unnamed: 226', 'Unnamed: 227', 'Unnamed: 228', 'Unnamed: 1', 'Unnamed: 2',
                           'Unnamed: 4', 'Unnamed: 5']

    # drop all the columns which are not useful for us
    df = remove_columns(df, unnecessary_columns)
    # remove the first two rows - unnecessary data describing the columns
    df = remove_rows(df, [0, 1])
    # rename columns
    df.columns = ['ID', 'Status', 'Duration', 'D1_Undergraduation', 'D1_Specialization', 'D1_Master', 'D1_Phd', 'D1_Courses',
                  'Q8_Who_is_AdressingRE_Tester', 'Q8_Who_is_AdressingRE_Others', 'Q8_Who_is_AdressingRE_Others_Free',
                  
                  'Q9_RE_Elicitation_Interviews', 'Q9_RE_Elicitation_Scenarios', 'Q9_RE_Elicitation_Prototyping', 'Q9_RE_Elicitation_WorkshopsMeetings', 
                  'Q9_RE_Elicitation_Observation', 'Q9_RE_Elicitation_Others', 'Q9_RE_Elicitation_Others_Free', 
                  
                  'Q10_RE_Documentation_NotDocumented', 'Q10_RE_Documentation_VisionDocument', 'Q10_RE_Documentation_RequirementsLists', 
                  'Q10_RE_Documentation_GoalModels', 'Q10_RE_Documentation_UseCaseModels', 'Q10_RE_Documentation_Prototypes', 'Q10_RE_Documentation_UserStories',
                  'Q10_RE_Documentation_BDDScenarios', 'Q10_RE_Documentation_MLCanvas', 'Q10_RE_Documentation_Notebooks', 'Q10_RE_Documentation_DataModels',
                  'Q10_RE_Documentation_Others', 'Q10_RE_Documentation_Others_Free',
                  
                  'Q11_NFRs_NotConsidered', 'Q11_NFRs_DataQuality', 'Q11_NFRs_ModelAccountability', 'Q11_NFRs_ModelEthicsFairness', 
                  'Q11_NFRs_ModelExplainability', 'Q11_NFRs_ModelInteractiveness', 'Q11_NFRs_ModelReliability', 'Q11_NFRs_ModelTransparency',
                  'Q11_NFRs_SystemCompatibility', 'Q11_NFRs_SystemMaintanibility', 'Q11_NFRs_SystemPerformance', 'Q11_NFRs_SystemPortability',
                  'Q11_NFRs_SystemPrivacy', 'Q11_NFRs_SystemReliability', 'Q11_NFRs_SystemSafety', 'Q11_NFRs_SystemSecurity', 'Q11_NFRs_SystemUsability',
                  'Q11_NFRs_Others', 'Q11_NFRs_Others_Free',
                  
                  'Q12_RE_Most_Difficult_Activity_CustomerExpectactions', 'Q12_RE_Most_Difficult_Activity_ElicitingAnalyzing', 
                  'Q12_RE_Most_Difficult_Activity_AligningREData', 'Q12_RE_Most_Difficult_Activity_Conflicts', 
                  'Q12_RE_Most_Difficult_Activity_NewQualityAttributes', 'Q12_RE_Most_Difficult_Activity_Documentation', 
                  'Q12_RE_Most_Difficult_Activity_SelectingMetrics', 'Q12_RE_Most_Difficult_Activity_Verification', 
                  'Q12_RE_Most_Difficult_Activity_ChangingRE', 'Q12_RE_Most_Difficult_Activity_Customer_Others', 'Q12_RE_Most_Difficult_Activity_Customer_Others_Free',
                  'Origin']
    
    return df

# %%
# read survey csv
df = pd.read_csv("data_project_851780_2022_05_02.csv", sep=";")

# %%
# format df for a better understanding of columns and data
df = format_df(df)

# %%
df.head(10)
# Out:
#     ID          Status Duration      D1_Undergraduation  \
# 2   31  Completed (31)     1317               Economics
# 3   34  Completed (31)      854                     -99
# 4   36  Completed (31)     1593             Mathmathics
# 5   57  Completed (31)     4238        Computer Science
# 6   46  Completed (31)     2821   Graduation in Actuary
# 7   53  Completed (31)     2097      Information System
# 8   58  Completed (31)     1696        Computer Science
# 9   64  Completed (31)     1250  Electrical engineering
# 10  65  Completed (31)      106                     -99
# 11  69  Completed (31)       79                     -99
#
#                   D1_Specialization                             D1_Master  \
# 2                               -99                    M.Sc. in Economics
# 3                       Management                                     No
# 4                       Informatics                  MSC Computer Science
# 5       Data science specialization                                   -99
# 6   Post Graduation in Data Science       M Sc in Data Science -ML models
# 7                               -99          M.Sc. in Applied Informatics
# 8                               -99                      Computer Science
# 9                               -99  M.Sc. in AI and Software Engineering
# 10                              -99                                   -99
# 11                              -99                                   -99
#
#                   D1_Phd                                         D1_Courses  \
# 2                    -99                         Data Scientist in Datacamp
# 3                     No                                                 No
# 4   PhD computer Science                          Vários cursos in Coursera
# 5                    -99                                                -99
# 6                no Ph D                            no other certifications
# 7                    -99                                                -99
# 8                    -99  Microsoft Professional Program Data Science & ...
# 9       Computer science  Azure Associate AI Engineer, Azure Data Scienc...
# 10                   -99                                                -99
# 11                   -99                                                -99
#
#    D1_Others D2_Country  ...  \
# 2        -99     Brazil  ...
# 3         No     Brazil  ...
# 4        -99     Brazil  ...
# 5        -99    Germany  ...
# 6        -99     Brazil  ...
# 7        -99     Brazil  ...
# 8        -99    Germany  ...
# 9        -99     Sweden  ...
# 10       -99          0  ...
# 11       -99          0  ...
#
#    Q12_RE_Most_Difficult_Activity_Customer_Eliciting_Analyzing  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                              quoted
# 8                                              quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_AligningRE_Data  \
# 2                                              quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                              quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Conflicts  \
# 2                                         not quoted
# 3                                         not quoted
# 4                                         not quoted
# 5                                             quoted
# 6                                         not quoted
# 7                                         not quoted
# 8                                             quoted
# 9                                             quoted
# 10                                        not quoted
# 11                                        not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_New_Quality_Attributes  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                              quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                          not quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Documentation  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                              quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Selecting_Metrics  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Verification  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                              quoted
# 8                                          not quoted
# 9                                              quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Changing_RE  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                          not quoted
# 6                                          not quoted
# 7                                          not quoted
# 8                                          not quoted
# 9                                          not quoted
# 10                                         not quoted
# 11                                         not quoted
#
#    Q12_RE_Most_Difficult_Activity_Customer_Others  \
# 2                                             -99
# 3                                             -99
# 4                                             -99
# 5                                             -99
# 6                                             -99
# 7                                             -99
# 8                                             -99
# 9                                             -99
# 10                                            -99
# 11                                            -99
#
#    Q12_RE_Most_Difficult_Activity_Customer_Others_Free
# 2                     https://ww2.unipark.de/uc/seml/
# 3                                                 -99
# 4                                                 -99
# 5                                                 -99
# 6                                                 -99
# 7                                                 -99
# 8                                       https://t.co/
# 9                           https://www.linkedin.com/
# 10                                                -99
# 11                    https://ww2.unipark.de/uc/seml/
#
# [10 rows x 185 columns]

# %%
def rename_values(rename_mapping, values):
    renamed_values = []
    
    for value in values:
        renamed_values.append(rename_mapping.get(value, 'Not selected'))
    
    return renamed_values

# %%
def single_barplot(df, x_axis, y_axis, title='', x_label='', y_label='', x_label_rotation=0):
    #draw a barplot with single bars
    barplot = sns.catplot(data=df, kind="bar", x=x_axis, y=y_axis, ci="sd", palette="dark", alpha=.5, linewidth=5,
                          height=5, aspect=10/5).set(title=title)
    
    barplot.set_xticklabels(rotation=x_label_rotation)
    barplot.despine(left=True)
    barplot.set_axis_labels(x_label, y_label)

# %%
# mapping of old labels to new one
d3_rename_mapping = {
    '1-10 employees': '1-10',
    '11-50 employees': '11-50',
    '51-250 employees': '51-250',
    '251-500 employees': '251-500',
    '501-1,000 employees': '501-1000',
    '1,001-2,000 employees': '1001-2000',
    'More than 2,000 employees': '+2000'
}
# index of our barplot
indexes = list(df['D3_Company_Size'].value_counts().index)
# total answers of each index
values = list(df['D3_Company_Size'].value_counts())
# dataframe specific for question D3
d3_df= pd.DataFrame(data={'Company Size': rename_values(d3_rename_mapping, indexes), 'Answers': values})

single_barplot(d3_df, "Company Size", "Answers", title="What is the size of the organization you currently work for?",
               x_label="Total of Employees", y_label="Answers", x_label_rotation=45)

# %%
# mapping of old labels to new one
d4_rename_mapping = {
    'Project Lead / Project Manager': 'Project Lead / Project Manager',
    'Business Analyst': 'Business Analyst',
    'Requirements Engineer': 'Requirements Engineer',
    'Solution Architect': 'Solution Architect',
    'Data Scientist': 'Data Scientist',
    'Developer': 'Developer',
    'Test Manager / Tester': 'Test Manager / Tester',
    'Other, which one?': 'Other'
}

# index of our barplot
indexes = list(df['D4_Role'].value_counts().index)
# total answers of each index
values = list(df['D4_Role'].value_counts())
# dataframe specific for question D4
d4_df= pd.DataFrame(data={'Main Role': rename_values(d4_rename_mapping, indexes), 'Answers': values})

#drop all rows that have 'Other, which one?' selected - it will be displayed in other view
d4_df = d4_df[d4_df['Main Role'] != 'Other']

single_barplot(d4_df, "Main Role", "Answers", title="Which role best describes your current activities within the company?",
               x_label="Role", y_label="Answers", x_label_rotation=90)

# %%
# mapping of old labels to new one
d9_rename_mapping = {
    '1-5 members': '1-5',
    '6-10 members': '6-10',
    '11-20 members': '11-20',
    '20-50 members': '20-50',
    '50+ members': '50+'
}
# index of our barplot
indexes = list(df['D9_ML_Project_Team_Size'].value_counts().index)
# total answers of each index
values = list(df['D9_ML_Project_Team_Size'].value_counts())
# dataframe specific for question D9
d9_df= pd.DataFrame(data={'Team Size': rename_values(d9_rename_mapping, indexes), 'Answers': values})

single_barplot(d9_df, "Team Size", "Answers", 
               title="Considering the ML-enabled system projects in which you participated, what is the average team size?",
               x_label="Total of Members", y_label="Answers", x_label_rotation=0)

# %%
def pie_chart(values, labels, title=""):
    #'values' contains percentages of pie - sum must not exceed 100
    # 'values' and 'labels' must have same length

    #define Seaborn color palette to use
    colors = sns.color_palette('pastel')[0:len(values)]

    #create pie chart with matplotlib but use seaborn default color pallete
    plt.pie(values, labels=labels, colors=colors, autopct='%.0f%%')
    plt.title(title)
    plt.show()

# %%
# mapping of old labels to new one
d11_rename_mapping = {
    'Mostly agile': 'Mostly agile',
    'Balanced between agile and traditional': 'Balanced between agile and traditional',
    'Totally traditional': 'Totally traditional',
    'Mostly traditional': 'Mostly traditional',
    'Totally agile': 'Totally agile',
    "I don't know": "I don't know"
}
# labels of our pie chart
labels = list(df['D11_Agile_Development'].value_counts().index)
# total answers of each label
values = list(df['D11_Agile_Development'].value_counts())

# normalize to the sum become 100
sum_values = sum(values)
normalized_values = [(float(v)/sum_values)* 100 for v in values]

pie_chart(normalized_values, rename_values(d11_rename_mapping, labels), 
          title="Considering the ML-enabled system projects in which you participated, how agile do you rate your development?")

# %%
def single_boxplot(df, y_axis, title=''):
    #draw a single boxplot - only y axis
    sns.boxplot(y=y_axis, data=df).set(title=title)
    sns.despine(offset=10, trim=True)

# %%
def single_violinplot(df, y_axis, title=''):
    # draw a single violinplot - only y axis
    # also show a line indicating quartiles
    sns.violinplot(data=df, y=y_axis, inner="quartile", linewidth=1).set(title=title)
    sns.despine(left=True)

# %%
def single_histplot(df, x_axis, title=''):
    # draw a histplot about one variable - only x axis
    sns.histplot(data=df, x=x_axis, kde=True).set(title=title)

# %%
# d5 dataframe not considering the answers with no value
d5_df = pd.DataFrame()
d5_df['Software Experience'] = list(df['D5_Software_Experience'])

# remove those who didn't answered
d5_df = d5_df[d5_df['Software Experience'] != '-99']

# remove one outlier - 255 years is not valid
d5_df = d5_df[d5_df['Software Experience'] != '255']


# convert column to integer - if you read before this line, you will get an string like '14'
d5_df = d5_df.astype({"Software Experience": int}, errors='raise') 

single_boxplot(d5_df, "Software Experience",
               title="How many years of experience do you have in working with the development of software based products?")

# %%
# d6 dataframe not considering the answers with no value
d6_df = pd.DataFrame()
d6_df['ML Experience'] = list(df['D6_ML_Experience'])

# remove those who didn't answered
d6_df = d6_df[d6_df['ML Experience'] != '-99']

# convert column to integer - if you read before this line, you will get an string like '14'
d6_df = d6_df.astype({"ML Experience": int}, errors='raise') 

single_violinplot(d6_df, "ML Experience",
                  title="How many years of experience do you have in developing ML-enabled systems?")

# %%
# d7 dataframe not considering the answers with no value
d7_df = pd.DataFrame()
d7_df['ML Projects'] = list(df['D7_Total_ML_Projects'])

# remove those who didn't answered
d7_df = d7_df[d7_df['ML Projects'] != '-99']

# convert column to integer - if you read before this line, you will get an string like '14'
d7_df = d7_df.astype({"ML Projects": int}, errors='raise') 

single_histplot(d7_df, "ML Projects",
                  title="How many ML-enabled system projects have you participated in?")
