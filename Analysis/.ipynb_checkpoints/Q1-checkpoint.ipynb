# %%
import pandas as pd
from ipynb.fs.full.utils import custom_groupby, get_df, replace_values_by_condition
from ipynb.fs.full.plots import heatmap, likert

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head(10)
# Out:
#     ID          Status Duration                      D1_Undergraduation  \
# 2   31  Completed (31)     1317                               Economics
# 3   34  Completed (31)      854                                     -99
# 4   36  Completed (31)     1593                             Mathematics
# 5   57  Completed (31)     4238                        Computer Science
# 6   46  Completed (31)     2821                       Actuarial Science
# 7   53  Completed (31)     2097                      Information System
# 8   58  Completed (31)     1696                        Computer Science
# 9   64  Completed (31)     1250  Electrical and Electronics Engineering
# 10  65  Completed (31)      106                                     -99
# 11  69  Completed (31)       79                                     -99
#
#                   D1_Specialization                             D1_Master  \
# 2                               -99                    M.Sc. in Economics
# 3                       Management                                     No
# 4                       Informatics                  MSC Computer Science
# 5       Data science specialization                                   -99
# 6   Post Graduation in Data Science       M Sc in Data Science -ML models
# 7                               -99          M.Sc. in Applied Informatics
# 8                               -99                      Computer Science
# 9                               -99  M.Sc. in AI and Software Engineering
# 10                              -99                                   -99
# 11                              -99                                   -99
#
#                   D1_Phd                                         D1_Courses  \
# 2                    -99                         Data Scientist in Datacamp
# 3                     No                                                 No
# 4   PhD computer Science                          Vários cursos in Coursera
# 5                    -99                                                -99
# 6                no Ph D                            no other certifications
# 7                    -99                                                -99
# 8                    -99  Microsoft Professional Program Data Science & ...
# 9       Computer science  Azure Associate AI Engineer, Azure Data Scienc...
# 10                   -99                                                -99
# 11                   -99                                                -99
#
#    D1_Others D2_Country  ... Q15_Model_Deploy_Production_Monitoring  \
# 2        -99     Brazil  ...                                    -77
# 3         No     Brazil  ...                                     70
# 4        -99     Brazil  ...                                     60
# 5        -99    Germany  ...                                    100
# 6        -99     Brazil  ...                                     80
# 7        -99     Brazil  ...                                     30
# 8        -99    Germany  ...                                     10
# 9        -99     Sweden  ...                                      0
# 10       -99          0  ...                                    -77
# 11       -99          0  ...                                    -77
#
#    Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                  not quoted
# 3                                  not quoted
# 4                                      quoted
# 5                                  not quoted
# 6                                  not quoted
# 7                                      quoted
# 8                                      quoted
# 9                                  not quoted
# 10                                 not quoted
# 11                                 not quoted
#
#    Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                         not quoted
# 3                                         not quoted
# 4                                         not quoted
# 5                                             quoted
# 6                                             quoted
# 7                                             quoted
# 8                                         not quoted
# 9                                         not quoted
# 10                                        not quoted
# 11                                        not quoted
#
#    Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                      not quoted
# 3                                          quoted
# 4                                          quoted
# 5                                          quoted
# 6                                          quoted
# 7                                      not quoted
# 8                                      not quoted
# 9                                      not quoted
# 10                                     not quoted
# 11                                     not quoted
#
#    Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                          not quoted                       not quoted
# 3                          not quoted                       not quoted
# 4                          not quoted                       not quoted
# 5                          not quoted                       not quoted
# 6                          not quoted                       not quoted
# 7                          not quoted                       not quoted
# 8                          not quoted                       not quoted
# 9                          not quoted                       not quoted
# 10                         not quoted                       not quoted
# 11                         not quoted                       not quoted
#
#    Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                    -99
# 3                                    -99
# 4                                    -99
# 5                                    -99
# 6                                    -99
# 7                                    -99
# 8                                    -99
# 9                                    -99
# 10                                   -99
# 11                                   -99
#
#    Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                            0
# 3                                           No
# 4                         Yes, Please, specify
# 5                                           No
# 6                                           No
# 7                                           No
# 8                                           No
# 9                                           No
# 10                                           0
# 11                                           0
#
#    Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                            -99
# 3                                            -99
# 4                                   Own approach
# 5                                            -99
# 6                                            -99
# 7                                            -99
# 8                                            -99
# 9                                            -99
# 10                                           -99
# 11                                           -99
#
#                              Origin
# 2   https://ww2.unipark.de/uc/seml/
# 3                               -99
# 4                               -99
# 5                               -99
# 6                               -99
# 7                               -99
# 8                     https://t.co/
# 9         https://www.linkedin.com/
# 10                              -99
# 11  https://ww2.unipark.de/uc/seml/
#
# [10 rows x 202 columns]

# %%
df[['Q1_ML_Life_Cycle_Importance_Problem_Understanding', 'Q1_ML_Life_Cycle_Importance_Data_Collection', 
'Q1_ML_Life_Cycle_Importance_Data_Pre-Processing', 'Q1_ML_Life_Cycle_Importance_Model_Creation',
'Q1_ML_Life_Cycle_Importance_Model_Evaluation', 'Q1_ML_Life_Cycle_Importance_Model_Deployment',
'Q1_ML_Life_Cycle_Importance_Model_Monitoring']].head()
# Out:
#   Q1_ML_Life_Cycle_Importance_Problem_Understanding  \
# 2                                Extremely Relevant
# 3                                    High Relevance
# 4                                Extremely Relevant
# 5                                Extremely Relevant
# 6                                Extremely Relevant
#
#   Q1_ML_Life_Cycle_Importance_Data_Collection  \
# 2                              High Relevance
# 3                              High Relevance
# 4                          Extremely Relevant
# 5                                     Neutral
# 6                          Extremely Relevant
#
#   Q1_ML_Life_Cycle_Importance_Data_Pre-Processing  \
# 2                                  High Relevance
# 3                                  High Relevance
# 4                              Extremely Relevant
# 5                                   Low Relevance
# 6                              Extremely Relevant
#
#   Q1_ML_Life_Cycle_Importance_Model_Creation  \
# 2                             High Relevance
# 3                         Extremely Relevant
# 4                         Extremely Relevant
# 5                                    Neutral
# 6                         Extremely Relevant
#
#   Q1_ML_Life_Cycle_Importance_Model_Evaluation  \
# 2                               High Relevance
# 3                           Extremely Relevant
# 4                           Extremely Relevant
# 5                               High Relevance
# 6                           Extremely Relevant
#
#   Q1_ML_Life_Cycle_Importance_Model_Deployment  \
# 2                               High Relevance
# 3                           Extremely Relevant
# 4                           Extremely Relevant
# 5                           Extremely Relevant
# 6                           Extremely Relevant
#
#   Q1_ML_Life_Cycle_Importance_Model_Monitoring
# 2                                      Neutral
# 3                               High Relevance
# 4                           Extremely Relevant
# 5                                      Neutral
# 6                           Extremely Relevant

# %%
# two unexpected values appear = 0 and -77
# replace them to "I don't know" value

# replacing 0
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Problem_Understanding', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Data_Collection', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Data_Pre-Processing', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Creation', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Evaluation', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Deployment', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Monitoring', "0", "I don't know", "eq")

# replacing -77
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Problem_Understanding', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Data_Collection', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Data_Pre-Processing', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Creation', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Evaluation', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Deployment', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q1_ML_Life_Cycle_Importance_Model_Monitoring', "-77", "I don't know", "eq")

# %%
columns = {
    'Q1_ML_Life_Cycle_Importance_Problem_Understanding': 'Problem Understanding',
    'Q1_ML_Life_Cycle_Importance_Data_Collection': 'Data Collection',
    'Q1_ML_Life_Cycle_Importance_Data_Pre-Processing': 'Data Pre-Processing',
    'Q1_ML_Life_Cycle_Importance_Model_Creation': 'Model Creation',
    'Q1_ML_Life_Cycle_Importance_Model_Evaluation': 'Model Evaluation',
    'Q1_ML_Life_Cycle_Importance_Model_Deployment': 'Model Deployment',
    'Q1_ML_Life_Cycle_Importance_Model_Monitoring': 'Model Monitoring'
}

# values = ["Not Relevant at All", "Low Relevance", "Neutral", "High Relevance", "Extremely Relevant", "I don't know"]
values = ["Not Relevant at All", "Low Relevance", "Neutral", "High Relevance", "Extremely Relevant"]

# it will store the life cycles
life_cycles = []
# it will store the difficulties
difficulties = []
# it will store the total answers of those who answered 'Problem Understanding' and 
# said that is 'Not Relevant at All', 'Low Relevance'... then, 'Data Collection' with 'Not Relevant at All', 'Low Relevance'...
answers = []

# let's compute for each life cycle and difficulty, the total answers
for column in columns:
    for value in values:
        
        life_cycles.append(columns[column])
        difficulties.append(value)
        answers.append(df[column].value_counts().get(value, 0))

# %%
# create a custom dataframe to handle only the columns that we want
q1_df = pd.DataFrame()
q1_df['Life Cycle'] = life_cycles
q1_df['Relevance'] = difficulties
q1_df['Answers'] = answers

# %%
q1_df
# Out:
#                Life Cycle            Relevance  Answers
# 0   Problem Understanding  Not Relevant at All        3
# 1   Problem Understanding        Low Relevance        0
# 2   Problem Understanding              Neutral        6
# 3   Problem Understanding       High Relevance       30
# 4   Problem Understanding   Extremely Relevant      145
# 5         Data Collection  Not Relevant at All        1
# 6         Data Collection        Low Relevance        3
# 7         Data Collection              Neutral       16
# 8         Data Collection       High Relevance       67
# 9         Data Collection   Extremely Relevant       98
# 10    Data Pre-Processing  Not Relevant at All        1
# 11    Data Pre-Processing        Low Relevance        6
# 12    Data Pre-Processing              Neutral       13
# 13    Data Pre-Processing       High Relevance       75
# 14    Data Pre-Processing   Extremely Relevant       88
# 15         Model Creation  Not Relevant at All        1
# 16         Model Creation        Low Relevance        4
# 17         Model Creation              Neutral       30
# 18         Model Creation       High Relevance       81
# 19         Model Creation   Extremely Relevant       70
# 20       Model Evaluation  Not Relevant at All        1
# 21       Model Evaluation        Low Relevance        2
# 22       Model Evaluation              Neutral       15
# 23       Model Evaluation       High Relevance       79
# 24       Model Evaluation   Extremely Relevant       87
# 25       Model Deployment  Not Relevant at All        2
# 26       Model Deployment        Low Relevance        8
# 27       Model Deployment              Neutral       36
# 28       Model Deployment       High Relevance       74
# 29       Model Deployment   Extremely Relevant       61
# 30       Model Monitoring  Not Relevant at All        1
# 31       Model Monitoring        Low Relevance       11
# 32       Model Monitoring              Neutral       28
# 33       Model Monitoring       High Relevance       91
# 34       Model Monitoring   Extremely Relevant       49

# %%
# to use a custom order of columns on heatmap 
# you need to put the index of the columns displayed on this cell in the order you want
# pivot_df = q1_df.pivot('Life Cycle', 'Relevance', 'Answers')
# print(pivot_df.columns)

# %%
heatmap(q1_df, 'Life Cycle', 'Relevance', 'Answers', order=[4, 2, 3, 1, 0], title='How relevant do you think each of the seven ML life cycle stages is with regard to project success?')

# %%
def likert_formatted_df(column, formatted_column, values):
    # for this column, we will plot a likert plot
    
    # it will store the total difficulties for this column, each answer = one row
    difficulties = []

    # let's compute for each life cycle and difficulty, the total answers
    for value in values:
        total_answers_difficulty = df[column].value_counts().get(value, 0)
        for _ in range(total_answers_difficulty):
            difficulties.append(value)
    
    column_likert_df = pd.DataFrame()
    column_likert_df['Difficulty on ' + formatted_column] = difficulties
    
    likert(column_likert_df, values, use_percentage=True, bar_label=True)

# %%
columns = {
        'Q1_ML_Life_Cycle_Importance_Problem_Understanding': 'Problem Understanding',
        'Q1_ML_Life_Cycle_Importance_Data_Collection': 'Data Collection',
        'Q1_ML_Life_Cycle_Importance_Data_Pre-Processing': 'Data Pre-Processing',
        'Q1_ML_Life_Cycle_Importance_Model_Creation': 'Model Creation',
        'Q1_ML_Life_Cycle_Importance_Model_Evaluation': 'Model Evaluation',
        'Q1_ML_Life_Cycle_Importance_Model_Deployment': 'Model Deployment',
        'Q1_ML_Life_Cycle_Importance_Model_Monitoring': 'Model Monitoring'
    }
values = ["Not Relevant at All", "Low Relevance", "Neutral", "High Relevance", "Extremely Relevant"]
for column in columns:
    likert_formatted_df(column, columns[column], values)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
q1_df
# Out:
#                Life Cycle            Relevance  Answers
# 0   Problem Understanding  Not Relevant at All        3
# 1   Problem Understanding        Low Relevance        0
# 2   Problem Understanding              Neutral        6
# 3   Problem Understanding       High Relevance       30
# 4   Problem Understanding   Extremely Relevant      145
# 5         Data Collection  Not Relevant at All        1
# 6         Data Collection        Low Relevance        3
# 7         Data Collection              Neutral       16
# 8         Data Collection       High Relevance       67
# 9         Data Collection   Extremely Relevant       98
# 10    Data Pre-Processing  Not Relevant at All        1
# 11    Data Pre-Processing        Low Relevance        6
# 12    Data Pre-Processing              Neutral       13
# 13    Data Pre-Processing       High Relevance       75
# 14    Data Pre-Processing   Extremely Relevant       88
# 15         Model Creation  Not Relevant at All        1
# 16         Model Creation        Low Relevance        4
# 17         Model Creation              Neutral       30
# 18         Model Creation       High Relevance       81
# 19         Model Creation   Extremely Relevant       70
# 20       Model Evaluation  Not Relevant at All        1
# 21       Model Evaluation        Low Relevance        2
# 22       Model Evaluation              Neutral       15
# 23       Model Evaluation       High Relevance       79
# 24       Model Evaluation   Extremely Relevant       87
# 25       Model Deployment  Not Relevant at All        2
# 26       Model Deployment        Low Relevance        8
# 27       Model Deployment              Neutral       36
# 28       Model Deployment       High Relevance       74
# 29       Model Deployment   Extremely Relevant       61
# 30       Model Monitoring  Not Relevant at All        1
# 31       Model Monitoring        Low Relevance       11
# 32       Model Monitoring              Neutral       28
# 33       Model Monitoring       High Relevance       91
# 34       Model Monitoring   Extremely Relevant       49

# %%
# desmembra o df
stages = []
relevance = []
for idx, row in q1_df.iterrows():
    total_answers = int(row['Answers'])
    for t in range(total_answers):
        stages.append(row['Life Cycle'])
        relevance.append(row['Relevance'])

q1_df_tmp = pd.DataFrame()
q1_df_tmp['Life Cycle'] = stages 
q1_df_tmp['Relevance'] = relevance

q1_df_tmp = q1_df_tmp.fillna(0)

# %%
df_tmp = (q1_df_tmp
      .groupby("Life Cycle")["Relevance"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
      .unstack())

df_tmp = df_tmp.fillna(0)

# %%
df_tmp
# Out:
# Relevance              Extremely Relevant  High Relevance  Low Relevance  \
# Life Cycle
# Data Collection                     52.97           36.22           1.62
# Data Pre-Processing                 48.09           40.98           3.28
# Model Creation                      37.63           43.55           2.15
# Model Deployment                    33.70           40.88           4.42
# Model Evaluation                    47.28           42.93           1.09
# Model Monitoring                    27.22           50.56           6.11
# Problem Understanding               78.80           16.30           0.00
#
# Relevance              Neutral  Not Relevant at All
# Life Cycle
# Data Collection           8.65                 0.54
# Data Pre-Processing       7.10                 0.55
# Model Creation           16.13                 0.54
# Model Deployment         19.89                 1.10
# Model Evaluation          8.15                 0.54
# Model Monitoring         15.56                 0.56
# Problem Understanding     3.26                 1.63

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Plot barras horizontais
df_tmp.plot.barh(stacked=True,
                 ax=ax,
                 edgecolor="black")

# Adding bar labels
is_last = False
counter = 0
for c in ax.containers:
    labels = [("  " if counter == len(ax.containers) - 1 else '') + str(round(v.get_width(), 2)) + ("\n\n\n" if v.get_width() < 4 and counter < len(ax.containers) - 1 else "") if v.get_width() > 0 else '' for v in c]
    ax.bar_label(c,
                 label_type='center' if counter < len(ax.containers) - 1 else 'edge',
                 labels = labels,
                 size = 11) # add a container object "c" as first argument
    counter += 1
# Removing spines
for s in ["top", "right"]:
    ax.spines[s].set_visible(False)
    
# Adding tick and axes labels
ax.tick_params(labelsize = 14, labelrotation = 0)
ax.set_xlabel("Percentage (%)", size = 14)
ax.set_ylabel("Life Cycle", size = 14)
# Customising legend
ax.legend(labels = ["Extremely Relevant", "High Relevance", "Low Relevance", "Neutral", "Not Relevant at All"],
          fontsize = 12,
          title = "Relevance",
          title_fontsize = 18)
# Fixing legend position
ax.set_title("How relevant do you think each of the seven ML life cycle stages is with regard to project success?")
ax.legend(bbox_to_anchor=(1.25, 1), loc='upper right', title="Relevance")
