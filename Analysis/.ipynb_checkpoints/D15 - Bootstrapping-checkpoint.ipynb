# %%
import pandas as pd
import numpy as np
import random
import math
import seaborn as sns
import matplotlib.pyplot as plt
from ipynb.fs.full.utils import get_df, rename_values,remove_value
from ipynb.fs.full.plots import single_barplot
from ipynb.fs.full.bootstrapping_utils import bootstrapping, confidence_interval
from statistics import mean, pstdev

# %%
# get formatted and ready to use dataframe
df = get_df()
df = df[['D15_ML_Algorithms_Apriori', 'D15_ML_Algorithms_Bayesian', 'D15_ML_Algorithms_DBSCAN', 
         'D15_ML_Algorithms_Decision_Tree','D15_ML_Algorithms_Ensembles', 'D15_ML_Algorithms_Gaussian_Mixture', 
         'D15_ML_Algorithms_KMeans', 'D15_ML_Algorithms_KNN', 'D15_ML_Algorithms_Linear_Regression',
         'D15_ML_Algorithms_Logistic_Regression', 'D15_ML_Algorithms_Naive_Bayes', 
         'D15_ML_Algorithms_Neural_Networks', 'D15_ML_Algorithms_SVM', 'D15_ML_Algorithms_Others']]
df.head(10)
# Out:
#    D15_ML_Algorithms_Apriori D15_ML_Algorithms_Bayesian  \
# 2                 not quoted                 not quoted
# 3                 not quoted                 not quoted
# 4                 not quoted                 not quoted
# 5                 not quoted                 not quoted
# 6                     quoted                 not quoted
# 7                 not quoted                 not quoted
# 8                 not quoted                 not quoted
# 9                 not quoted                     quoted
# 10                not quoted                 not quoted
# 11                not quoted                 not quoted
#
#    D15_ML_Algorithms_DBSCAN D15_ML_Algorithms_Decision_Tree  \
# 2                not quoted                      not quoted
# 3                not quoted                          quoted
# 4                    quoted                          quoted
# 5                not quoted                          quoted
# 6                not quoted                          quoted
# 7                not quoted                      not quoted
# 8                not quoted                      not quoted
# 9                not quoted                      not quoted
# 10               not quoted                      not quoted
# 11               not quoted                      not quoted
#
#    D15_ML_Algorithms_Ensembles D15_ML_Algorithms_Gaussian_Mixture  \
# 2                   not quoted                         not quoted
# 3                   not quoted                         not quoted
# 4                   not quoted                         not quoted
# 5                   not quoted                         not quoted
# 6                       quoted                         not quoted
# 7                   not quoted                         not quoted
# 8                       quoted                         not quoted
# 9                       quoted                         not quoted
# 10                  not quoted                         not quoted
# 11                  not quoted                         not quoted
#
#    D15_ML_Algorithms_KMeans D15_ML_Algorithms_KNN  \
# 2                not quoted            not quoted
# 3                not quoted            not quoted
# 4                    quoted            not quoted
# 5                not quoted                quoted
# 6                    quoted                quoted
# 7                not quoted            not quoted
# 8                not quoted            not quoted
# 9                not quoted                quoted
# 10               not quoted            not quoted
# 11               not quoted            not quoted
#
#    D15_ML_Algorithms_Linear_Regression D15_ML_Algorithms_Logistic_Regression  \
# 2                               quoted                            not quoted
# 3                           not quoted                            not quoted
# 4                           not quoted                            not quoted
# 5                           not quoted                                quoted
# 6                               quoted                                quoted
# 7                           not quoted                            not quoted
# 8                               quoted                            not quoted
# 9                           not quoted                            not quoted
# 10                          not quoted                            not quoted
# 11                          not quoted                            not quoted
#
#    D15_ML_Algorithms_Naive_Bayes D15_ML_Algorithms_Neural_Networks  \
# 2                     not quoted                        not quoted
# 3                     not quoted                        not quoted
# 4                     not quoted                            quoted
# 5                     not quoted                        not quoted
# 6                         quoted                            quoted
# 7                     not quoted                            quoted
# 8                     not quoted                            quoted
# 9                         quoted                            quoted
# 10                    not quoted                        not quoted
# 11                    not quoted                        not quoted
#
#    D15_ML_Algorithms_SVM D15_ML_Algorithms_Others
# 2             not quoted               not quoted
# 3             not quoted               not quoted
# 4             not quoted                   quoted
# 5             not quoted               not quoted
# 6                 quoted                   quoted
# 7             not quoted               not quoted
# 8             not quoted               not quoted
# 9                 quoted               not quoted
# 10            not quoted               not quoted
# 11            not quoted               not quoted

# %%
# the possible answers are the ones in columns
valid_options_list = [column.split("D15_ML_Algorithms_")[1] for column in list(df.columns)]

# %%
# answers could be composed by more than one option, so we will have an array of selected options
valid_answers_list = []
prefix = 'D15_ML_Algorithms_'
for idx, row in df.iterrows():
    answer = []
    for option in valid_options_list:
        # if the option was selected, we add to our current answer
        if row[prefix + option] == 'quoted':
            answer.append(option)
    
    # if answer is empty, we assume that 'Others' was assigned - in terms of meaning 'Other context not listed'
    if not answer:
        answer = ['Others']
    valid_answers_list.append(answer)

# %%
bootstrapped_dict_data = bootstrapping(answers=valid_answers_list, all_options=valid_options_list,
                                       replacements=1000, population_size=1000, question_type='multiple')

# %%
lower, X_mean, upper = confidence_interval(data_points=bootstrapped_dict_data['Decision_Tree'])
print("Mean: " + str(X_mean) + "| Lower: " + str(lower) + "| Uper: " + str(upper))
# Out:
# Mean: 47.5378| Lower: 47.49083778836234| Uper: 47.58476221163765

# %%
# get a pair of values between dict key and all the list values inside that key 
# key: [val_1, val_2] ---> [(key, val_1), (key, val_2)...]
indexes = []
values = []
for idx in bootstrapped_dict_data:
    indexes += [idx for _ in range(len(bootstrapped_dict_data[idx]))]
    values += bootstrapped_dict_data[idx]

# %%
# build a dataframe from the population metrics
bootstrapped_df = pd.DataFrame()
bootstrapped_df['ML Algorithms'] = indexes
bootstrapped_df['Value'] = values

# %%
# draw bar plot graphics
d15_plot = sns.catplot(data=bootstrapped_df.sort_values(by=['Value'], ascending = False), 
                      kind="bar", x="Value", y="ML Algorithms", ci="sd", 
                      palette="dark", alpha=.6, height=6)
d15_plot.despine(left=True)
d15_plot.set_axis_labels("Percentage of Answers", "ML Algorithms")
