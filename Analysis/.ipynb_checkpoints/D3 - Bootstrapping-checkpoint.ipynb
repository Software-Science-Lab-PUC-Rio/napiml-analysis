# %%
import pandas as pd
import numpy as np
import random
import math
import seaborn as sns
import matplotlib.pyplot as plt
from ipynb.fs.full.utils import get_df, rename_values,remove_value
from ipynb.fs.full.plots import single_barplot
from statistics import mean, pstdev

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df['D3_Company_Size'].head(10)
# Out:
# 2         1,001-2,000 employees
# 3     More than 2,000 employees
# 4              51-250 employees
# 5     More than 2,000 employees
# 6           501-1,000 employees
# 7         1,001-2,000 employees
# 8                1-10 employees
# 9     More than 2,000 employees
# 10                            0
# 11                            0
# Name: D3_Company_Size, dtype: object

# %%
# remove undesired and not useful data
remove_value(df,'0','D3_Company_Size')

# %%
valid_options_list = list(df['D3_Company_Size'].unique())

# %%
valid_answers_list = list(df['D3_Company_Size'])

# %%
def single_option_sampling(*, main_answers: list, options: list, population_size: int):
    # ensure that all options will be filled - with 0 at least
    population_answers = {option: 0 for option in options}
    
    # will take r times a random chosen option
    for _ in range(population_size):
        rand_idx = random.randrange(len(main_answers))
        random_option = main_answers[rand_idx]
        # increase option total of answers
        population_answers[random_option] += 1
        
    return population_answers

# %%
def bootstrapping(*, answers: list, all_options: list, replacements: int, population_size: int):
    populations = []
    for _ in range(replacements):
        population = single_option_sampling(main_answers=answers, options=all_options, 
                                            population_size=population_size)
        # add population new answers
        populations.append(population)
    
    # now we have all answers distributed over Replacements populations
    # lets compute the percentage of answers in each option
    population_metrics = {option: [] for option in all_options}
    for population in populations:
        for option in population:
            population_metrics[option].append( (population[option] / population_size) * 100 )
    
    return population_metrics

# %%
def confidence_interval(*, data_points: list, confidence: float = 0.95):
    # https://www.indeed.com/career-advice/career-development/how-to-calculate-confidence-interval
    # mean
    X = mean(data_points)
    # population standard deviation
    S = pstdev(data_points)
    # data points length
    n = len(data_points)
    # square root data_points length
    sr_n = math.sqrt(n)
    # standard error
    standard_error = S / n
    # margin error
    margin_error = standard_error * 2
    
    lower_value = X - (confidence * (S / sr_n))
    upper_value = X + (confidence * (S / sr_n))
    
    return lower_value, X, upper_value

# %%
tmp = bootstrapping(answers=valid_answers_list, all_options=valid_options_list,
                    replacements=1000, population_size=1000)

# %%
l, X, u = confidence_interval(data_points=tmp['More than 2,000 employees'])

# %%
print("Media: " + str(X))
print(str(l) + "---" + str(u))
# Out:
# Media: 44.2566
# 44.20978151287045---44.30341848712955

# %%
tmp_df = pd.DataFrame()

indexes = []
values = []
for idx in tmp:
    
    indexes += [idx for _ in range(len(tmp[idx]))]
    values += tmp[idx]
    
tmp_df['Company Size'] = indexes
tmp_df['Value'] = values

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=tmp_df, kind="bar",
    x="Value", y="Company Size", ci="sd",  palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")

# %%
# mapping of old labels to new one
d3_rename_mapping = {
    '1-10 employees': '1-10',
    '11-50 employees': '11-50',
    '51-250 employees': '51-250',
    '251-500 employees': '251-500',
    '501-1,000 employees': '501-1000',
    '1,001-2,000 employees': '1001-2000',
    'More than 2,000 employees': '+2000'
}

# %%
df['D3_Company_Size'].value_counts().index
# Out:
# Index(['More than 2,000 employees', '51-250 employees', '11-50 employees',
#        '1,001-2,000 employees', '0', '1-10 employees', '251-500 employees',
#        '501-1,000 employees'],
#       dtype='object')

# %%
# index of our barplot
indexes = list(df['D3_Company_Size'].value_counts().index)
# total answers of each index
values = list(df['D3_Company_Size'].value_counts())
# dataframe specific for question D3
d3_df= pd.DataFrame(data={'Company Size': rename_values(d3_rename_mapping, indexes), 'Pretty Company Size': indexes, 'Answers': values})

# %%
d3_df
# Out:
#   Company Size        Pretty Company Size  Answers
# 0        +2000  More than 2,000 employees      112
# 1       51-250           51-250 employees       42
# 2        11-50            11-50 employees       28
# 3    1001-2000      1,001-2,000 employees       23
# 4         1-10             1-10 employees       21
# 5      251-500          251-500 employees       20
# 6     501-1000        501-1,000 employees        7

# %%
total_answers = d3_df['Answers'].sum()
total_answers
# Out:
# 253

# %%
for idx, row in d3_df.iterrows():
    # build list with answers to a binary version
    yes_entries = [1 for _ in range(row['Answers'])]
    no_entries = [0 for _ in range(total_answers - row['Answers'])]
    all_entries = yes_entries + no_entries
    
    # which metric we'll use
    metric_name = 'mean'
    
    # generate samples
    sampling_values = sampling(n_samples=50, sample_size=4, all_entries=all_entries, metric_name=metric_name)
    # compute bootstrapping with median
    metric_value, lower, upper = percentile_method(sampling_values=sampling_values, confidence_interval=95, metric_name=metric_name)
    
    sns.kdeplot(sampling_values)
    plt.title(row['Pretty Company Size'] + " -- Metric Name: " + str(metric_name) + "\n Metric Value: " + str(metric_value) + "| Lower CI: " + str(lower) + "| Upper CI: " + str(upper))
    plt.xlabel("My Company has " + row['Pretty Company Size'])
    plt.axvline(metric_value, 0, 14, linestyle="--", color="green")
    plt.axvline(lower, 0, 14, linestyle="--", color="red")
    plt.axvline(upper, 0, 14, linestyle="--", color="blue")
    plt.show()
