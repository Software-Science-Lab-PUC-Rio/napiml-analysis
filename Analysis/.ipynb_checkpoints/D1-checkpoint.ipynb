# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values, replace_values_by_condition,remove_value, replace_list_values_by_condition
from ipynb.fs.full.plots import single_barplot

# %%
df = get_df()
df = df[['D1_Undergraduation', 'D1_Specialization', 'D1_Master', 'D1_Phd', 'D1_Courses']]
df.head(10)
# Out:
#                         D1_Undergraduation                D1_Specialization  \
# 2                                Economics                              -99
# 3                                      -99                      Management
# 4                              Mathematics                      Informatics
# 5                         Computer Science      Data science specialization
# 6                        Actuarial Science  Post Graduation in Data Science
# 7                       Information System                              -99
# 8                         Computer Science                              -99
# 9   Electrical and Electronics Engineering                              -99
# 10                                     -99                              -99
# 11                                     -99                              -99
#
#                                D1_Master                D1_Phd  \
# 2                     M.Sc. in Economics                   -99
# ...

# %%
# replace values for undergraduation
df = replace_values_by_condition(df, 'D1_Undergraduation', '-99', 'Not selected', 'eq')
df = replace_values_by_condition(df, 'D1_Undergraduation', 'Informatics', 'Computer Science', 'eq')

# %%
indexes = list(df['D1_Undergraduation'].value_counts().index)
answers = list(df['D1_Undergraduation'].value_counts())
df_d1_undergraduation = pd.DataFrame(data={"Undergraduation": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_undergraduation,'Not selected','Undergraduation')

single_barplot(df_d1_undergraduation, "Answers", "Undergraduation", title="Undergraduations that participants have completed",
               x_label="Valid Answers", y_label="Undergraduation")

# %%
# replace values for specialization
df = replace_values_by_condition(df, 'D1_Specialization', '-99', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'AI & ML', 'Artificial Intelligence', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Artifical Intelligence', 'Artificial Intelligence', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Artificial Intelligence Curriculum', 'Artificial Intelligence', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Big Data, AI, HCI, Computational Math, Distributed Systems, MultiAgent Systems', 'Big Data', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'CS, SE', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'CBA em Gestão de TI e Ciência de Dados', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Computer Engineering, Software Engineering', 'Software Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Cience specialization', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Engineering and Analytics', 'Data Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science ', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science Bootcamp / Udacity MLE Nanodegree', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science Especialization', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science Specialization', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science and ML', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science and Machine Learning', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science and Statistics Computacional ', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science specialization', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data Science, Aeroderivative Turbines, Database architecture', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data science and data engineer', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Data science specialization', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Especialização em BI e ML', 'Business Inteligence', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Especialização em Bases de Dados', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'General Theoretical Computer Science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'I have specialization in Big Data', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Informatins', 'Informatics', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'MBA EM BIG DATA (DATA SCIENCE)', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'MBA in Logistics, MBA in Data Science (USP - ICMC)', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'MBA in Project Management', 'Project Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'MBA - Gestão de Projetos', 'Project Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Machine Learning,NLP', 'Machine Learning', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Management ', 'Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Managent Analytics', 'Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Mathematical Physics', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Medical Physics', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Nenhuma ', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'None', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Post Grad in Data Science and Business Analytics', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Post Graduation in Data Science', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Project Management Specialization', 'Project Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Projecto management ude', 'Project Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Software Engineering specialization', 'Software engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Software implementation project manager', 'Project Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Systems analysis with agile methods', 'Systems Analysis', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Web and Data Science, Finance and Accounting', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'a', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'computer science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'data science', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'especialização em Ciência de Dados', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'machine learning', 'Machine Learning', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'none', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'not applied', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'pattern recognition, image processing, computer vision', 'Computer Vision', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'project management specialization', 'Project Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Informatics', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Bioinformatics (undergrad) / Logic & Theoretical CS (Master)', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Business information ', 'Business information', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'MBA in Business Management', 'Business Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Management', 'Business Management', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Mobile and web applications', 'Mobile and web applications', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Numerical Simulation & Non-Linear Optimization ', 'Numerical Simulation & Non-Linear Optimization', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Software engineering', 'Software Engineering', 'eq')

# %%
indexes = list(df['D1_Specialization'].value_counts().index)
answers = list(df['D1_Specialization'].value_counts())
df_d1_specialization = pd.DataFrame(data={"Specialization": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_specialization,'Not Selected','Specialization')

single_barplot(df_d1_specialization, "Answers", "Specialization", title="Specializations that participants have completed",
               x_label="Valid Answers", y_label="Specialization")

# %%
# replace values for master
df = replace_values_by_condition(df, 'D1_Master', '-', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', '-99', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Applied Mathematics', 'Mathematics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'CEFET/RJ', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'CS', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Computer Science Information and Security', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Computer Science, Business Administration, IT Project Management', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Computer Science, Business Administration', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Doutorado em Ciência e Engenharia dos Materiais - UFSCar', 'Material Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Eletrical Engennering', 'Eletrical Enginnering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'I haven\'t', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Informatics', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Information Engineering ', 'Information Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M Sc in Data Science -ML models', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M,Sc. in Applied Computing', 'Applied Computing', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M. SC. Computer science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.SC. in Business Administration', 'Business Administration', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc Statistics ', 'Statistics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc Zoology', 'Zoology', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc em Sistema de Informação', 'Information System', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc in Computer Science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc in Informatics', 'Informatics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. Applied Data Analytics', 'Data Analytics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. Engineering Physics', 'Engineering Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. Robotics, Cognition, Intelligence', 'Robotics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in AI and Software Engineering', 'Software Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Applied Informatics', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Artificial Intelligence', 'Artificial Intelligence', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Business Administration', 'Business Administration', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Cognitive Science', 'Cognitive Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Computational/Civil Engineering', 'Civil Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Computer Engineering', 'Computer Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Computer Science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Computer Science (due in march/2022)', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Control Engineering ', 'Control Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Data Science', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Data Science + M.Sc. in Finance', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Data Visualization', 'Data Visualization', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Economics', 'Economics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Electrical and Electronics Engineer', 'Electrical and Electronics Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Electrical and Electronics Engineering', 'Electrical and Electronics Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Electrical&Electronics Eng.', 'Electrical and Electronics Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Engineering', 'Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Informatics', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Mechanical Engineering', 'Mechanical Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Operational Research', 'Operational Research', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Theoretical Physics', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in informatic', 'informatic', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc.. in Algorithms, Graph Theory', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSC Computer Science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MBA', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSc Computer Science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSc in Big Data and Business Analytics', 'Big Data and Business Analytics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSc in Computer Science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSc in Computer Science, Parallel Computing', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSc in E-commerce and Internet Computing', 'E-commerce and Internet Computing', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'MSc. in Computer Science in AI', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Management information systems/ Computer Engineering', 'Computer Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master Electrical Engineering', 'Electrical Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in Business Administration', 'Business Administration', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in CS', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in Computer Science, MAster in MArketing and Trade Management', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in Computer Science²', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in Engineering', 'Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in Software Engineering', 'Software Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master in physics', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Master of Business Administration', 'Business Administration', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Masters in Industrial Engineering and Management', 'Industrial Engineering and Management', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Mestrado em Engenharia de Produção', 'Production Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Mestre em Engenharia Eletrônica e Computação', 'Computer Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Msc communication systems', 'Communication Systems', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Msc in Physics', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Nenhuma ', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'No', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'None', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Operation Research an Data Science', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Particle physics', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Physics\'', 'Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Pontifícia Universidade Católica', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Software engineering', 'Software Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'System and Computer Engineering, PESC/UFRJ ', 'Computer Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Technology and Engineering Management master program', 'Engineering Management', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Visual Computing M.Sc.', 'Visual Computing', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'computational modeling', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'computer engineering', 'Computer Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'computer science', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'informatic', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'technical mathematics, maître d\'informatique', 'Mathematics', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'yes', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Eletrical Enginnering', 'Electrical Enginnering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'Informatics', 'Computer Science', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Electrical Engineering at Federal University of Minas Gerais (UFMG)', 'Electrical Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in Knowledge Extraction', 'Artificial Intelligence', 'eq')
df = replace_values_by_condition(df, 'D1_Master', 'M.Sc. in MIS', 'Business Administration', 'eq')

# %%
indexes = list(df['D1_Master'].value_counts().index)
answers = list(df['D1_Master'].value_counts())
df_d1_master = pd.DataFrame(data={"Master": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_master,'Not Selected','Master')

single_barplot(df_d1_master, "Answers", "Master", title="Masters that participants have completed",
               x_label="Valid Answers", y_label="Master")

# %%
# replace values for phd
replace_list_values_by_condition(df, 'D1_Phd',['PH.D in Informatics','Computational Science','Computational Science Candidate'
,'phd in computer science','Ph.D in Computer Science','Ph.D. in Computer Science','Computational Sciences'
,'Computational science','Computer science','Electrical & Computer Science','Electrical & Computer Science','Informatics'
, 'Ph.D. in Algorithms, Graph Theory', 'Ph.D. in Informatics', 'Computer Science Candidate', 'Computer Sciences'
,'Informatics, PPGI/UFRJ', 'PhD in Computer Science, Symbolic Computation, Automated Theorem Proving'
,'Ph.D. in Informatics ', 'Ph.D. in Computer Science (machine learning)','Ph.D. in Computer Science '
,'computational modeling', 'PhD in Computer Science','PhD computer Science','PhD in Computing Science and Telecomunications',
'[Ongoing] Ph.D. in Machine Learning'], 'Computer Science', 'eq')
replace_list_values_by_condition(df,'D1_Phd',[ '-99','I haven\'t','Nenhuma','No','None', 'Nenhuma','Nenhuma ','no Ph D'
,'-', 'student'],'Not Selected','eq')
replace_list_values_by_condition(df,'D1_Phd',['Physics','Particle physics','Ph.D. in Astrophysics',],'Physics','eq')
replace_list_values_by_condition(df,'D1_Phd',['PhD math ','mathematics', 'Ph.D. in Mathematics',],'Mathematics','eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Statistics, currently in progress', 'Statistics', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Information Technologies', 'Information Technology', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D Biology', 'Biology', 'eq')
# esse cara vai pra onde??
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D. in Computer Science and Mathematics (AI, Machine Learning, Data Mining)', 'Computer Science', 'eq')
##########################
#################### avaliar agrupamento
df = replace_values_by_condition(df, 'D1_Phd', 'Ph. D. in Electrical Engineering at Federal University of Minas Gerais (UFMG)', 'Electrical and Electronics Eng.', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D. in Electrical and Electronics Engineering', 'Electrical and Electronics Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D. Electrical Engineering', 'Electrical Engineering', 'eq')
####################
df = replace_values_by_condition(df, 'D1_Phd', 'Pós Doutorado em Engenharia Mecânica na área de Materiais e Processos de Fabricação - UNICAMP', 'Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'D.Sc. in Operational Research', 'Operational Research', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D. in Information Technologies', 'Information Technologies', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D. in Mathematical Physics', 'Mathematical Physics', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D. in Mechanical Engineering', 'Mechanical Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'PhD Enginiering Mechatronics', 'Engineering Mechatronics', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'D.Sc. in Computational/Civil Engineering', 'Computational/Civil Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Tecn.Lic. in Software Engineering', 'Software Engineering', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'phd in Technical Sciences', 'Technical Sciences', 'eq')
df = replace_values_by_condition(df, 'D1_Phd', 'Ph.D in Theoretical Physics', 'Theoretical Physics', 'eq')

# %%
indexes = list(df['D1_Phd'].value_counts().index)
answers = list(df['D1_Phd'].value_counts())
df_d1_phd = pd.DataFrame(data={"PhD": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_phd,'Not Selected','PhD')

single_barplot(df_d1_phd, "Answers", "PhD", title="Ph. D that participants have completed",
               x_label="Valid Answers", y_label="Ph. D")

# %%
# replace values for courses
df = replace_values_by_condition(df, 'D1_Courses', '-', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', '-99', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'AWS Machine Learning Specialty', 'AWS Machine Learning', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Certificação em Microstrategy', 'Certification in Microstrategy', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera ', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera (DeepLearning.ai)', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera - Data Scientist', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera Data Science Professional Certificate', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera Deep Learning Specialization', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera Deep Learning Specialization/ Datacamp Data Science Track ...', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera DeepLearning certification', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera IBM Data Science Specialization certificate, Coursera Andrew NG ML courses', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera course on ML', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Coursera/edX courses on ML and data science', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'D1_Courses', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Science Certification', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Science For All Graduate', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Science Specialications (Stanford, Harvard, Datacamp)', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Science with R, Python, SQL Bootcamp', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Science, Machine learning and Big Data specialization on Udemy', 'Udemy', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Scientist Basic', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Scientist in Datacamp', 'Datacamp', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data science - Spark Academy', 'Data Science', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data science and machine learning with statistic and python - Udemy', 'Udemy', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Datacamp DS With Python Track', 'Datacamp', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Datacamp Data Scientist Path, Datacamp Data Analyst Path, Datacamp Machine Learning Engineer Path', 'Datacamp', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Deep Learning Specialization (Coursera), Data Scientist NanoDegree (Udacity), Deep Learning NanoDegree (Udacity), Artificial Intelligence NanoDegree (Udacity)', 'Udacity', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Deep Learning specialization on Coursera; NLP and DS Nanodegrees on Udacity', 'Udacity', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Cloud', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Cloud Certified Architect', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Cloud Professional Data Engineer', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Professional Data Engineer, Coursera ML, Coursera Tensorflow Developer', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Professional ML Engineer Certification', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Professional ML Engineer and Data Engineer Certification', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google Professional ML Engineer, Google Professional Data Engineer', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Google introduction to ML', 'Google Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'I have completed some courses on ML and Data Science, mainly on Alura (a Brazilian e-learning platform) and less frequently on Udemy.', 'Alura', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'I haven\'t', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'HCIA Machine Learning, HCIA Machine Learning NV2', 'HCIA', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'IA HCIA huawei, ML HCIA huawei, ML HCIA huawei nv2 ', 'HCIA', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'IBM AI Professional Certificate, Coursera Python for Everybody\'s Specialization, DeeplearingAI Coursera', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'IBM Data science on Coursera ', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Machine Learning course Coursera', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Machine Learning on Coursera', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Microsoft Professional Program Data Science & ML specialization', 'Microsoft Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Microsoft certifications: Microsoft - DAT203.2x  Principles of Machine Learning ,   DAT210x  Programming with Python for Data Science ', 'Microsoft Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'NVIDIA - Deep Learning for Computer Vision, NVIDIA - Deep Learning for Multiple Data Types, Coursera - Machine Learning from Andrew NG', 'Andrew NG', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Machine Learning by Andrew Ng', 'Andrew NG', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'No', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'No certification', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'None', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Several courses on Datacamp', 'Several', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'UC Berkeley Data Science (10-Week Course)', 'UC Berkeley', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Udacity Data Scientist', 'Udacity', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Udacity Deep Learning Nanodegree, Udacity Data Engineer Nanodegree, Coursera Deep Learning Specialization, Azure Data Scientist Certification, Azure AI Engineer Certification', 'Udacity', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Udacity course on ML', 'Udacity', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Udemy x3', 'Udemy', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Udemy, DataCamp, Coursera', 'Udemy', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Various Coursera courses on ML', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Vários cursos in Coursera', 'Coursera', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'no other certifications', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'none', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'not applied', 'Not Selected', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'AWS Certification Machine Learning - Specialty', 'AWS Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'AWS Machine Learning', 'AWS Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Applied Data Science Camp', 'ADSCAMP', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Artificial Intelligence applied to Geosciences at UFMG', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Artificial Intelligence | Asian Institute of Management', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Azure Associate AI Engineer, Azure Data Science Associate', 'Azure Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Azure Machine Learning', 'Azure Certification', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'BTH Masters Course in ML, Combient course in Applied Data Science', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Certification Data scientist specialized in data analytics', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'DS4A - Correlation One', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'ITIL, PMP, Big Data analyze', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Several Coursera, Udacity and Microsoft Azure certificates on Data Science topics', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Several Coursera, Udacity and Microsoft Azure certificates on Data Science topics', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'UC Berkeley', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Certification in Microstrategy', 'Short General ML Courses', 'eq')
df = replace_values_by_condition(df, 'D1_Courses', 'Data Science', 'Not Selected', 'eq')

# %%
indexes = list(df['D1_Courses'].value_counts().index)
answers = list(df['D1_Courses'].value_counts())
df_d1_courses = pd.DataFrame(data={"Courses": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_courses,'Not Selected','Courses')

single_barplot(df_d1_courses, "Answers", "Courses", title="Courses that participants have completed",
               x_label="Valid Answers", y_label="Courses")
