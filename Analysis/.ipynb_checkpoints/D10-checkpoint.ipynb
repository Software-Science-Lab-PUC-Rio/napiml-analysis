# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values, replace_values_by_condition
from ipynb.fs.full.plots import single_barplot, wordcloud

# %%
df = get_df()
df = df[['D10_ML_Management_Framework_None', 'D10_ML_Management_Framework_CRISP-DM', 'D10_ML_Management_Framework_Kanban',
         'D10_ML_Management_Framework_Lean','D10_ML_Management_Framework_RUP', 'D10_ML_Management_Framework_SAFe', 
         'D10_ML_Management_Framework_Scrum', 'D10_ML_Management_Framework_Others', 'D10_ML_Management_Framework_Others_Free']]
df.head(10)
# Out:
#    D10_ML_Management_Framework_None D10_ML_Management_Framework_CRISP-DM  \
# 2                        not quoted                           not quoted
# 3                        not quoted                           not quoted
# 4                            quoted                           not quoted
# 5                        not quoted                           not quoted
# 6                        not quoted                           not quoted
# 7                        not quoted                           not quoted
# 8                            quoted                           not quoted
# 9                        not quoted                           not quoted
# 10                       not quoted                           not quoted
# 11                       not quoted                           not quoted
#
#    D10_ML_Management_Framework_Kanban D10_ML_Management_Framework_Lean  \
# 2                          not quoted                       not quoted
# 3                          not quoted                       not quoted
# 4                          not quoted                       not quoted
# 5                          not quoted                       not quoted
# 6                              quoted                       not quoted
# 7                              quoted                       not quoted
# 8                          not quoted                       not quoted
# 9                              quoted                       not quoted
# 10                         not quoted                       not quoted
# 11                         not quoted                       not quoted
#
#    D10_ML_Management_Framework_RUP D10_ML_Management_Framework_SAFe  \
# 2                       not quoted                       not quoted
# 3                       not quoted                       not quoted
# 4                       not quoted                       not quoted
# 5                       not quoted                       not quoted
# 6                       not quoted                       not quoted
# 7                       not quoted                       not quoted
# 8                       not quoted                       not quoted
# 9                       not quoted                       not quoted
# 10                      not quoted                       not quoted
# 11                      not quoted                       not quoted
#
#    D10_ML_Management_Framework_Scrum D10_ML_Management_Framework_Others  \
# 2                         not quoted                         not quoted
# 3                             quoted                         not quoted
# 4                         not quoted                         not quoted
# 5                             quoted                         not quoted
# 6                         not quoted                         not quoted
# 7                             quoted                         not quoted
# 8                             quoted                         not quoted
# 9                         not quoted                         not quoted
# 10                        not quoted                         not quoted
# 11                        not quoted                         not quoted
#
#    D10_ML_Management_Framework_Others_Free
# 2                                      -99
# 3                                      -99
# 4                                      -99
# 5                                      -99
# 6                                      -99
# 7                                      -99
# 8                                      -99
# 9                                      -99
# 10                                     -99
# 11                                     -99

# %%
label = ['None', 'CRISP', 'KANBAN', 'Lean', 'RUP', 'SAFe', 'Scrum']
frameworks = [
    df['D10_ML_Management_Framework_None'].value_counts()['quoted'],
    df['D10_ML_Management_Framework_CRISP-DM'].value_counts()['quoted'],
    df['D10_ML_Management_Framework_Kanban'].value_counts()['quoted'],
    df['D10_ML_Management_Framework_Lean'].value_counts()['quoted'],
    df['D10_ML_Management_Framework_RUP'].value_counts()['quoted'],
    df['D10_ML_Management_Framework_SAFe'].value_counts()['quoted'],
    df['D10_ML_Management_Framework_Scrum'].value_counts()['quoted']
]

# %%
# compute total of unique answers in this question
total = 0
for idx, row in df.iterrows():
    print(row)
    input()
    if row['D10_ML_Management_Framework_None'] == 'quoted' or row['D10_ML_Management_Framework_CRISP-DM'] == 'quoted' or row['D10_ML_Management_Framework_Kanban'] == 'quoted' or row['D10_ML_Management_Framework_Lean'] == 'quoted' or row['D10_ML_Management_Framework_RUP'] == 'quoted' or row['D10_ML_Management_Framework_SAFe'] == 'quoted' or row['D10_ML_Management_Framework_Scrum'] == 'quoted':
        total += 1

total_answers = 'N = ' + str(total)
# Out:
#   Cell In[15], line 6
#     if row['D10_ML_Management_Framework_None'] == 'quoted' or row['D10_ML_Management_Framework_CRISP-DM'] == 'quoted'
#                                                                                                                       ^
# SyntaxError: expected ':'

# %%
d10_df= pd.DataFrame(data={'Project Context': label, 'Answers': frameworks})

# %%
print(d10_df)
# Out:
#   Project Context  Answers
# 0          Nenhum       67
# 1           CRISP       41
# 2          KANBAN       83
# 3            Lean       16
# 4             RUP        3
# 5            SAFe        8
# 6           Scrum      139

# %%
single_barplot(d10_df.sort_values(by=['Answers'], ascending=False), "Project Context", "Answers", 
               title="Considering the ML-enabled system projects in which you participated,which project management frameworks were applied?",
               x_label="Framework", y_label="Answers", x_label_rotation=0, 
               color="#429bf5", total_answers=total_answers, bar_orientation='vertical')

# %%
for other in list(df['D10_ML_Management_Framework_Others_Free'].unique()):
    print(other)
# Out:
# -99
# nan
# Task List
# V model
# Tailored Waterfall/Agile
# Kaizen
# TMVA - Toolkit for Multivariate Data Analysis
# agile style (iterative, regular meetings,...) - but not fully Scrum

# %%
list(df['D10_ML_Management_Framework_Others_Free'].unique())
# Out:
# ['-99',
#  nan,
#  'Task List',
#  'V model',
#  'Tailored Waterfall/Agile',
#  'Kaizen',
#  'TMVA - Toolkit for Multivariate Data Analysis',
#  'agile style (iterative, regular meetings,...) - but not fully Scrum']

# %%
df = replace_values_by_condition(df, 'D10_ML_Management_Framework_Others_Free',
                                 'agile style (iterative, regular meetings,...) - but not fully Scrum',
                                 'Agile Style', 'eq')
df = replace_values_by_condition(df, 'D10_ML_Management_Framework_Others_Free',
                                 'TMVA - Toolkit for Multivariate Data Analysis',
                                 'TMVA', 'eq')
df = replace_values_by_condition(df, 'D10_ML_Management_Framework_Others_Free',
                                 'Tailored Waterfall/Agile',
                                 'Tailored Waterfall', 'eq')
df = replace_values_by_condition(df, 'D10_ML_Management_Framework_Others_Free',
                                 'V model',
                                 'VModel', 'eq')

# %%
# build simple text frequency - no preprocessing
frameworks_free = list(filter(lambda a: str(a) != '-99', list(df['D10_ML_Management_Framework_Others_Free'])))
frameworks_free = list(filter(lambda a: str(a) != 'nan', frameworks_free))
frameworks_free_dict = {}
for ff in frameworks_free:
    frameworks_free_dict[ff] = 1

# %%
wordcloud(frameworks_free_dict)
