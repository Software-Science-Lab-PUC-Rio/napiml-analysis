# %%
import pandas as pd
from ipynb.fs.full.utils import custom_groupby, get_df, replace_values_by_condition
from ipynb.fs.full.plots import heatmap, likert

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head(10)
# Out:
#     ID          Status Duration                      D1_Undergraduation  \
# 2   31  Completed (31)     1317                               Economics
# 3   34  Completed (31)      854                                     -99
# 4   36  Completed (31)     1593                             Mathematics
# 5   57  Completed (31)     4238                        Computer Science
# 6   46  Completed (31)     2821                       Actuarial Science
# 7   53  Completed (31)     2097                      Information System
# 8   58  Completed (31)     1696                        Computer Science
# 9   64  Completed (31)     1250  Electrical and Electronics Engineering
# 10  65  Completed (31)      106                                     -99
# 11  69  Completed (31)       79                                     -99
#
#                   D1_Specialization                             D1_Master  \
# 2                               -99                    M.Sc. in Economics
# 3                       Management                                     No
# 4                       Informatics                  MSC Computer Science
# 5       Data science specialization                                   -99
# 6   Post Graduation in Data Science       M Sc in Data Science -ML models
# 7                               -99          M.Sc. in Applied Informatics
# 8                               -99                      Computer Science
# 9                               -99  M.Sc. in AI and Software Engineering
# 10                              -99                                   -99
# 11                              -99                                   -99
#
#                   D1_Phd                                         D1_Courses  \
# 2                    -99                         Data Scientist in Datacamp
# 3                     No                                                 No
# 4   PhD computer Science                          Vários cursos in Coursera
# 5                    -99                                                -99
# 6                no Ph D                            no other certifications
# 7                    -99                                                -99
# 8                    -99  Microsoft Professional Program Data Science & ...
# 9       Computer science  Azure Associate AI Engineer, Azure Data Scienc...
# 10                   -99                                                -99
# 11                   -99                                                -99
#
#    D1_Others D2_Country  ... Q15_Model_Deploy_Production_Monitoring  \
# 2        -99     Brazil  ...                                    -77
# 3         No     Brazil  ...                                     70
# 4        -99     Brazil  ...                                     60
# 5        -99    Germany  ...                                    100
# 6        -99     Brazil  ...                                     80
# 7        -99     Brazil  ...                                     30
# 8        -99    Germany  ...                                     10
# 9        -99     Sweden  ...                                      0
# 10       -99          0  ...                                    -77
# 11       -99          0  ...                                    -77
#
#    Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                  not quoted
# 3                                  not quoted
# 4                                      quoted
# 5                                  not quoted
# 6                                  not quoted
# 7                                      quoted
# 8                                      quoted
# 9                                  not quoted
# 10                                 not quoted
# 11                                 not quoted
#
#    Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                         not quoted
# 3                                         not quoted
# 4                                         not quoted
# 5                                             quoted
# 6                                             quoted
# 7                                             quoted
# 8                                         not quoted
# 9                                         not quoted
# 10                                        not quoted
# 11                                        not quoted
#
#    Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                      not quoted
# 3                                          quoted
# 4                                          quoted
# 5                                          quoted
# 6                                          quoted
# 7                                      not quoted
# 8                                      not quoted
# 9                                      not quoted
# 10                                     not quoted
# 11                                     not quoted
#
#    Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                          not quoted                       not quoted
# 3                          not quoted                       not quoted
# 4                          not quoted                       not quoted
# 5                          not quoted                       not quoted
# 6                          not quoted                       not quoted
# 7                          not quoted                       not quoted
# 8                          not quoted                       not quoted
# 9                          not quoted                       not quoted
# 10                         not quoted                       not quoted
# 11                         not quoted                       not quoted
#
#    Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                    -99
# 3                                    -99
# 4                                    -99
# 5                                    -99
# 6                                    -99
# 7                                    -99
# 8                                    -99
# 9                                    -99
# 10                                   -99
# 11                                   -99
#
#    Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                            0
# 3                                           No
# 4                         Yes, Please, specify
# 5                                           No
# 6                                           No
# 7                                           No
# 8                                           No
# 9                                           No
# 10                                           0
# 11                                           0
#
#    Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                            -99
# 3                                            -99
# 4                                   Own approach
# 5                                            -99
# 6                                            -99
# 7                                            -99
# 8                                            -99
# 9                                            -99
# 10                                           -99
# 11                                           -99
#
#                              Origin
# 2   https://ww2.unipark.de/uc/seml/
# 3                               -99
# 4                               -99
# 5                               -99
# 6                               -99
# 7                               -99
# 8                     https://t.co/
# 9         https://www.linkedin.com/
# 10                              -99
# 11  https://ww2.unipark.de/uc/seml/
#
# [10 rows x 202 columns]

# %%
df[['Q2_ML_Life_Cycle_Difficulty_Problem_Understanding', 'Q2_ML_Life_Cycle_Difficulty_Data_Collection', 
'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing', 'Q2_ML_Life_Cycle_Difficulty_Model_Creation',
'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation', 'Q2_ML_Life_Cycle_Difficulty_Model_Deployment',
'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring']].head()
# Out:
#   Q2_ML_Life_Cycle_Difficulty_Problem_Understanding  \
# 2                                                 0
# 3                                           Complex
# 4                                           Complex
# 5                                           Complex
# 6                                           Neutral
#
#   Q2_ML_Life_Cycle_Difficulty_Data_Collection  \
# 2                                           0
# 3                                     Complex
# 4                                Very Complex
# 5                                        Easy
# 6                                     Neutral
#
#   Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing  \
# 2                                               0
# 3                                    Very Complex
# 4                                         Complex
# 5                                            Easy
# 6                                         Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Creation  \
# 2                                          0
# 3                               Very Complex
# 4                                    Complex
# 5                                    Neutral
# 6                                    Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Evaluation  \
# 2                                            0
# 3                                      Complex
# 4                                      Neutral
# 5                                      Complex
# 6                                 Very Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Deployment  \
# 2                                            0
# 3                                 Very Complex
# 4                                      Neutral
# 5                                 Very Complex
# 6                                 Very Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Monitoring
# 2                                            0
# 3                                      Neutral
# 4                                      Complex
# 5                                         Easy
# 6                                      Neutral

# %%
# check if there is something unexpected in the columns
# print(df['Q2_ML_Life_Cycle_Difficulty_Problem_Understanding'].unique())
# print(df['Q2_ML_Life_Cycle_Difficulty_Data_Collection'].unique())
# print(df['Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing'].unique())
# print(df['Q2_ML_Life_Cycle_Difficulty_Model_Creation'].unique())
# print(df['Q2_ML_Life_Cycle_Difficulty_Model_Evaluation'].unique())
# print(df['Q2_ML_Life_Cycle_Difficulty_Model_Deployment'].unique())
# print(df['Q2_ML_Life_Cycle_Difficulty_Model_Monitoring'].unique())

# %%
# two unexpected values appear = 0 and -77
# replace them to "I don't know" value

# replacing 0
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Problem_Understanding', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Data_Collection', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Creation', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Deployment', "0", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring', "0", "I don't know", "eq")

# replacing -77
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Problem_Understanding', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Data_Collection', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Creation', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Deployment', "-77", "I don't know", "eq")
df = replace_values_by_condition(df, 'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring', "-77", "I don't know", "eq")

# %%
columns = {
    'Q2_ML_Life_Cycle_Difficulty_Problem_Understanding': 'Problem Understanding',
    'Q2_ML_Life_Cycle_Difficulty_Data_Collection': 'Data Collection',
    'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing': 'Data Pre-Processing',
    'Q2_ML_Life_Cycle_Difficulty_Model_Creation': 'Model Creation',
    'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation': 'Model Evaluation',
    'Q2_ML_Life_Cycle_Difficulty_Model_Deployment': 'Model Deployment',
    'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring': 'Model Monitoring'
}

# values = ["Very Easy", "Easy", "Neutral", "Complex", "Very Complex", "I don't know"]
values = ["Very Easy", "Easy", "Neutral", "Complex", "Very Complex"]


# it will store the life cycles
life_cycles = []
# it will store the difficulties
difficulties = []
# it will store the total answers of those who answered 'Problem Understanding' and 
# said that is 'Not Relevant at All', 'Low Relevance'... then, 'Data Collection' with 'Not Relevant at All', 'Low Relevance'...
answers = []

# let's compute for each life cycle and difficulty, the total answers
for column in columns:
    for value in values:
        
        life_cycles.append(columns[column])
        difficulties.append(value)
        answers.append(df[column].value_counts().get(value, 0))

# %%
# create a custom dataframe to handle only the columns that we want
q2_df = pd.DataFrame()
q2_df['Life Cycle'] = life_cycles
q2_df['Difficulty'] = difficulties
q2_df['Answers'] = answers

# %%
q2_df
# Out:
#                Life Cycle    Difficulty  Answers
# 0   Problem Understanding     Very Easy        1
# 1   Problem Understanding          Easy        8
# 2   Problem Understanding       Neutral       42
# 3   Problem Understanding       Complex       81
# 4   Problem Understanding  Very Complex       51
# 5         Data Collection     Very Easy        0
# 6         Data Collection          Easy       19
# 7         Data Collection       Neutral       63
# 8         Data Collection       Complex       60
# 9         Data Collection  Very Complex       41
# 10    Data Pre-Processing     Very Easy        1
# 11    Data Pre-Processing          Easy       17
# 12    Data Pre-Processing       Neutral       56
# 13    Data Pre-Processing       Complex       73
# 14    Data Pre-Processing  Very Complex       35
# 15         Model Creation     Very Easy        4
# 16         Model Creation          Easy       27
# 17         Model Creation       Neutral       61
# 18         Model Creation       Complex       68
# 19         Model Creation  Very Complex       24
# 20       Model Evaluation     Very Easy        1
# 21       Model Evaluation          Easy       25
# 22       Model Evaluation       Neutral       57
# 23       Model Evaluation       Complex       73
# 24       Model Evaluation  Very Complex       26
# 25       Model Deployment     Very Easy        2
# 26       Model Deployment          Easy       14
# 27       Model Deployment       Neutral       70
# 28       Model Deployment       Complex       63
# 29       Model Deployment  Very Complex       30
# 30       Model Monitoring     Very Easy        2
# 31       Model Monitoring          Easy       23
# 32       Model Monitoring       Neutral       80
# 33       Model Monitoring       Complex       57
# 34       Model Monitoring  Very Complex       15

# %%
# to use a custom order of columns on heatmap 
# you need to put the index of the columns displayed on this cell in the order you want
# pivot_df = q1_df.pivot('Life Cycle', 'Difficulty', 'Answers')
# print(pivot_df.columns)

# %%
heatmap(q2_df, 'Life Cycle', 'Difficulty', 'Answers', order=[4, 1, 2, 0, 3], title='How difficult do you think each of the seven ML life cycle stages are in general?')

# %%
def likert_formatted_df(column, formatted_column, values):
    # for this column, we will plot a likert plot
    
    # it will store the total difficulties for this column, each answer = one row
    difficulties = []

    # let's compute for each life cycle and difficulty, the total answers
    for value in values:
        total_answers_difficulty = df[column].value_counts().get(value, 0)
        for _ in range(total_answers_difficulty):
            difficulties.append(value)
    
    column_likert_df = pd.DataFrame()
    column_likert_df['Difficulty on ' + formatted_column] = difficulties
    
    likert(column_likert_df, values, use_percentage=True, bar_label=True)

# %%
columns = {
    'Q2_ML_Life_Cycle_Difficulty_Problem_Understanding': 'Problem Understanding',
    'Q2_ML_Life_Cycle_Difficulty_Data_Collection': 'Data Collection',
    'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing': 'Data Pre-Processing',
    'Q2_ML_Life_Cycle_Difficulty_Model_Creation': 'Model Creation',
    'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation': 'Model Evaluation',
    'Q2_ML_Life_Cycle_Difficulty_Model_Deployment': 'Model Deployment',
    'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring': 'Model Monitoring'
}

values = ["Very Easy", "Easy", "Neutral", "Complex", "Very Complex"]
for column in columns:
    likert_formatted_df(column, columns[column], values)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
q2_df
# Out:
#                Life Cycle    Difficulty  Answers
# 0   Problem Understanding     Very Easy        1
# 1   Problem Understanding          Easy        8
# 2   Problem Understanding       Neutral       42
# 3   Problem Understanding       Complex       81
# 4   Problem Understanding  Very Complex       51
# 5         Data Collection     Very Easy        0
# 6         Data Collection          Easy       19
# 7         Data Collection       Neutral       63
# 8         Data Collection       Complex       60
# 9         Data Collection  Very Complex       41
# 10    Data Pre-Processing     Very Easy        1
# 11    Data Pre-Processing          Easy       17
# 12    Data Pre-Processing       Neutral       56
# 13    Data Pre-Processing       Complex       73
# 14    Data Pre-Processing  Very Complex       35
# 15         Model Creation     Very Easy        4
# 16         Model Creation          Easy       27
# 17         Model Creation       Neutral       61
# 18         Model Creation       Complex       68
# 19         Model Creation  Very Complex       24
# 20       Model Evaluation     Very Easy        1
# 21       Model Evaluation          Easy       25
# 22       Model Evaluation       Neutral       57
# 23       Model Evaluation       Complex       73
# 24       Model Evaluation  Very Complex       26
# 25       Model Deployment     Very Easy        2
# 26       Model Deployment          Easy       14
# 27       Model Deployment       Neutral       70
# 28       Model Deployment       Complex       63
# 29       Model Deployment  Very Complex       30
# 30       Model Monitoring     Very Easy        2
# 31       Model Monitoring          Easy       23
# 32       Model Monitoring       Neutral       80
# 33       Model Monitoring       Complex       57
# 34       Model Monitoring  Very Complex       15

# %%
# desmembra o df
stages = []
difficulty = []
for idx, row in q2_df.iterrows():
    total_answers = int(row['Answers'])
    for t in range(total_answers):
        stages.append(row['Life Cycle'])
        difficulty.append(row['Difficulty'])

q2_df_tmp = pd.DataFrame()
q2_df_tmp['Life Cycle'] = stages 
q2_df_tmp['Difficulty'] = difficulty

q2_df_tmp = q2_df_tmp.fillna(0)

# %%
df_tmp = (q2_df_tmp
      .groupby("Life Cycle")["Difficulty"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
      .unstack())

df_tmp = df_tmp.fillna(0)

# %%
df_tmp
# Out:
# Difficulty             Complex   Easy  Neutral  Very Complex  Very Easy
# Life Cycle
# Data Collection          32.79  10.38    34.43         22.40       0.00
# Data Pre-Processing      40.11   9.34    30.77         19.23       0.55
# Model Creation           36.96  14.67    33.15         13.04       2.17
# Model Deployment         35.20   7.82    39.11         16.76       1.12
# Model Evaluation         40.11  13.74    31.32         14.29       0.55
# Model Monitoring         32.20  12.99    45.20          8.47       1.13
# Problem Understanding    44.26   4.37    22.95         27.87       0.55

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Plot barras horizontais
df_tmp.plot.barh(stacked=True,
                 ax=ax,
                 edgecolor="black")

# Adding bar labels
is_last = False
counter = 0
for c in ax.containers:
    labels = [("  " if counter == len(ax.containers) - 1 else '') + str(round(v.get_width(), 2)) + ("\n\n\n" if v.get_width() < 4 and counter < len(ax.containers) - 1 else "") if v.get_width() > 0 else '' for v in c]
    ax.bar_label(c,
                 label_type='center' if counter < len(ax.containers) - 1 else 'edge',
                 labels = labels,
                 size = 11) # add a container object "c" as first argument
    counter += 1
# Removing spines
for s in ["top", "right"]:
    ax.spines[s].set_visible(False)
    
# Adding tick and axes labels
ax.tick_params(labelsize = 14, labelrotation = 0)
ax.set_xlabel("Percentage (%)", size = 14)
ax.set_ylabel("Life Cycle", size = 14)
# Customising legend
ax.legend(labels = ["Very Easy", "Easy", "Neutral", "Complex", "Very Complex"],
          fontsize = 12,
          title = "Difficulty",
          title_fontsize = 18)
# Fixing legend position
ax.set_title("How difficult do you think each of the seven ML life cycle stages are in general?")
ax.legend(bbox_to_anchor=(1.25, 1), loc='upper right', title="Difficulty")
