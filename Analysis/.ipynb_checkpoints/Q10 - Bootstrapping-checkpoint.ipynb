# %%
import pandas as pd
import numpy as np
import random
import math
import seaborn as sns
import matplotlib.pyplot as plt
from ipynb.fs.full.utils import get_df, rename_values,remove_value
from ipynb.fs.full.plots import single_barplot
from ipynb.fs.full.bootstrapping_utils import bootstrapping, confidence_interval
from statistics import mean, pstdev

# %%
# get formatted and ready to use dataframe
df = get_df()
df = df[['Q10_ML_Documentation_Not_Documented', 'Q10_ML_Documentation_Vision_Document',
         'Q10_ML_Documentation_Requirements_Lists', 'Q10_ML_Documentation_Goal_Models',
         'Q10_ML_Documentation_Use_Case_Models', 'Q10_ML_Documentation_Prototypes',
         'Q10_ML_Documentation_User_Stories', 'Q10_ML_Documentation_BDD_Scenarios', 
         'Q10_ML_Documentation_MLCanvas', 'Q10_ML_Documentation_Notebooks',
         'Q10_ML_Documentation_Data_Models', 'Q10_ML_Documentation_Others']]
df.head(10)
# Out:
#    Q10_ML_Documentation_Not_Documented Q10_ML_Documentation_Vision_Document  \
# 2                               quoted                           not quoted
# 3                           not quoted                               quoted
# 4                           not quoted                           not quoted
# 5                           not quoted                               quoted
# 6                           not quoted                           not quoted
# 7                           not quoted                               quoted
# 8                           not quoted                           not quoted
# 9                           not quoted                           not quoted
# 10                          not quoted                           not quoted
# 11                          not quoted                           not quoted
#
#    Q10_ML_Documentation_Requirements_Lists Q10_ML_Documentation_Goal_Models  \
# 2                               not quoted                       not quoted
# 3                               not quoted                       not quoted
# 4                               not quoted                       not quoted
# 5                                   quoted                       not quoted
# 6                                   quoted                       not quoted
# 7                                   quoted                       not quoted
# 8                               not quoted                           quoted
# 9                                   quoted                           quoted
# 10                              not quoted                       not quoted
# 11                              not quoted                       not quoted
#
#    Q10_ML_Documentation_Use_Case_Models Q10_ML_Documentation_Prototypes  \
# 2                            not quoted                      not quoted
# 3                            not quoted                      not quoted
# 4                                quoted                      not quoted
# 5                            not quoted                          quoted
# 6                                quoted                          quoted
# 7                                quoted                          quoted
# 8                                quoted                      not quoted
# 9                                quoted                          quoted
# 10                           not quoted                      not quoted
# 11                           not quoted                      not quoted
#
#    Q10_ML_Documentation_User_Stories Q10_ML_Documentation_BDD_Scenarios  \
# 2                         not quoted                         not quoted
# 3                         not quoted                         not quoted
# 4                             quoted                         not quoted
# 5                         not quoted                         not quoted
# 6                         not quoted                         not quoted
# 7                         not quoted                         not quoted
# 8                         not quoted                         not quoted
# 9                         not quoted                         not quoted
# 10                        not quoted                         not quoted
# 11                        not quoted                         not quoted
#
#    Q10_ML_Documentation_MLCanvas Q10_ML_Documentation_Notebooks  \
# 2                     not quoted                     not quoted
# 3                     not quoted                     not quoted
# 4                     not quoted                     not quoted
# 5                     not quoted                     not quoted
# 6                     not quoted                         quoted
# 7                     not quoted                         quoted
# 8                         quoted                         quoted
# 9                     not quoted                         quoted
# 10                    not quoted                     not quoted
# 11                    not quoted                     not quoted
#
#    Q10_ML_Documentation_Data_Models Q10_ML_Documentation_Others
# 2                        not quoted                  not quoted
# 3                        not quoted                  not quoted
# 4                            quoted                  not quoted
# 5                        not quoted                  not quoted
# 6                            quoted                  not quoted
# 7                            quoted                  not quoted
# 8                            quoted                  not quoted
# 9                            quoted                  not quoted
# 10                       not quoted                  not quoted
# 11                       not quoted                  not quoted

# %%
# the possible answers are the ones in columns
valid_options_list = [column.split("Q10_ML_Documentation_")[1] for column in list(df.columns)]

# %%
# answers could be composed by more than one option, so we will have an array of selected options
valid_answers_list = []
prefix = 'Q10_ML_Documentation_'
for idx, row in df.iterrows():
    answer = []
    for option in valid_options_list:
        # if the option was selected, we add to our current answer
        if row[prefix + option] == 'quoted':
            answer.append(option)
    
    # if answer is empty, we assume that 'Others' was assigned - in terms of meaning 'Other context not listed'
    if not answer:
        answer = ['Others']
    valid_answers_list.append(answer)

# %%
bootstrapped_dict_data = bootstrapping(answers=valid_answers_list, all_options=valid_options_list,
                                       replacements=1000, population_size=1000, question_type='multiple')

# %%
lower, X_mean, upper = confidence_interval(data_points=bootstrapped_dict_data['Data_Models'])
print("Mean: " + str(X_mean) + "| Lower: " + str(lower) + "| Uper: " + str(upper))
# Out:
# Mean: 12.2974| Lower: 12.264777862591485| Uper: 12.330022137408514

# %%
# get a pair of values between dict key and all the list values inside that key 
# key: [val_1, val_2] ---> [(key, val_1), (key, val_2)...]
indexes = []
values = []
for idx in bootstrapped_dict_data:
    indexes += [idx for _ in range(len(bootstrapped_dict_data[idx]))]
    values += bootstrapped_dict_data[idx]

# %%
# build a dataframe from the population metrics
bootstrapped_df = pd.DataFrame()
bootstrapped_df['Requirements Documentation'] = indexes
bootstrapped_df['Value'] = values

# %%
# draw bar plot graphics
d15_plot = sns.catplot(data=bootstrapped_df.sort_values(by=['Value'], ascending = False), 
                      kind="bar", x="Value", y="Requirements Documentation", ci="sd", 
                      palette="dark", alpha=.6, height=6)
d15_plot.despine(left=True)
d15_plot.set_axis_labels("Percentage of Answers", "Requirements Documentation")
