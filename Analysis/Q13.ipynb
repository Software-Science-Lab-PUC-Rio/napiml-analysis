# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values
from ipynb.fs.full.plots import single_barplot

# %%
df = get_df()

# %%
print(df)
# Out:
#       ID          Status Duration D1_Undergraduation  \
# 2     31  Completed (31)     1317          Economics
# 3     34  Completed (31)      854                -99
# 4     36  Completed (31)     1593        Mathematics
# 5     57  Completed (31)     4238   Computer Science
# 6     46  Completed (31)     2821  Actuarial Science
# ..   ...             ...      ...                ...
# 273  458  Suspended (22)        0   Computer Science
# 274  499  Suspended (22)        0   Computer Science
# 275  500  Suspended (22)        0   Computer Science
# 276  518  Suspended (22)        0   Computer Science
# 277  522  Suspended (22)       35                -99
#
#                    D1_Specialization                        D1_Master  \
# 2                                -99               M.Sc. in Economics
# 3                        Management                                No
# 4                        Informatics             MSC Computer Science
# 5        Data science specialization                              -99
# 6    Post Graduation in Data Science  M Sc in Data Science -ML models
# ..                               ...                              ...
# 273             Software Engineering                 Computer Systems
# 274                              -99                              -99
# 275      Data Science Specialization        M.Sc. in Computer Science
# 276                              -99                              -99
# 277                              -99                              -99
#
#                    D1_Phd                  D1_Courses D1_Others  \
# 2                     -99  Data Scientist in Datacamp       -99
# 3                      No                          No        No
# 4    PhD computer Science   Vários cursos in Coursera       -99
# 5                     -99                         -99       -99
# 6                 no Ph D     no other certifications       -99
# ..                    ...                         ...       ...
# 273      Computer Science                        none       -99
# 274                   -99                         -99       -99
# 275                   -99                         -99       -99
# 276                   -99                         -99       -99
# 277                   -99                         -99       -99
#
#          D2_Country  ... Q15_Model_Deploy_Production_Monitoring  \
# 2            Brazil  ...                                    -77
# 3            Brazil  ...                                     70
# 4            Brazil  ...                                     60
# 5           Germany  ...                                    100
# 6            Brazil  ...                                     80
# ..              ...  ...                                    ...
# 273  United Kingdom  ...                                    -77
# 274          Brazil  ...                                    -77
# 275          Brazil  ...                                    -77
# 276          Brazil  ...                                    -77
# 277               0  ...                                    -77
#
#     Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                   not quoted
# 3                                   not quoted
# 4                                       quoted
# 5                                   not quoted
# 6                                   not quoted
# ..                                         ...
# 273                                        -77
# 274                                        -77
# 275                                        -77
# 276                                        -77
# 277                                        -77
#
#     Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                          not quoted
# 3                                          not quoted
# 4                                          not quoted
# 5                                              quoted
# 6                                              quoted
# ..                                                ...
# 273                                               -77
# 274                                               -77
# 275                                               -77
# 276                                               -77
# 277                                               -77
#
#     Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                       not quoted
# 3                                           quoted
# 4                                           quoted
# 5                                           quoted
# 6                                           quoted
# ..                                             ...
# 273                                            -77
# 274                                            -77
# 275                                            -77
# 276                                            -77
# 277                                            -77
#
#     Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                           not quoted                       not quoted
# 3                           not quoted                       not quoted
# 4                           not quoted                       not quoted
# 5                           not quoted                       not quoted
# 6                           not quoted                       not quoted
# ..                                 ...                              ...
# 273                                -77                              -77
# 274                                -77                              -77
# 275                                -77                              -77
# 276                                -77                              -77
# 277                                -77                              -77
#
#     Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                     -99
# 3                                     -99
# 4                                     -99
# 5                                     -99
# 6                                     -99
# ..                                    ...
# 273                                   -66
# 274                                   -66
# 275                                   -66
# 276                                   -66
# 277                                   -66
#
#     Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                             0
# 3                                            No
# 4                          Yes, Please, specify
# 5                                            No
# 6                                            No
# ..                                          ...
# 273                                         -77
# 274                                         -77
# 275                                         -77
# 276                                         -77
# 277                                         -77
#
#     Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                             -99
# 3                                             -99
# 4                                    Own approach
# 5                                             -99
# 6                                             -99
# ..                                            ...
# 273                                           -66
# 274                                           -66
# 275                                           -66
# 276                                           -66
# 277                                           -66
#
#                                        Origin
# 2             https://ww2.unipark.de/uc/seml/
# 3                                         -99
# 4                                         -99
# 5                                         -99
# 6                                         -99
# ..                                        ...
# 273  https://machine-learning-survey.web.app/
# 274  https://machine-learning-survey.web.app/
# 275  https://machine-learning-survey.web.app/
# 276  https://machine-learning-survey.web.app/
# 277  https://machine-learning-survey.web.app/
#
# [276 rows x 202 columns]

# %%
df[['Q13_Model_Deploy_Approach_Embedded_Model',
'Q13_Model_Deploy_Approach_Service',
'Q13_Model_Deploy_Approach_PaaS',
'Q13_Model_Deploy_Approach_Others',
'Q13_Model_Deploy_Approach_Others_Free']]
# Out:
#     Q13_Model_Deploy_Approach_Embedded_Model  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                 not quoted
# 5                                 not quoted
# 6                                 not quoted
# ..                                       ...
# 273                                      -77
# 274                                      -77
# 275                                      -77
# 276                                      -77
# 277                                      -77
#
#     Q13_Model_Deploy_Approach_Service Q13_Model_Deploy_Approach_PaaS  \
# 2                              quoted                     not quoted
# 3                              quoted                     not quoted
# 4                              quoted                         quoted
# 5                              quoted                         quoted
# 6                              quoted                     not quoted
# ..                                ...                            ...
# 273                               -77                            -77
# 274                               -77                            -77
# 275                               -77                            -77
# 276                               -77                            -77
# 277                               -77                            -77
#
#     Q13_Model_Deploy_Approach_Others Q13_Model_Deploy_Approach_Others_Free
# 2                         not quoted                                   -99
# 3                         not quoted                                   -99
# 4                         not quoted                                   -99
# 5                         not quoted                                   -99
# 6                         not quoted                                   -99
# ..                               ...                                   ...
# 273                              -77                                   -66
# 274                              -77                                   -66
# 275                              -77                                   -66
# 276                              -77                                   -66
# 277                              -77                                   -66
#
# [276 rows x 5 columns]

# %%
approachs = ['Embedded Model', 'Separate Service', 'PaaS']

# %%
approachs_total = [df['Q13_Model_Deploy_Approach_Embedded_Model'].value_counts()['quoted'],
                   df['Q13_Model_Deploy_Approach_Service'].value_counts()['quoted'],
                   df['Q13_Model_Deploy_Approach_PaaS'].value_counts()['quoted']
                  ]

# %%
q13_df= pd.DataFrame(data={'Approaches': approachs, 'Answers': approachs_total})

# %%
q13_df
# Out:
#          Approaches  Answers
# 0    Embedded Model       72
# 1  Separate Service      100
# 2              PaaS       40

# %%
single_barplot(q13_df.sort_values(by=['Answers'], ascending=False), "Approaches", "Answers", 
               title="In the context of the ML-enabled system projects you participated in, which approach is typically used to deploy ML models?",
               x_label="Approaches", y_label="Answers")

# %%
df['Q13_Model_Deploy_Approach_Others_Free'].unique()
# Out:
# array(['-99', nan, 'dataiku', 'none', 'Specific container',
#        'Not applicable, it was for research purposes.', "I don't know",
#        'Technical Reports', '-66'], dtype=object)

# %%
for other in list(df['Q13_Model_Deploy_Approach_Others_Free'].unique()):
    print(other)
# Out:
# -99
# nan
# dataiku
# none
# Specific container
# Not applicable, it was for research purposes.
# I don't know
# Technical Reports
# -66
