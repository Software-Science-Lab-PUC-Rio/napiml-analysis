# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values, replace_values_by_condition,remove_value, replace_list_values_by_condition
from ipynb.fs.full.plots import single_barplot

# %%
df = get_df()
df = df[['D1_Undergraduation', 'D1_Specialization', 'D1_Master', 'D1_Phd', 'D1_Courses']]
df.head(10)
# Out:
#                         D1_Undergraduation                D1_Specialization  \
# 2                                Economics                              -99
# 3                                      -99                      Management
# 4                              Mathematics                      Informatics
# 5                         Computer Science      Data science specialization
# 6                        Actuarial Science  Post Graduation in Data Science
# 7                       Information System                              -99
# 8                         Computer Science                              -99
# 9   Electrical and Electronics Engineering                              -99
# 10                                     -99                              -99
# 11                                     -99                              -99
#
#                                D1_Master                D1_Phd  \
# 2                     M.Sc. in Economics                   -99
# ...

# %%
# replace values for undergraduation
df = replace_values_by_condition(df, 'D1_Undergraduation', '-99', 'Not selected', 'eq')
df = replace_values_by_condition(df, 'D1_Undergraduation', 'Computer Science, Mathematics', 'Mathematics', 'eq')
df = replace_values_by_condition(df, 'D1_Undergraduation', 'Mathematics, Physics', 'Physics', 'eq')

replace_list_values_by_condition(df, 'D1_Undergraduation',['Informatics', 'Business Informatics',
                                                           'Software Engineering', 'Computer Engineering',
                                                           'Computer System Administration', 
                                                           'Computer System Management', 'Data Base', 
                                                           'Data Processing'], 'Computer Science', 'eq')

replace_list_values_by_condition(df, 'D1_Undergraduation',['Information System', 
                                                           'System Administration',
                                                           'Systems Analysis', 
                                                           'Information Engineering'], 'Information Systems', 'eq')

replace_list_values_by_condition(df, 'D1_Undergraduation',['Management and Industrial Engineering', 
                                                           'Industrial Eng, Mathematics'], 'Industrial Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Undergraduation',['Aerospace Engineering', 'Robotics Engineering',
                                                          'Nuclear Engineering', 'Metallurgical Engineering',
                                                          'Manufacturing Engineering', 'Logistics',
                                                          'Instrumentation and Control Engineering',
                                                          'Industrial Pharmacy', 'Chip designer',
                                                          'Biology', 'Automation Engineering'], 'Others', 'eq')

# %%
indexes = list(df['D1_Undergraduation'].value_counts().index)
answers = list(df['D1_Undergraduation'].value_counts())
df_d1_undergraduation = pd.DataFrame(data={"Undergraduation": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_undergraduation,'Not selected','Undergraduation')
remove_value(df_d1_undergraduation,'Others','Undergraduation')

# compute total of answer considered in this question
total_answers = "N = " + str(sum(df_d1_undergraduation['Answers']))

single_barplot(df_d1_undergraduation, "Answers", "Undergraduation", title="Top Undergraduations that participants have completed",
               x_label="Valid Answers", y_label="Undergraduation", color="#429bf5", total_answers=total_answers)

# %%
# replace values for specialization
replace_list_values_by_condition(df, 'D1_Specialization',['-99', 'Nenhuma', 'Nenhuma ', 'none', 'not applied', 'None', 'a'], 'Not Selected', 'eq')
replace_list_values_by_condition(df, 'D1_Specialization',['Signal Processing', 'Autonomous Vehicle Navigation', 
                                                          'Mechanical Dynamics', 'Platform and robotic Manager',
                                                          'Control Theory, Information Technologies, Mechatronics',
                                                          'Engineering, Mechanics, Psychology',
                                                          'Infosec Management', 'Marketing, Finances', 'Actuarial Science',
                                                          'Inequality Measurement', 'Econometrics, Finance', 
                                                          'Media Informatics', 'Electrical Engineering'], 'Others', 'eq')

df = replace_values_by_condition(df, 'D1_Specialization', 'pattern recognition, image processing, computer vision', 'Computer Vision', 'eq')
df = replace_values_by_condition(df, 'D1_Specialization', 'Informatins', 'Informatics', 'eq')


replace_list_values_by_condition(df, 'D1_Specialization',['Mobile and web applications '], 'Web Development', 'eq')
replace_list_values_by_condition(df, 'D1_Specialization',['Numerical Simulation & Non-Linear Optimization ', 'Operations Research', 
                                                          'Mathematical modeling, optimization, machine learning'], 'Optimization', 'eq')
replace_list_values_by_condition(df, 'D1_Specialization',['Especialização em BI e ML', 'Business Engineering', 'Business Inteligence'], 'Business Intelligence', 'eq')
replace_list_values_by_condition(df, 'D1_Specialization',['Data Engineering and Analytics', 'Data engineering', 'Data Management'], 'Data Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['Big Data, AI, HCI, Computational Math, Distributed Systems, MultiAgent Systems',
                                                          'Oracle DB Developer', 'I have specialization in Big Data'], 'Big Data', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['AI & ML', 'Artifical Intelligence', 
                                                          'Artificial Intelligence Curriculum', 'Natural Language Processing', ], 'Artificial Intelligence', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['CS, SE', 'Informatics', 
                                                          'Bioinformatics (undergrad) / Logic & Theoretical CS (Master)',
                                                          'computer science',
                                                          'General Theoretical Computer Science', 'Computer systems',
                                                          'Systems analysis with agile methods'], 'Computer Science', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['Computer Engineering, Software Engineering', 'Software Architecture', 'SW Architectures',
                                                          'Software Engineering specialization', 'Software Coordinator', 'Software analyst',
                                                          'Software engineering', 'Systems Analysis'], 'Software Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['CBA em Gestão de TI e Ciência de Dados', 
                                                          'Data Cience specialization', 'Data Science', 
                                                          'Data Science Bootcamp / Udacity MLE Nanodegree', 
                                                          'Data Science Especialization', 
                                                          'Data Science Specialization', 'Data Science and ML',
                                                          'Data Science and Machine Learning',
                                                          'Data Science specialization', 
                                                          'Data Science, Aeroderivative Turbines, Database architecture', 'Data science and data engineer',
                                                          'Data science specialization', 'Especialização em Bases de Dados', 
                                                          'MBA EM BIG DATA (DATA SCIENCE)', 'MBA in Logistics, MBA in Data Science (USP - ICMC)',
                                                          'Post Grad in Data Science and Business Analytics', 
                                                          'Post Graduation in Data Science',
                                                          'data science', 'especialização em Ciência de Dados', 
                                                          'Web and Data Science, Finance and Accounting',
                                                          'Data Science and Statistics Computacional '], 'Data Science', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['MBA in Project Management',
                                                          'MBA - Gestão de Projetos', 
                                                          'Project Management Specialization',
                                                          'Projecto management ude', 
                                                          'Software implementation project manager', 
                                                          'project management specialization'], 'Project Management', 'eq')

replace_list_values_by_condition(df, 'D1_Specialization',['Machine Learning,NLP', 'machine learning', 'Time Series Forecasting '], 
                                 'Machine Learning', 'eq')
                                 
replace_list_values_by_condition(df, 'D1_Specialization',['Management', 'Management ', 'Managent Analytics', 'Business Data Analysis', 'CRM Specialization',
                                                          'MBA in Business Management', 'Business information ', 'Executive MBA'],
                                 'Business Management', 'eq')
                                 
replace_list_values_by_condition(df, 'D1_Specialization',['Mathematical Physics', 'Medical Physics'], 'Physics', 'eq')

# %%
indexes = list(df['D1_Specialization'].value_counts().index)
answers = list(df['D1_Specialization'].value_counts())
df_d1_specialization = pd.DataFrame(data={"Specialization": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_specialization,'Not Selected','Specialization')
remove_value(df_d1_specialization,'Others','Specialization')

# compute total of answer considered in this question
total_answers = "N = " + str(sum(df_d1_specialization['Answers']))


single_barplot(df_d1_specialization, "Answers", "Specialization", title="Top Specializations that participants have completed",
               x_label="Valid Answers", y_label="Specialization", color="#429bf5", total_answers=total_answers)

# %%
# replace values for master

replace_list_values_by_condition(df, 'D1_Master',['-', '-99', 'MBA', 'Pontifícia Universidade Católica', 'None', 'No', 'Nenhuma', 'Nenhuma ', 'CEFET/RJ', 
                                                  "I haven't", 'yes', 'M.Sc. in Engineering', 'Master in Engineering'], 'Not Selected', 'eq')
replace_list_values_by_condition(df, 'D1_Master',['Master in Computer Science²', 
                                                  'Master in Computer Science, MAster in MArketing and Trade Management',
                                                  'Master in CS', 'MSc in Computer Science, Parallel Computing',
                                                  'MSc in Computer Science', 'MSc Computer Science',
                                                  'MSC Computer Science', 'M.Sc.. in Algorithms, Graph Theory', 
                                                  'M.Sc. in informatic', 'computer science', 'computational modeling',
                                                  'Visual Computing M.Sc.', 'Computer Science Information and Security',
                                                  'Computer Systems', 'Computer Science, Business Administration, IT Project Management',
                                                  'Computer Science, Business Administration', 'Computer Science', 
                                                  'CS', 'Informatics', 'M.Sc. in Computer Science (due in march/2022)', 
                                                  'M.Sc. in Computer Science', 'M.Sc. in Applied Informatics', 
                                                  'M.Sc in Informatics', 'M.Sc in Computer Science', 'M. SC. Computer science',
                                                  'M,Sc. in Applied Computing', 'M.Sc. in Informatics'], 'Computer Science', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Information Technology', 'Information Engineering ', 'Information Engineering', 'M.Sc em Sistema de Informação',
                                                  'MSc in E-commerce and Internet Computing', 'Management information systems/ Computer Engineering', 
                                                  'Technology and Engineering Management master program', 'M.Sc. in MIS'], 'Information System', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['computer engineering','System and Computer Engineering, PESC/UFRJ ', 'Computer Engineering', 
                                                  'M.Sc. in Computer Engineering', 'M.Sc. in Computational/Civil Engineering'], 'Computer Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Master in Software Engineering', 'Software engineering', 
                                                  'Software Engineering and Management', 'Software Engineering'], 'Software Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Master in Business Administration', 'Management and Strategy', 'Master of Business Administration', 
                                                  'Business Informatics', 'M.Sc. in Business Administration', 'M.SC. in Business Administration'], 'Business and Management', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Master Electrical Engineering', 'M.Sc. in Electrical&Electronics Eng.', 'M.Sc. in Electrical and Electronics Engineering', 
                                                  'M.Sc. in Electrical and Electronics Engineer', 'Mestre em Engenharia Eletrônica e Computação',
                                                  'Eletrical Engennering', 'Electronics', 'Electrical Engineering', 'M.Sc. in Electrical Engineering at Federal University of Minas Gerais (UFMG)',
                                                  'Electrical & Computer Science'], 'Electrical Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['MSc in Big Data and Business Analytics', 'M.Sc. in Data Visualization', 'Data Science', 'M.Sc. Applied Data Analytics',
                                                  'M Sc in Data Science -ML models', 'M.Sc. in Data Science', 'Engineering and Management of Complex Systems - Machine Learning',
                                                  'M.Sc. in Data Science + M.Sc. in Finance', 'Big Data Analytics and the Management'], 'Data Science', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['MSc. in Computer Science in AI', 'Artificial Intelligence', 'M.Sc. in Artificial Intelligence', 
                                                  'M.Sc. in AI and Software Engineering', 'Autonomous intelligent systems', 'M.Sc. Robotics, Cognition, Intelligence', 
                                                  'M.Sc. in Knowledge Extraction'], 'Artificial Intelligence', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['M.Sc. in Theoretical Physics', 'Master in physics', 'Physics', 'Particle physics', 'Msc in Physics', 'M.Sc. Engineering Physics'], 'Physics', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Biostatistics', 'M.Sc Statistics ', 'Statistic and Optimization'], 'Statistics', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['M.Sc. in Economics', 'Economics'], 'Economics', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['M.Sc. in Operational Research', 'Operation Research an Data Science'], 'Operational Research', 'eq')

replace_list_values_by_condition(df, 'D1_Master',["technical mathematics, maître d'informatique", 'Mathematics', 'Applied Mathematics'], 'Mathematics', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Game Design'], 'Game Design', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['Chemical Engineering'], 'Chemical Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Master',['M.Sc. in Mechanical Engineering', 'Teleinformatics Engineering', 'Msc communication systems', 
                                                  'Mestrado em Engenharia de Produção', 'Mechanical Engineering and Computer Engineering',
                                                  'Masters in Industrial Engineering and Management', 'Doutorado em Ciência e Engenharia dos Materiais - UFSCar',
                                                  'Industrial Engineering', 'Complex Systems', 'Aerospace Engineering', 'M.Sc. in Control Engineering ', 
                                                  'M.Sc. in Cognitive Science', 'M.Sc Zoology', 'Logistics'], 'Others', 'eq')

# %%
indexes = list(df['D1_Master'].value_counts().index)
answers = list(df['D1_Master'].value_counts())
df_d1_master = pd.DataFrame(data={"Master": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_master,'Not Selected','Master')
remove_value(df_d1_master,'Others','Master')

# compute total of answer considered in this question
total_answers = "N = " + str(sum(df_d1_master['Answers']))

single_barplot(df_d1_master, "Answers", "Master", title="Top Masters that participants have completed",
               x_label="Valid Answers", y_label="Master",color="#429bf5", total_answers=total_answers)

# %%
# replace values for phd

replace_list_values_by_condition(df, 'D1_Phd',['-', '-99', 'no Ph D', "I haven't", 'Nenhuma ', 'No', 'None', 'student'], 'Not Selected', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Ph.D. in Computer Science', 'Ph.D. in Computer Science ', 
                                               'Ph.D. in Computer Science (machine learning)', 
                                               'Ph.D. in Computer Science and Mathematics (AI, Machine Learning, Data Mining)', 
                                               'Ph.D. in Informatics ', 'PhD computer Science', 'PhD in Computer Science', 
                                               'PhD in Computer Science, Symbolic Computation, Automated Theorem Proving', 
                                               'PhD in Computing Science and Telecomunications', 'computational modeling', 
                                               '[Ongoing] Ph.D. in Machine Learning', 'phd in computer science', 'Ph.D. in Algorithms, Graph Theory',
                                               'Computational Science', 'Computer Science', 'Computer Science Candidate', 'Computer Sciences', 
                                               'Computer science', 'Informatics, PPGI/UFRJ', 'PH.D in Informatics', 'Ph.D in Computer Science'], 'Computer Science', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Ph.D. in Information Technologies', 'Information Technologies', 'Information Technology'], 'Information Technology', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Computer Engineering', 'D.Sc. in Computational/Civil Engineering', 'Electrical & Computer Science'], 'Computer Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Ph.D. in Electrical and Electronics Engineering', 'Ph.D. Electrical Engineering', 
                                               'Electrical and Electronics Eng.', 'Ph. D. in Electrical Engineering at Federal University of Minas Gerais (UFMG)'], 'Electrical Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Physics', 'Ph.D in Theoretical Physics', 'Particle physics'], 'Physics', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['D.Sc. in Operational Research', 'Operations Research'], 'Operational Research', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Ph.D. in Mathematical Physics', 'Ph.D. in Mathematics', 'PhD math ', 'mathematics'], 'Mathematics', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['Ph.D. in Mechanical Engineering', 
                                               'Pós Doutorado em Engenharia Mecânica na área de Materiais e Processos de Fabricação - UNICAMP',
                                               'Mechanics and Numerical Simulation'], 'Mechanical Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Phd',['PhD Enginiering Mechatronics', 'Statistics, currently in progress', 'Tecn.Lic. in Software Engineering',
                                               'phd in Technical Sciences', 'Ph.D. in Astrophysics', 'Software Product Lines', 'Chemical Engineering', 
                                               'Control Engineering', 'Ph.D Biology'], 'Others', 'eq')

# %%
indexes = list(df['D1_Phd'].value_counts().index)
answers = list(df['D1_Phd'].value_counts())
df_d1_phd = pd.DataFrame(data={"PhD": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_phd,'Not Selected','PhD')
remove_value(df_d1_phd,'Others','PhD')

# compute total of answer considered in this question
total_answers = "N = " + str(sum(df_d1_phd['Answers']))

single_barplot(df_d1_phd, "Answers", "PhD", title="Top Ph. D that participants have completed",
               x_label="Valid Answers", y_label="Ph. D", color="#429bf5", total_answers=total_answers)

# %%
# replace values for courses
replace_list_values_by_condition(df, 'D1_Courses',['-', '-99', "I haven't", 'none', 'no other certifications', 'No', 'None', 'No certification', 'not applied'], 'Not Selected', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['Machine Learning on Coursera', 'Machine Learning course Coursera', 'Machine Learning by Andrew Ng',
                                                   'IA HCIA huawei, ML HCIA huawei, ML HCIA huawei nv2 ',
                                                   'I have completed some courses on ML and Data Science, mainly on Alura (a Brazilian e-learning platform) and less frequently on Udemy.',
                                                   'HCIA Machine Learning, HCIA Machine Learning NV2', 'Google introduction to ML', 'Google Professional ML Engineer Certification', 
                                                   'Microsoft Professional Program Data Science & ML specialization',
                                                   'Microsoft certifications: Microsoft - DAT203.2x  Principles of Machine Learning ,   DAT210x  Programming with Python for Data Science ',
                                                   'Udacity course on ML', 'Azure Machine Learning', 'BTH Masters Course in ML, Combient course in Applied Data Science',
                                                   'AWS Machine Learning Specialty', 'AWS Machine Learning', 'AWS Certified Machine Learning - Specialty', 'Coursera course on ML',
                                                   'Coursera IBM Data Science Specialization certificate, Coursera Andrew NG ML courses', 
                                                   'Various Coursera courses on ML'], 'Machine Learning', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['IBM Data science on Coursera ', 'Udacity Data Scientist', 'UC Berkeley Data Science (10-Week Course)',
                                                   'Several Coursera, Udacity and Microsoft Azure certificates on Data Science topics', 'Coursera - Data Scientist', 
                                                   'Certified Data scientist specialized in data analytics', 'Applied Data Science Camp',
                                                   'Coursera Data Science Professional Certificate', 
                                                   'Datacamp Data Scientist Path, Datacamp Data Analyst Path, Datacamp Machine Learning Engineer Path', 
                                                   'Data Science Specialications (Stanford, Harvard, Datacamp)',
                                                   'Datacamp DS With Python Track', 'Data science and machine learning with statistic and python - Udemy',
                                                   'Data science - Spark Academy', 'Data Scientist in Datacamp', 'Data Scientist Basic', 
                                                   'Data Science with R, Python, SQL Bootcamp', 'Data Science For All Graduate', 'Data Science Certification',
                                                   'Data Science', 'Coursera/edX courses on ML and data science', 'DS4A - Correlation One'], 'Data Science', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['Google Professional ML Engineer, Google Professional Data Engineer', 
                                                   'Google Professional ML Engineer and Data Engineer Certification', 
                                                   'Google Professional Data Engineer, Coursera ML, Coursera Tensorflow Developer',
                                                   'Google Cloud Professional Data Engineer'], 'Data Engineering', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['Google Cloud Certified Architect', 'Google Cloud'], 'Cloud Management', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['ITIL, PMP, Big Data analyze', 
                                                   'Data Science, Machine learning and Big Data specialization on Udemy'], 'Big Data', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['NVIDIA - Deep Learning for Computer Vision, NVIDIA - Deep Learning for Multiple Data Types, Coursera - Machine Learning from Andrew NG',
                                                   'Udacity Deep Learning Nanodegree, Udacity Data Engineer Nanodegree, Coursera Deep Learning Specialization, Azure Data Scientist Certification, Azure AI Engineer Certification',
                                                   'Deep Learning specialization on Coursera; NLP and DS Nanodegrees on Udacity', 
                                                   'Deep Learning Specialization (Coursera), Data Scientist NanoDegree (Udacity), Deep Learning NanoDegree (Udacity), Artificial Intelligence NanoDegree (Udacity)',
                                                   'Coursera (DeepLearning.ai)', 'Coursera Deep Learning Specialization',
                                                   'Coursera Deep Learning Specialization/ Datacamp Data Science Track ...',
                                                   'Coursera DeepLearning certification'], 'Deep Learning', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',["IBM AI Professional Certificate, Coursera Python for Everybody's Specialization, DeeplearingAI Coursera", 
                                                   'Azure Associate AI Engineer, Azure Data Science Associate', 
                                                   'Artificial Intelligence | Asian Institute of Management', 
                                                   'Artificial Intelligence applied to Geosciences at UFMG'], 'Artificial Intelligence', 'eq')

replace_list_values_by_condition(df, 'D1_Courses',['Certificação em Microstrategy', 'ADSCAMP', 
                                                   'Vários cursos in Coursera', 'Udemy, DataCamp, Coursera', 'Udemy x3', 'Udemy',
                                                   'Several courses on Datacamp', 'Several', 'Coursera ', 'Coursera', 'Courses'], 'Others', 'eq')

# %%
indexes = list(df['D1_Courses'].value_counts().index)
answers = list(df['D1_Courses'].value_counts())
df_d1_courses = pd.DataFrame(data={"Courses": indexes, 'Answers': answers})

# %%
# remove the undesirable one
remove_value(df_d1_courses,'Not Selected','Courses')
remove_value(df_d1_courses,'Others','Courses')

# compute total of answer considered in this question
total_answers = "N = " + str(sum(df_d1_courses['Answers']))

single_barplot(df_d1_courses, "Answers", "Courses", title="Top Courses that participants have completed",
               x_label="Valid Answers", y_label="Courses", color="#429bf5", total_answers=total_answers)
