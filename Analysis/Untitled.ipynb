# %%
import pandas as pd

# %%
df = pd.read_csv("data_project_851780_2022_05_02.csv", sep=";")

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'D1. For each level of education below, please specify the name(s) of the degree(s) / program(s) you have completed:',
#  'D1. For each level of education below, please specify the name(s) of the degree(s) / program(s) you have completed:.1',
#  'D1. For each level of education below, please specify the name(s) of the degree(s) / program(s) you have completed:.2',
#  'D1. For each level of education below, please specify the name(s) of the degree(s) / program(s) you have completed:.3',
#  'D1. For each level of education below, please specify the name(s) of the degree(s) / program(s) you have completed:.4',
#  'D1. For each level of education below, please specify the name(s) of the degree(s) / program(s) you have completed:.5',
#  'D2. Which country do you currently work in?',
#  'D3. What is the size of the organization you currently work for?',
# ...
