# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values
from ipynb.fs.full.plots import single_barplot

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %%
df_q10 = df.filter(regex='Q10')
df_q10.head()
# Out:
#   Q10_RE_Documentation_NotDocumented  Q10_RE_Documentation_VisionDocument  \
# 2                              quoted                          not quoted
# 3                          not quoted                              quoted
# 4                          not quoted                          not quoted
# 5                          not quoted                              quoted
# 6                          not quoted                          not quoted
#
#   Q10_RE_Documentation_RequirementsLists  Q10_RE_Documentation_GoalModels  \
# 2                              not quoted                      not quoted
# 3                              not quoted                      not quoted
# 4                              not quoted                      not quoted
# 5                                  quoted                      not quoted
# 6                                  quoted                      not quoted
#
#   Q10_RE_Documentation_UseCaseModels Q10_RE_Documentation_Prototypes   \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                             quoted                       not quoted
# 5                         not quoted                           quoted
# 6                             quoted                           quoted
#
#   Q10_RE_Documentation_UserStories Q10_RE_Documentation_BDDScenarios   \
# 2                       not quoted                         not quoted
# 3                       not quoted                         not quoted
# 4                           quoted                         not quoted
# 5                       not quoted                         not quoted
# 6                       not quoted                         not quoted
#
#   Q10_RE_Documentation_MLCanvas  Q10_RE_Documentation_Notebooks   \
# 2                     not quoted                      not quoted
# 3                     not quoted                      not quoted
# 4                     not quoted                      not quoted
# 5                     not quoted                      not quoted
# 6                     not quoted                          quoted
#
#   Q10_RE_Documentation_DataModels Q10_RE_Documentation_Others  \
# 2                      not quoted                  not quoted
# 3                      not quoted                  not quoted
# 4                          quoted                  not quoted
# 5                      not quoted                  not quoted
# 6                          quoted                  not quoted
#
#   Q10_RE_Documentation_Others_Free
# 2                                                -99
# 3                                                -99
# 4                                                -99
# 5                                                -99
# 6                                                -99

# %%
#Responses as others

df_q10_others = df_q10.filter(regex='Others')
df_q10_others

for c in df_q10_others.columns:
    print(c)
    print(df_q10_others[c].value_counts())
# Out:
# Q10_RE_Documentation_Others
# not quoted    179
# -77            82
# quoted         15
# Name: Q10_RE_Documentation_Others, dtype: int64
# Q10_RE_Documentation_Others_Free
# -99                                                                                       179
# -66                                                                                        82
# Notion/ Git hub                                                                             1
# Jira                                                                                        1
# Reporting via Jira & Confluence                                                             1
# limited docmentataion                                                                       1
# wiki                                                                                        1
# Meeting Notes, mostly                                                                       1
# Google Docs shared between stakeholders                                                     1
# Formal Documentation in Confluence for Models Validation and Audit (Internal/External)      1
# Design documents                                                                            1
# Confluence docs                                                                             1
# Confluence pages                                                                            1
# Design docs                                                                                 1
# Creating a  document in Confluence.                                                         1
# Mathematical Models                                                                         1
# Name: Q10_RE_Documentation_Others_Free                  , dtype: int64

# %%
# Pandas DataFrame [quoted per columns]

dict_q10 = {}
for c in df_q10.columns:
    if "Free" and "Others" not in c:
        role = c.split('_')
        dict_q10[role[3:][0]] = df_q10[c].value_counts()['quoted']

df_q10_quoted = pd.DataFrame(data={'Documentation': list(dict_q10.keys()), 'Answers': list(dict_q10.values())})
df_q10_quoted = df_q10_quoted.sort_values('Answers', ascending=False)
df_q10_quoted
# Out:
#          Documentation  Answers
# 9           Notebooks        66
# 6          UserStories       63
# 2   RequirementsLists        51
# 5          Prototypes        42
# 4        UseCaseModels       38
# 10          DataModels       34
# 0       NotDocumented        30
# 1       VisionDocument       29
# 3           GoalModels       29
# 8            MLCanvas        15
# 7        BDDScenarios         4

# %%
single_barplot(df_q10_quoted, "Answers", "Documentation",
               title="How were requirements typically documented in the ML-enabled system projects you participated in?",
               x_label="Count", y_label="Technique", x_label_rotation=0)

# %%
for other in list(df['Q10_RE_Documentation_Others_Free                  '].unique()):
    print(other)
# Out:
# -99
# Notion/ Git hub
# nan
# Jira
# Reporting via Jira & Confluence
# limited docmentataion
# wiki
# Meeting Notes, mostly
# Google Docs shared between stakeholders
# Formal Documentation in Confluence for Models Validation and Audit (Internal/External)
# Design documents
# Confluence docs
# Confluence pages
# Design docs
# Creating a  document in Confluence.
# Mathematical Models
# -66
