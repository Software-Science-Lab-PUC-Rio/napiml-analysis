# %%
import pandas as pd
from ipynb.fs.full.utils import get_df, rename_values
from ipynb.fs.full.plots import single_barplot

# %%
# get formatted and ready to use dataframe
df = get_df()

# %%
df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %%
df_q9 = df.filter(regex='Q9')
df_q9.head()
# Out:
#   Q9_RE_Elicitation_Interviews  Q9_RE_Elicitation_Scenarios   \
# 2                    not quoted                   not quoted
# 3                    not quoted                       quoted
# 4                        quoted                       quoted
# 5                        quoted                   not quoted
# 6                        quoted                       quoted
#
#   Q9_RE_Elicitation_Prototyping  Q9_RE_Elicitation_WorkshopsMeetings   \
# 2                         quoted                           not quoted
# 3                     not quoted                           not quoted
# 4                     not quoted                               quoted
# 5                         quoted                           not quoted
# 6                         quoted                               quoted
#
#   Q9_RE_Elicitation_Observation Q9_RE_Elicitation_Others  \
# 2                    not quoted               not quoted
# 3                    not quoted               not quoted
# 4                    not quoted                   quoted
# 5                    not quoted               not quoted
# 6                    not quoted               not quoted
#
#   Q9_RE_Elicitation_Others_Free
# 2                                             -99
# 3                                             -99
# 4                                      Literature
# 5                                             -99
# 6                                             -99

# %%
#Responses as others

df_q9_others = df_q9.filter(regex='Others')
df_q9_others

for c in df_q9_others.columns:
    print(c)
    print(df_q9_others[c].value_counts())
# Out:
# Q9_RE_Elicitation_Others
# not quoted    183
# -77            82
# quoted         11
# Name: Q9_RE_Elicitation_Others, dtype: int64
# Q9_RE_Elicitation_Others_Free
# -99                                                         183
# -66                                                          82
# Literature                                                    1
# Beer please                                                   1
# meetings with stakeholders                                    1
# simulating system's behavior                                  1
# They were not really, invented                                1
# Wishful thinking in the project proposal                      1
# Squad's OKRs                                                  1
# I don't know                                                  1
# analysis of artifacts                                         1
# by submitting my undergraduate thesis to the institution      1
# Name: Q9_RE_Elicitation_Others_Free                  , dtype: int64

# %%
# Pandas DataFrame [quoted per columns]

dict_q9 = {}
for c in df_q9.columns:
    if "Free" and "Others" not in c:
        role = c.split('_')
        dict_q9[role[3:][0]] = df_q9[c].value_counts()['quoted']

df_q9_quoted = pd.DataFrame(data={'Elicitation': list(dict_q9.keys()), 'Answers': list(dict_q9.values())})
df_q9_quoted = df_q9_quoted.sort_values('Answers', ascending=False)
df_q9_quoted
# Out:
#           Elicitation  Answers
# 0         Interviews        97
# 1          Scenarios        75
# 2        Prototyping        75
# 3  WorkshopsMeetings        74
# 4         Observation       64

# %%
single_barplot(df_q9_quoted, "Answers", "Elicitation",
               title="How were requirements typically elicited in the ML-enabled system projects you participated in?",
               x_label="Count", y_label="Technique", x_label_rotation=0)

# %%
for other in list(df['Q9_RE_Elicitation_Others_Free                  '].unique()):
    print(other)
# Out:
# -99
# Literature
# Beer please
# meetings with stakeholders
# nan
# simulating system's behavior
# They were not really, invented
# Wishful thinking in the project proposal
# Squad's OKRs
# I don't know
# analysis of artifacts
# by submitting my undergraduate thesis to the institution
# -66
