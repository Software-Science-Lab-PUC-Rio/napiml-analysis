# %% [markdown]
# # Question Q4: Practitioners Main Problems on Problem Understanding and Requirements Stage

# %% [markdown]
# *Question*: According to your personal experience, please outline the main problems or difficulties (up to three) faced during each of the seven ML life cycle stages.

# %% [markdown]
# *Answer Type*: Text Free

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Initialization
#
# Here we get a formatted Pandas DataFrame from a raw CSV containing the Survey responses. When formatting, we discard unused columns and renames existing ones to more clear names. We created two classes that help us manage this dataframe and create meaningful charts.

# %%
dataframe_obj = DataframeUtils(df_path='./data/main_data.csv', sep=';',
                               to_discard_columns_file='./data/unused_columns.txt',
                               to_format_columns_file='./data/formatted_columns.txt')
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# In this research, we conservatively considered those who fully completed the survey. So, we discarded suspended submissions.

# %%
dataframe_obj.df.drop(dataframe_obj.df[dataframe_obj.df['Status'] == 'Suspended (22)'].index, inplace = True)

# %%
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Grounded Theory
#
# Here we get a formatted Pandas DataFrame from an Excel file containing the codes and categorization of our qualitative responses.

# %%
qualitative_df = pd.read_excel('./data/Problems on ML Stages/PROBLEM UNDERSTANDING.xlsx')
qualitative_df.head()
# Out:
#   lfdn             PROBLEM UNDERSTANDING AND REQUIREMENTS  \
# 0   31  Client often don't know what they want to lear...
# 1   36                        Learning the problem domain
# 2   46  understand the pain and identify if ML is real...
# 3   53                         not know about the problem
# 4   64  understand the context: domain, what decisions...
#
#                            TOPIC CATEGORY
# 0          PROBLEM UNDERSTANDING    INPUT
# 1  BUSINESS/DOMAIN UNDERSTANDING    INPUT
# 2          PROBLEM UNDERSTANDING    INPUT
# 3          PROBLEM UNDERSTANDING    INPUT
# 4          PROBLEM UNDERSTANDING    INPUT

# %% [markdown]
# ### Basic Analysis

# %%
# get our valid respondents ids
respondents_ids = list(dataframe_obj.df['ID'])
respondents_ids = [int(respondent_id) for respondent_id in respondents_ids]
respondents_ids[:5]
# Out:
# [31, 34, 36, 57, 46]

# %%
# discard the ids that are suspended
qualitative_df = qualitative_df[qualitative_df['lfdn'].isin(respondents_ids)][['PROBLEM UNDERSTANDING AND REQUIREMENTS', 'TOPIC', 'CATEGORY']]

# %%
# get a list with all the reported categories
category_column = list(qualitative_df['CATEGORY'])
category_column[:5]
# Out:
# ['INPUT', 'INPUT', 'INPUT', 'INPUT', 'INPUT']

# %%
# compute the total of answers that belong to each category
total_per_category_df = qualitative_df[['CATEGORY', 'TOPIC']].groupby(['CATEGORY']).count()
total_per_category_df
# Out:
#                 TOPIC
# CATEGORY
# DATA                6
# INFRASTRUCTURE      4
# INPUT             135
# METHOD             61
# ORGANIZATION       43

# %%
# get the total of qualitative answers
total_answers = total_per_category_df['TOPIC'].sum()
print(f'The total of qualitative answers to be considered is {total_answers}')
# Out:
# The total of qualitative answers to be considered is 249

# %%
# we create two lists that contain, for each category, the total of qualitative answers and their percentage
category_percentage = []
category_total = []
# note that we will have repeated values, once we are creating lists with the same length of the column 'CATEGORY' in the qualitative dataframe
for category in category_column:
    category_percentage.append(round(total_per_category_df.loc[category]['TOPIC'] / total_answers * 100, 2))
    category_total.append(total_per_category_df.loc[category]['TOPIC'])

# %%
# include two new columns to our qualitative dataframe
qualitative_df['CATEGORY_TOTAL'] = category_total
qualitative_df['CATEGORY_%'] = category_percentage
qualitative_df.head()
# Out:
#               PROBLEM UNDERSTANDING AND REQUIREMENTS  \
# 0  Client often don't know what they want to lear...
# 1                        Learning the problem domain
# 2  understand the pain and identify if ML is real...
# 3                         not know about the problem
# 4  understand the context: domain, what decisions...
#
#                            TOPIC CATEGORY  CATEGORY_TOTAL  CATEGORY_%
# 0          PROBLEM UNDERSTANDING    INPUT             135       54.22
# 1  BUSINESS/DOMAIN UNDERSTANDING    INPUT             135       54.22
# 2          PROBLEM UNDERSTANDING    INPUT             135       54.22
# 3          PROBLEM UNDERSTANDING    INPUT             135       54.22
# 4          PROBLEM UNDERSTANDING    INPUT             135       54.22

# %%
# now we group our results considering the category and the topic
qualitative_df = qualitative_df.groupby(['CATEGORY', 'CATEGORY_TOTAL', 'CATEGORY_%', 'TOPIC']).count()

# %%
# rename the remaining column, which is now a simple count representing the quantity of each category and topic
qualitative_df.columns = ['QUANTITY']
# add the percentage version of each quantity to improve readability
qualitative_df['QUANTITY_%'] = round(qualitative_df['QUANTITY'] / qualitative_df['QUANTITY'].sum() * 100, 2)
qualitative_df
# Out:
#                                                                                            QUANTITY  \
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           6              2.41       DATA AVAILABILITY                                        2
#                                          DATA COLLECTION                                          1
#                                          DATA PREPROCESSING                                       1
#                                          DATA QUALITY                                             2
# INFRASTRUCTURE 4              1.61       COMPUTATIONAL CONSTRAINTS                                4
# INPUT          135            54.22      BALANCING RISKS AND BENEFITS                             1
#                                          BUSINESS/DOMAIN UNDERSTANDING                           29
#                                          DEFINING/DOCUMENTING REQUIREMENTS                        6
#                                          DIFFICULTIES IN VALUE CREATION                           1
#                                          DOMAIN COMPLEXITY                                        1
#                                          INCOMPLETE/INCORRECT REQUIREMENTS                        5
#                                          PROBLEM UNDERSTANDING                                   56
#                                          REQUIREMENTS OVERTHINKING                                1
#                                          SCOPE DEFINITION                                         4
#                                          STRATEGIC ALIGNMENTS                                     1
#                                          UNCLEAR GOALS                                           17
#                                          UNCLEAR REQUIREMENTS                                    13
# METHOD         61             24.50      ACCURACY CHECKING                                        1
#                                          COMMUNICATION                                           17
#                                          DATA SCIENCE COMPLEXITY                                  3
#                                          END TO END PROCESS                                       1
#                                          ESTIMATION ISSUES                                        1
#                                          LACK OF DATA SCIENCE KNOWLEDGE                           5
#                                          MANAGING EXPECTATIONS                                   29
#                                          METHOD                                                   1
#                                          MODEL EVALUATION METRIC CHOICE                           1
#                                          PROJECT                                                  1
#                                          SOLUTION UNIQUENESS                                      1
# ORGANIZATION   43             17.27      DATA SCIENCE COMPLEXITY                                  1
#                                          DEFINITION OF ROLES AND RESPONSIBILITIES                 1
#                                          FINANCIAL ISSUES                                         2
#                                          LACK OF ANALYTICAL THINKING                              1
#                                          LACK OF RESOURCES AND REFERENCES                         4
#                                          LACK OF TIME                                             8
#                                          LOW CLIENT/DOMAIN EXPERT AVAILABILITY/ENGAGEMENT        25
#                                          NO DATA DRIVEN PRIORITY                                  1
#
#                                                                                            QUANTITY_%
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           6              2.41       DATA AVAILABILITY                                       0.80
#                                          DATA COLLECTION                                         0.40
#                                          DATA PREPROCESSING                                      0.40
#                                          DATA QUALITY                                            0.80
# INFRASTRUCTURE 4              1.61       COMPUTATIONAL CONSTRAINTS                               1.61
# INPUT          135            54.22      BALANCING RISKS AND BENEFITS                            0.40
#                                          BUSINESS/DOMAIN UNDERSTANDING                          11.65
#                                          DEFINING/DOCUMENTING REQUIREMENTS                       2.41
#                                          DIFFICULTIES IN VALUE CREATION                          0.40
#                                          DOMAIN COMPLEXITY                                       0.40
#                                          INCOMPLETE/INCORRECT REQUIREMENTS                       2.01
#                                          PROBLEM UNDERSTANDING                                  22.49
#                                          REQUIREMENTS OVERTHINKING                               0.40
#                                          SCOPE DEFINITION                                        1.61
#                                          STRATEGIC ALIGNMENTS                                    0.40
#                                          UNCLEAR GOALS                                           6.83
#                                          UNCLEAR REQUIREMENTS                                    5.22
# METHOD         61             24.50      ACCURACY CHECKING                                       0.40
#                                          COMMUNICATION                                           6.83
#                                          DATA SCIENCE COMPLEXITY                                 1.20
#                                          END TO END PROCESS                                      0.40
#                                          ESTIMATION ISSUES                                       0.40
#                                          LACK OF DATA SCIENCE KNOWLEDGE                          2.01
#                                          MANAGING EXPECTATIONS                                  11.65
#                                          METHOD                                                  0.40
#                                          MODEL EVALUATION METRIC CHOICE                          0.40
#                                          PROJECT                                                 0.40
#                                          SOLUTION UNIQUENESS                                     0.40
# ORGANIZATION   43             17.27      DATA SCIENCE COMPLEXITY                                 0.40
#                                          DEFINITION OF ROLES AND RESPONSIBILITIES                0.40
#                                          FINANCIAL ISSUES                                        0.80
#                                          LACK OF ANALYTICAL THINKING                             0.40
#                                          LACK OF RESOURCES AND REFERENCES                        1.61
#                                          LACK OF TIME                                            3.21
#                                          LOW CLIENT/DOMAIN EXPERT AVAILABILITY/ENGAGEMENT       10.04
#                                          NO DATA DRIVEN PRIORITY                                 0.40
