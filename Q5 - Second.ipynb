# %% [markdown]
# # Second Problems that most likely lead to Project Failure

# %% [markdown]
# *Question*: Regarding the problems listed in previous question, please rank the ones (up to three) that most likely lead to ooverall project failur.

# %% [markdown]
# *Answer Type*: Text Free

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Initialization
#
# Here we get a formatted Pandas DataFrame from a raw CSV containing the Survey responses. When formatting, we discard unused columns and renames existing ones to more clear names. We created two classes that help us manage this dataframe and create meaningful charts.

# %%
dataframe_obj = DataframeUtils(df_path='./data/main_data.csv', sep=';',
                               to_discard_columns_file='./data/unused_columns.txt',
                               to_format_columns_file='./data/formatted_columns.txt')
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %%
# For PROFES, we discarded suspended submissions (e.g., remove those who didn't complete the survey).
dataframe_obj.df.drop(dataframe_obj.df[dataframe_obj.df['Status'] == 'Suspended (22)'].index, inplace = True)

# %%
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Grounded Theory
#
# Here we get a formatted Pandas DataFrame from an Excel file containing the codes and categorization of our qualitative responses.

# %%
qualitative_df = pd.read_excel('./data/Problems on ML Stages/PROJECT FAILURE - SECOND.xlsx')
qualitative_df.head()
# Out:
#    lfdn                                        Q5 - SECOND  \
# 0    31               Others tasks which competes the time
# 1    36                     Prediction Task identification
# 2    46  we need to cut or we need to cluster some kind...
# 3    53                                   apply the models
# 4    58                           Sufficient Data Quantity
#
#                           TOPIC      CATEGORY
# 0                  LACK OF TIME  ORGANIZATION
# 1  MODEL SELECTION AND CREATION        METHOD
# 2         PROBLEM UNDERSTANDING         INPUT
# 3  MODEL SELECTION AND CREATION        METHOD
# 4             INSUFFICIENT DATA          DATA

# %% [markdown]
# ### Basic Analysis

# %%
# get our respondents ids
respondents_ids = list(dataframe_obj.df['ID'])
respondents_ids = [int(respondent_id) for respondent_id in respondents_ids]
respondents_ids[:5]
# Out:
# [31, 34, 36, 57, 46]

# %%
# discard the ids
qualitative_df = qualitative_df[qualitative_df['lfdn'].isin(respondents_ids)][['Q5 - SECOND', 'TOPIC', 'CATEGORY']]

# %%
# get a list with all the reported categories
category_column = list(qualitative_df['CATEGORY'])
category_column[:5]
# Out:
# ['ORGANIZATION', 'METHOD', 'INPUT', 'METHOD', 'DATA']

# %%
# compute the total of answers that belong to each category
total_per_category_df = qualitative_df[['CATEGORY', 'TOPIC']].groupby(['CATEGORY']).count()
total_per_category_df
# Out:
#                 TOPIC
# CATEGORY
# DATA               58
# INFRASTRUCTURE      9
# INPUT              21
# METHOD             28
# ORGANIZATION       23
# PEOPLE              2

# %%
# get the total of qualitative answers
total_answers = total_per_category_df['TOPIC'].sum()
print(f'The total of qualitative answers to be considered is {total_answers}')
# Out:
# The total of qualitative answers to be considered is 141

# %%
# we create two lists that contain, for each category, the total of qualitative answers and their percentage
category_percentage = []
category_total = []
# note that we will have repeated values, once we are creating lists with the same length of the column 'CATEGORY' in the qualitative dataframe
for category in category_column:
    category_percentage.append(round(total_per_category_df.loc[category]['TOPIC'] / total_answers * 100, 2))
    category_total.append(total_per_category_df.loc[category]['TOPIC'])

# %%
# include two new columns to our qualitative dataframe
qualitative_df['CATEGORY_TOTAL'] = category_total
qualitative_df['CATEGORY_%'] = category_percentage
qualitative_df.head()
# Out:
#                                          Q5 - SECOND  \
# 0               Others tasks which competes the time
# 1                     Prediction Task identification
# 2  we need to cut or we need to cluster some kind...
# 3                                   apply the models
# 4                           Sufficient Data Quantity
#
#                           TOPIC      CATEGORY  CATEGORY_TOTAL  CATEGORY_%
# 0                  LACK OF TIME  ORGANIZATION              23       16.31
# 1  MODEL SELECTION AND CREATION        METHOD              28       19.86
# 2         PROBLEM UNDERSTANDING         INPUT              21       14.89
# 3  MODEL SELECTION AND CREATION        METHOD              28       19.86
# 4             INSUFFICIENT DATA          DATA              58       41.13

# %%
# now we group our results considering the category and the topic
qualitative_df = qualitative_df.groupby(['CATEGORY', 'CATEGORY_TOTAL', 'CATEGORY_%', 'TOPIC']).count()

# %%
# rename the remaining column, which is now a simple count representing the quantity of each category and topic
qualitative_df.columns = ['QUANTITY']
# add the percentage version of each quantity to improve readability
qualitative_df['QUANTITY_%'] = round(qualitative_df['QUANTITY'] / qualitative_df['QUANTITY'].sum() * 100, 2)
qualitative_df
# Out:
#                                                                              QUANTITY  \
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           58             41.13      DATA AVAILABILITY                          5
#                                          DATA COLLECTION                           20
#                                          DATA PREPROCESSING                         8
#                                          DATA QUALITY                              10
#                                          DATA UNDERSTANDING                         1
#                                          INSUFFICIENT DATA                         14
# INFRASTRUCTURE 9              6.38       COMPUTATIONAL CONSTRAINTS                  2
#                                          DEPLOYMENT INFRASTRUCTURE                  4
#                                          MODEL DEPLOYMENT                           2
#                                          MODEL MONITORING                           1
# INPUT          21             14.89      INCOMPLETE/INCORRECT REQUIREMENTS          5
#                                          LACK OF DOMAIN KNOWLEDGE                   3
#                                          PROBLEM UNDERSTANDING                     13
# METHOD         28             19.86      CHOOSE AND EVALUATE THE METRICS            5
#                                          ERROR HANDLING                             1
#                                          FEATURE ENGINEERING                        1
#                                          HYPERPARAMETER TUNING                      2
#                                          INSUFFICIENT/UNACCEPTABLE RESULTS          2
#                                          MANAGING EXPECTATIONS                      3
#                                          MODEL EVALUATION                           2
#                                          MODEL SELECTION AND CREATION               8
#                                          MODEL UNDERSTANDING                        1
#                                          MODEL UPDATE                               1
#                                          SECURITY                                   1
#                                          TECHNICAL DEBT                             1
# ORGANIZATION   23             16.31      INSUFFICIENT CLIENT SUPPORT               14
#                                          LACK OF TIME                               7
#                                          PRIORITIZING ISSUES                        2
# PEOPLE         2              1.42       LACK OF DATA SCIENCE KNOWLEDGE             2
#
#                                                                              QUANTITY_%
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           58             41.13      DATA AVAILABILITY                         3.55
#                                          DATA COLLECTION                          14.18
#                                          DATA PREPROCESSING                        5.67
#                                          DATA QUALITY                              7.09
#                                          DATA UNDERSTANDING                        0.71
#                                          INSUFFICIENT DATA                         9.93
# INFRASTRUCTURE 9              6.38       COMPUTATIONAL CONSTRAINTS                 1.42
#                                          DEPLOYMENT INFRASTRUCTURE                 2.84
#                                          MODEL DEPLOYMENT                          1.42
#                                          MODEL MONITORING                          0.71
# INPUT          21             14.89      INCOMPLETE/INCORRECT REQUIREMENTS         3.55
#                                          LACK OF DOMAIN KNOWLEDGE                  2.13
#                                          PROBLEM UNDERSTANDING                     9.22
# METHOD         28             19.86      CHOOSE AND EVALUATE THE METRICS           3.55
#                                          ERROR HANDLING                            0.71
#                                          FEATURE ENGINEERING                       0.71
#                                          HYPERPARAMETER TUNING                     1.42
#                                          INSUFFICIENT/UNACCEPTABLE RESULTS         1.42
#                                          MANAGING EXPECTATIONS                     2.13
#                                          MODEL EVALUATION                          1.42
#                                          MODEL SELECTION AND CREATION              5.67
#                                          MODEL UNDERSTANDING                       0.71
#                                          MODEL UPDATE                              0.71
#                                          SECURITY                                  0.71
#                                          TECHNICAL DEBT                            0.71
# ORGANIZATION   23             16.31      INSUFFICIENT CLIENT SUPPORT               9.93
#                                          LACK OF TIME                              4.96
#                                          PRIORITIZING ISSUES                       1.42
# PEOPLE         2              1.42       LACK OF DATA SCIENCE KNOWLEDGE            1.42

# %%
df = qualitative_df['QUANTITY_%'].copy()
df.index = qualitative_df.index.get_level_values('TOPIC')
for key, val in zip(list(df.keys()), list(df)):
    print(f"{key.lower()} ({val} %)")
# Out:
# data availability (3.55 %)
# data collection (14.18 %)
# data preprocessing (5.67 %)
# data quality (7.09 %)
# data understanding (0.71 %)
# insufficient data (9.93 %)
# computational constraints (1.42 %)
# deployment infrastructure (2.84 %)
# model deployment (1.42 %)
# model monitoring (0.71 %)
# incomplete/incorrect requirements (3.55 %)
# lack of domain knowledge (2.13 %)
# problem understanding (9.22 %)
# choose and evaluate the metrics (3.55 %)
# error handling (0.71 %)
# feature engineering (0.71 %)
# hyperparameter tuning (1.42 %)
# insufficient/unacceptable results  (1.42 %)
# managing expectations (2.13 %)
# model evaluation (1.42 %)
# model selection and creation (5.67 %)
# model understanding (0.71 %)
# model update (0.71 %)
# security (0.71 %)
# technical debt (0.71 %)
# insufficient client support (9.93 %)
# lack of time (4.96 %)
# prioritizing issues (1.42 %)
# lack of data science knowledge (1.42 %)
