# %% [markdown]
# # Third Problems that most likely lead to Project Failure

# %% [markdown]
# *Question*: Regarding the problems listed in previous question,
# please rank the ones (up to three) that most likely lead t
# overall project failur.

# %% [markdown]
# *Answer Type*: Text Free

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Initialization
#
# Here we get a formatted Pandas DataFrame from a raw CSV containing the Survey responses. When formatting, we discard unused columns and renames existing ones to more clear names. We created two classes that help us manage this dataframe and create meaningful charts.

# %%
dataframe_obj = DataframeUtils(df_path='./data/main_data.csv', sep=';',
                               to_discard_columns_file='./data/unused_columns.txt',
                               to_format_columns_file='./data/formatted_columns.txt')
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %%
# For PROFES, we discarded suspended submissions (e.g., remove those who didn't complete the survey).
dataframe_obj.df.drop(dataframe_obj.df[dataframe_obj.df['Status'] == 'Suspended (22)'].index, inplace = True)

# %%
# dataframe preview
dataframe_obj.df.head()
# Out:
#    ID          Status Duration D1_Undergraduation  \
# 2  31  Completed (31)     1317          Economics
# 3  34  Completed (31)      854                -99
# 4  36  Completed (31)     1593        Mathematics
# 5  57  Completed (31)     4238   Computer Science
# 6  46  Completed (31)     2821  Actuarial Science
#
#                  D1_Specialization                        D1_Master  \
# 2                              -99               M.Sc. in Economics
# 3                      Management                                No
# 4                      Informatics             MSC Computer Science
# 5      Data science specialization                              -99
# 6  Post Graduation in Data Science  M Sc in Data Science -ML models
#
#                  D1_Phd                  D1_Courses D1_Others D2_Country  ...  \
# 2                   -99  Data Scientist in Datacamp       -99     Brazil  ...
# 3                    No                          No        No     Brazil  ...
# 4  PhD computer Science   Vários cursos in Coursera       -99     Brazil  ...
# 5                   -99                         -99       -99    Germany  ...
# 6               no Ph D     no other certifications       -99     Brazil  ...
#
#   Q15_Model_Deploy_Production_Monitoring  \
# 2                                    -77
# 3                                     70
# 4                                     60
# 5                                    100
# 6                                     80
#
#   Q16_Model_Monitor_Aspects_Input_And_Output  \
# 2                                 not quoted
# 3                                 not quoted
# 4                                     quoted
# 5                                 not quoted
# 6                                 not quoted
#
#   Q16_Model_Monitor_Aspects_Interpretability_Output  \
# 2                                        not quoted
# 3                                        not quoted
# 4                                        not quoted
# 5                                            quoted
# 6                                            quoted
#
#   Q16_Model_Monitor_Aspects_Output_And_Decisions  \
# 2                                     not quoted
# 3                                         quoted
# 4                                         quoted
# 5                                         quoted
# 6                                         quoted
#
#   Q16_Model_Monitor_Aspects_Fairness Q16_Model_Monitor_Aspects_Others  \
# 2                         not quoted                       not quoted
# 3                         not quoted                       not quoted
# 4                         not quoted                       not quoted
# 5                         not quoted                       not quoted
# 6                         not quoted                       not quoted
#
#   Q16_Model_Monitor_Aspects_Others_Free  \
# 2                                   -99
# 3                                   -99
# 4                                   -99
# 5                                   -99
# 6                                   -99
#
#   Q17_Automated_Machine_Learning_Tools_Yes_No  \
# 2                                           0
# 3                                          No
# 4                        Yes, Please, specify
# 5                                          No
# 6                                          No
#
#   Q17_Automated_Machine_Learning_Tools_Yes_Free  \
# 2                                           -99
# 3                                           -99
# 4                                  Own approach
# 5                                           -99
# 6                                           -99
#
#                             Origin
# 2  https://ww2.unipark.de/uc/seml/
# 3                              -99
# 4                              -99
# 5                              -99
# 6                              -99
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Grounded Theory
#
# Here we get a formatted Pandas DataFrame from an Excel file containing the codes and categorization of our qualitative responses.

# %%
qualitative_df = pd.read_excel('./data/Problems on ML Stages/PROJECT FAILURE - THIRD.xlsx')
qualitative_df.head()
# Out:
#    lfdn                                         Q5 - THIRD  \
# 0    31                 Search the appropriate methodology
# 1    36                        Selecionar of learning algo
# 2    46  present and discuss metrics and distribution o...
# 3    53                          Not knowing how to deploy
# 4    58       Deployment Costs for non-trivial ML projects
#
#                              TOPIC        CATEGORY
# 0     MODEL CREATION AND SELECTION          METHOD
# 1     MODEL CREATION AND SELECTION          METHOD
# 2  CHOOSE AND EVALUATE THE METRICS          METHOD
# 3        DEPLOYMENT INFRASTRUCTURE  INFRASTRUCTURE
# 4        DEPLOYMENT INFRASTRUCTURE  INFRASTRUCTURE

# %% [markdown]
# ### Basic Analysis

# %%
# get our respondents ids
respondents_ids = list(dataframe_obj.df['ID'])
respondents_ids = [int(respondent_id) for respondent_id in respondents_ids]
respondents_ids[:5]
# Out:
# [31, 34, 36, 57, 46]

# %%
# discard the ids
qualitative_df = qualitative_df[qualitative_df['lfdn'].isin(respondents_ids)][['Q5 - THIRD', 'TOPIC', 'CATEGORY']]

# %%
# get a list with all the reported categories
category_column = list(qualitative_df['CATEGORY'])
category_column[:5]
# Out:
# ['METHOD', 'METHOD', 'METHOD', 'INFRASTRUCTURE', 'INFRASTRUCTURE']

# %%
# compute the total of answers that belong to each category
total_per_category_df = qualitative_df[['CATEGORY', 'TOPIC']].groupby(['CATEGORY']).count()
total_per_category_df
# Out:
#                 TOPIC
# CATEGORY
# DATA               23
# INFRASTRUCTURE     25
# INPUT               8
# METHOD             40
# ORGANIZATION        7
# PEOPLE              7

# %%
# get the total of qualitative answers
total_answers = total_per_category_df['TOPIC'].sum()
print(f'The total of qualitative answers to be considered is {total_answers}')
# Out:
# The total of qualitative answers to be considered is 110

# %%
# we create two lists that contain, for each category, the total of qualitative answers and their percentage
category_percentage = []
category_total = []
# note that we will have repeated values, once we are creating lists with the same length of the column 'CATEGORY' in the qualitative dataframe
for category in category_column:
    category_percentage.append(round(total_per_category_df.loc[category]['TOPIC'] / total_answers * 100, 2))
    category_total.append(total_per_category_df.loc[category]['TOPIC'])

# %%
# include two new columns to our qualitative dataframe
qualitative_df['CATEGORY_TOTAL'] = category_total
qualitative_df['CATEGORY_%'] = category_percentage
qualitative_df.head()
# Out:
#                                           Q5 - THIRD  \
# 0                 Search the appropriate methodology
# 1                        Selecionar of learning algo
# 2  present and discuss metrics and distribution o...
# 3                          Not knowing how to deploy
# 4       Deployment Costs for non-trivial ML projects
#
#                              TOPIC        CATEGORY  CATEGORY_TOTAL  CATEGORY_%
# 0     MODEL CREATION AND SELECTION          METHOD              40       36.36
# 1     MODEL CREATION AND SELECTION          METHOD              40       36.36
# 2  CHOOSE AND EVALUATE THE METRICS          METHOD              40       36.36
# 3        DEPLOYMENT INFRASTRUCTURE  INFRASTRUCTURE              25       22.73
# 4        DEPLOYMENT INFRASTRUCTURE  INFRASTRUCTURE              25       22.73

# %%
# now we group our results considering the category and the topic
qualitative_df = qualitative_df.groupby(['CATEGORY', 'CATEGORY_TOTAL', 'CATEGORY_%', 'TOPIC']).count()

# %%
# rename the remaining column, which is now a simple count representing the quantity of each category and topic
qualitative_df.columns = ['QUANTITY']
# add the percentage version of each quantity to improve readability
qualitative_df['QUANTITY_%'] = round(qualitative_df['QUANTITY'] / qualitative_df['QUANTITY'].sum() * 100, 2)
qualitative_df
# Out:
#                                                                                            QUANTITY  \
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           23             20.91      DATA ACCESSIBILITY                                       1
#                                          DATA AVAILABILITY                                        1
#                                          DATA COLLECTION                                          3
#                                          DATA PREPROCESSING                                       9
#                                          DATA QUALITY                                             4
#                                          INSUFFICIENT DATA                                        5
# INFRASTRUCTURE 25             22.73      COMPUTATIONAL CONSTRAINTS                                5
#                                          DEPLOYMENT INFRASTRUCTURE                               15
#                                          INTEGRATION                                              1
#                                          MODEL MONITORING                                         2
#                                          SCALABILITY                                              2
# INPUT          8              7.27       INCOMPLETE/INCORRECT REQUIREMENTS                        4
#                                          LACK OF DOMAIN KNOWLEDGE                                 1
#                                          PROBLEM UNDERSTANDING                                    2
#                                          UNCLEAR GOALS                                            1
# METHOD         40             36.36      BUILD PIPELINES                                          2
#                                          CHOOSE AND EVALUATE THE METRICS                         13
#                                          CODE QUALITY                                             1
#                                          COMMUNICATION                                            1
#                                          FEATURE ENGINEERING                                      1
#                                          HYPERPARAMETER TUNING                                    3
#                                          MODEL CREATION AND SELECTION                            12
#                                          MODEL SCALABILITY                                        1
#                                          MODEL UPDATE                                             2
#                                          OVERFITTING AND UNDERFITTING                             2
#                                          UI                                                       1
#                                          USER ACCEPTANCE TEST                                     1
# ORGANIZATION   7              6.36       CHANGE MANAGEMENT                                        1
#                                          DEFINITION OF ROLES AND RESPONSIBILITIES                 1
#                                          FINANCIAL ISSUES                                         1
#                                          LACK OF TIME                                             1
#                                          LOW CLIENT/DOMAIN EXPERT AVAILABILITY/ENGAGEMENT         2
#                                          TEAM INTEGRATION                                         1
# PEOPLE         7              6.36       LACK OF DATA SCIENCE KNOWLEDGE                           3
#                                          LACK OF KNOWLEDGE                                        1
#                                          LACK OF TALENT/SKILL                                     3
#
#                                                                                            QUANTITY_%
# CATEGORY       CATEGORY_TOTAL CATEGORY_% TOPIC
# DATA           23             20.91      DATA ACCESSIBILITY                                      0.91
#                                          DATA AVAILABILITY                                       0.91
#                                          DATA COLLECTION                                         2.73
#                                          DATA PREPROCESSING                                      8.18
#                                          DATA QUALITY                                            3.64
#                                          INSUFFICIENT DATA                                       4.55
# INFRASTRUCTURE 25             22.73      COMPUTATIONAL CONSTRAINTS                               4.55
#                                          DEPLOYMENT INFRASTRUCTURE                              13.64
#                                          INTEGRATION                                             0.91
#                                          MODEL MONITORING                                        1.82
#                                          SCALABILITY                                             1.82
# INPUT          8              7.27       INCOMPLETE/INCORRECT REQUIREMENTS                       3.64
#                                          LACK OF DOMAIN KNOWLEDGE                                0.91
#                                          PROBLEM UNDERSTANDING                                   1.82
#                                          UNCLEAR GOALS                                           0.91
# METHOD         40             36.36      BUILD PIPELINES                                         1.82
#                                          CHOOSE AND EVALUATE THE METRICS                        11.82
#                                          CODE QUALITY                                            0.91
#                                          COMMUNICATION                                           0.91
#                                          FEATURE ENGINEERING                                     0.91
#                                          HYPERPARAMETER TUNING                                   2.73
#                                          MODEL CREATION AND SELECTION                           10.91
#                                          MODEL SCALABILITY                                       0.91
#                                          MODEL UPDATE                                            1.82
#                                          OVERFITTING AND UNDERFITTING                            1.82
#                                          UI                                                      0.91
#                                          USER ACCEPTANCE TEST                                    0.91
# ORGANIZATION   7              6.36       CHANGE MANAGEMENT                                       0.91
#                                          DEFINITION OF ROLES AND RESPONSIBILITIES                0.91
#                                          FINANCIAL ISSUES                                        0.91
#                                          LACK OF TIME                                            0.91
#                                          LOW CLIENT/DOMAIN EXPERT AVAILABILITY/ENGAGEMENT        1.82
#                                          TEAM INTEGRATION                                        0.91
# PEOPLE         7              6.36       LACK OF DATA SCIENCE KNOWLEDGE                          2.73
#                                          LACK OF KNOWLEDGE                                       0.91
#                                          LACK OF TALENT/SKILL                                    2.73

# %%
df = qualitative_df['QUANTITY_%'].copy()
df.index = qualitative_df.index.get_level_values('TOPIC')
for key, val in zip(list(df.keys()), list(df)):
    print(f"{key.lower()} ({val} %)")
# Out:
# data accessibility (0.91 %)
# data availability (0.91 %)
# data collection (2.73 %)
# data preprocessing (8.18 %)
# data quality (3.64 %)
# insufficient data (4.55 %)
# computational constraints (4.55 %)
# deployment infrastructure (13.64 %)
# integration (0.91 %)
# model monitoring (1.82 %)
# scalability (1.82 %)
# incomplete/incorrect requirements (3.64 %)
# lack of domain knowledge (0.91 %)
# problem understanding (1.82 %)
# unclear goals (0.91 %)
# build pipelines (1.82 %)
# choose and evaluate the metrics (11.82 %)
# code quality (0.91 %)
# communication (0.91 %)
# feature engineering (0.91 %)
# hyperparameter tuning (2.73 %)
# model creation and selection (10.91 %)
# model scalability (0.91 %)
# model update (1.82 %)
# overfitting and underfitting (1.82 %)
# ui (0.91 %)
# user acceptance test (0.91 %)
# change management (0.91 %)
# definition of roles and responsibilities (0.91 %)
# financial issues (0.91 %)
# lack of time (0.91 %)
# low client/domain expert availability/engagement (1.82 %)
# team integration (0.91 %)
# lack of data science knowledge (2.73 %)
# lack of knowledge (0.91 %)
# lack of talent/skill (2.73 %)
